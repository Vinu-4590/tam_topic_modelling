# %%
# !pip install urlextract
# !pip install spacy
# !pip install contractions
# !pip install pyenchant
# !sudo yum install -y enchant
# !sudo yum install -y hunspell-en
# Out:
# Collecting urlextract
#   Downloading urlextract-1.3.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: appdirs in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from urlextract) (1.4.4)
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from urlextract) (3.0.12)
# Requirement already satisfied: idna in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from urlextract) (2.10)
# Collecting uritools
#   Downloading uritools-3.0.2-py3-none-any.whl (12 kB)
# Installing collected packages: uritools, urlextract
# Successfully installed uritools-3.0.2 urlextract-1.3.0
# WARNING: You are using pip version 21.1.3; however, version 21.2.4 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.
# Collecting spacy
#   Downloading spacy-3.1.2-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#      |████████████████████████████████| 5.9 MB 4.7 MB/s eta 0:00:01
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.5-cp36-cp36m-manylinux2014_x86_64.whl (20 kB)
# Collecting typer<0.4.0,>=0.3.0
#   Downloading typer-0.3.2-py3-none-any.whl (21 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.5-cp36-cp36m-manylinux2014_x86_64.whl (126 kB)
#      |████████████████████████████████| 126 kB 82.3 MB/s eta 0:00:01
# Collecting thinc<8.1.0,>=8.0.8
#   Downloading thinc-8.0.10-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (625 kB)
#      |████████████████████████████████| 625 kB 83.3 MB/s eta 0:00:01
# Collecting pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4
#   Downloading pydantic-1.8.2-cp36-cp36m-manylinux2014_x86_64.whl (10.2 MB)
#      |████████████████████████████████| 10.2 MB 42.1 MB/s eta 0:00:01
# Requirement already satisfied: jinja2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy) (2.11.3)
# Collecting catalogue<2.1.0,>=2.0.4
#   Downloading catalogue-2.0.6-py3-none-any.whl (17 kB)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy) (20.9)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy) (3.7.4.3)
# Collecting spacy-legacy<3.1.0,>=3.0.7
#   Downloading spacy_legacy-3.0.8-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy) (49.6.0.post20210108)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy) (4.61.2)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.5-cp36-cp36m-manylinux2014_x86_64.whl (35 kB)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy) (2.25.1)
# Collecting srsly<3.0.0,>=2.4.1
#   Downloading srsly-2.4.1-cp36-cp36m-manylinux2014_x86_64.whl (456 kB)
#      |████████████████████████████████| 456 kB 83.4 MB/s eta 0:00:01
# Collecting pathy>=0.3.5
#   Downloading pathy-0.6.0-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 2.8 MB/s  eta 0:00:01
# Requirement already satisfied: numpy>=1.15.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy) (1.19.5)
# Collecting blis<0.8.0,>=0.4.0
#   Downloading blis-0.7.4-cp36-cp36m-manylinux2014_x86_64.whl (9.8 MB)
#      |████████████████████████████████| 9.8 MB 41.8 MB/s eta 0:00:01
# Collecting wasabi<1.1.0,>=0.8.1
#   Downloading wasabi-0.8.2-py3-none-any.whl (23 kB)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from catalogue<2.1.0,>=2.0.4->spacy) (3.4.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from packaging>=20.0->spacy) (2.4.7)
# Collecting smart-open<6.0.0,>=5.0.0
#   Downloading smart_open-5.2.1-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 11.1 MB/s eta 0:00:01
# Requirement already satisfied: dataclasses<1.0,>=0.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pathy>=0.3.5->spacy) (0.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: contextvars<3,>=2.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from thinc<8.1.0,>=8.0.8->spacy) (2.4)
# Requirement already satisfied: immutables>=0.9 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from contextvars<3,>=2.4->thinc<8.1.0,>=8.0.8->spacy) (0.15)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from typer<0.4.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from jinja2->spacy) (1.1.1)
# Installing collected packages: murmurhash, cymem, catalogue, wasabi, typer, srsly, smart-open, pydantic, preshed, blis, thinc, spacy-legacy, pathy, spacy
# Successfully installed blis-0.7.4 catalogue-2.0.6 cymem-2.0.5 murmurhash-1.0.5 pathy-0.6.0 preshed-3.0.5 pydantic-1.8.2 smart-open-5.2.1 spacy-3.1.2 spacy-legacy-3.0.8 srsly-2.4.1 thinc-8.0.10 typer-0.3.2 wasabi-0.8.2
# WARNING: You are using pip version 21.1.3; however, version 21.2.4 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.
# Collecting contractions
#   Downloading contractions-0.0.52-py2.py3-none-any.whl (7.2 kB)
# Collecting textsearch>=0.0.21
#   Downloading textsearch-0.0.21-py2.py3-none-any.whl (7.5 kB)
# Collecting anyascii
#   Downloading anyascii-0.3.0-py3-none-any.whl (284 kB)
#      |████████████████████████████████| 284 kB 6.1 MB/s eta 0:00:01
# Collecting pyahocorasick
#   Downloading pyahocorasick-1.4.2.tar.gz (321 kB)
#      |████████████████████████████████| 321 kB 74.1 MB/s eta 0:00:01
# Building wheels for collected packages: pyahocorasick
#   Building wheel for pyahocorasick (setup.py) ... done
#   Created wheel for pyahocorasick: filename=pyahocorasick-1.4.2-cp36-cp36m-linux_x86_64.whl size=91143 sha256=7ad19c3f651e0ab40469e076fe932dedd2ffc16300150f642d84320d76c5646e
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/13/37/bd/c904d816433e1f65c97ca85c56823f1a7cb0dcaf3af2b17798
# Successfully built pyahocorasick
# Installing collected packages: pyahocorasick, anyascii, textsearch, contractions
# Successfully installed anyascii-0.3.0 contractions-0.0.52 pyahocorasick-1.4.2 textsearch-0.0.21
# WARNING: You are using pip version 21.1.3; however, version 21.2.4 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.
# Collecting pyenchant
#   Downloading pyenchant-3.2.1-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 2.7 MB/s eta 0:00:011
# Installing collected packages: pyenchant
# Successfully installed pyenchant-3.2.1
# WARNING: You are using pip version 21.1.3; however, version 21.2.4 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.
# Loaded plugins: dkms-build-requires, priorities, update-motd, upgrade-helper,
#               : versionlock
# amzn-main                                                | 2.1 kB     00:00
# amzn-updates                                             | 3.8 kB     00:00
# Resolving Dependencies
# --> Running transaction check
# ---> Package enchant.x86_64 1:1.6.0-5.2.amzn1 will be installed
# --> Processing Dependency: libhunspell-1.2.so.0()(64bit) for package: 1:enchant-1.6.0-5.2.amzn1.x86_64
# --> Running transaction check
# ---> Package hunspell.x86_64 0:1.2.8-16.2.amzn1 will be installed
# --> Finished Dependency Resolution
#
# Dependencies Resolved
#
# ================================================================================
#  Package         Arch          Version                   Repository        Size
# ================================================================================
# Installing:
#  enchant         x86_64        1:1.6.0-5.2.amzn1         amzn-main         54 k
# Installing for dependencies:
#  hunspell        x86_64        1.2.8-16.2.amzn1          amzn-main        191 k
#
# Transaction Summary
# ================================================================================
# Install  1 Package (+1 Dependent package)
#
# Total download size: 245 k
# Installed size: 514 k
# Downloading packages:
# (1/2): enchant-1.6.0-5.2.amzn1.x86_64.rpm                  |  54 kB   00:00
# (2/2): hunspell-1.2.8-16.2.amzn1.x86_64.rpm                | 191 kB   00:00
# --------------------------------------------------------------------------------
# Total                                              1.6 MB/s | 245 kB  00:00
# Running transaction check
# Running transaction test
# Transaction test succeeded
# Running transaction
# Warning: RPMDB altered outside of yum.
#   Installing : hunspell-1.2.8-16.2.amzn1.x86_64                             1/2
#   Installing : 1:enchant-1.6.0-5.2.amzn1.x86_64                             2/2
#   Verifying  : hunspell-1.2.8-16.2.amzn1.x86_64                             1/2
#   Verifying  : 1:enchant-1.6.0-5.2.amzn1.x86_64                             2/2
#
# Installed:
#   enchant.x86_64 1:1.6.0-5.2.amzn1
#
# Dependency Installed:
#   hunspell.x86_64 0:1.2.8-16.2.amzn1
#
# Complete!
# Loaded plugins: dkms-build-requires, priorities, update-motd, upgrade-helper,
#               : versionlock
# Existing lock /var/run/yum.pid: another copy is running as pid 81982.
# Another app is currently holding the yum lock; waiting for it to exit...
#   The other application is: yum
#     Memory :  63 M RSS (310 MB VSZ)
#     Started: Thu Sep  9 09:28:29 2021 - 00:01 ago
#     State  : Running, pid: 81982
# Resolving Dependencies
# --> Running transaction check
# ---> Package hunspell-en.noarch 0:0.20090216-7.1.2.amzn1 will be installed
# --> Finished Dependency Resolution
#
# Dependencies Resolved
#
# ================================================================================
#  Package          Arch        Version                      Repository      Size
# ================================================================================
# Installing:
#  hunspell-en      noarch      0.20090216-7.1.2.amzn1       amzn-main      626 k
#
# Transaction Summary
# ================================================================================
# Install  1 Package
#
# Total download size: 626 k
# Installed size: 1.6 M
# Downloading packages:
# hunspell-en-0.20090216-7.1.2.amzn1.noarch.rpm              | 626 kB   00:00
# Running transaction check
# Running transaction test
# Transaction test succeeded
# Running transaction
#   Installing : hunspell-en-0.20090216-7.1.2.amzn1.noarch                    1/1
#   Verifying  : hunspell-en-0.20090216-7.1.2.amzn1.noarch                    1/1
#
# Installed:
#   hunspell-en.noarch 0:0.20090216-7.1.2.amzn1
#
# Complete!

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('all')
# !python -m spacy download en_core_web_sm
# Out:
# [nltk_data] Downloading package punkt to /home/ec2-user/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /home/ec2-user/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/biocreative_ppi.zip.
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_cat.zip.
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_esp.zip.
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/chat80.zip.
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/city_database.zip.
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/comparative_sentences.zip.
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2002.zip.
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/crubadan.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/dependency_treebank.zip.
# [nltk_data]    | Downloading package dolch to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/dolch.zip.
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/europarl_raw.zip.
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/floresta.zip.
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v15.zip.
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v17.zip.
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package ieer to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/ieer.zip.
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package indian to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/indian.zip.
# [nltk_data]    | Downloading package jeita to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    | Downloading package kimmo to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/kimmo.zip.
# [nltk_data]    | Downloading package knbc to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/lin_thesaurus.zip.
# [nltk_data]    | Downloading package mac_morpho to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/mac_morpho.zip.
# [nltk_data]    | Downloading package machado to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping models/moses_sample.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/nps_chat.zip.
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/omw.zip.
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/opinion_lexicon.zip.
# [nltk_data]    | Downloading package paradigms to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/paradigms.zip.
# [nltk_data]    | Downloading package pil to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/pil.zip.
# [nltk_data]    | Downloading package pl196x to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/pl196x.zip.
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/ppattach.zip.
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/problem_reports.zip.
# [nltk_data]    | Downloading package propbank to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    | Downloading package ptb to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/ptb.zip.
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_1.zip.
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_2.zip.
# [nltk_data]    | Downloading package pros_cons to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/pros_cons.zip.
# [nltk_data]    | Downloading package qc to /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/qc.zip.
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    | Downloading package rte to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/rte.zip.
# [nltk_data]    | Downloading package semcor to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/senseval.zip.
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentiwordnet.zip.
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentence_polarity.zip.
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/sinica_treebank.zip.
# [nltk_data]    | Downloading package smultron to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/smultron.zip.
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/state_union.zip.
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/subjectivity.zip.
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/swadesh.zip.
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/switchboard.zip.
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/timit.zip.
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/toolbox.zip.
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package udhr to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr.zip.
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/unicode_samples.zip.
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    | Downloading package verbnet to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet.zip.
# [nltk_data]    | Downloading package verbnet3 to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet3.zip.
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/webtext.zip.
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package ycoe to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/ycoe.zip.
# [nltk_data]    | Downloading package rslp to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping stemmers/rslp.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping taggers/universal_tagset.zip.
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping grammars/book_grammars.zip.
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping grammars/sample_grammars.zip.
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping grammars/spanish_grammars.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping grammars/large_grammars.zip.
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping help/tagsets.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping models/bllip_wsj_no_aux.zip.
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping models/word2vec_sample.zip.
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    | Downloading package mte_teip5 to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/mte_teip5.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping misc/perluniprops.zip.
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping corpora/nonbreaking_prefixes.zip.
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    | Downloading package porter_test to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping stemmers/porter_test.zip.
# [nltk_data]    | Downloading package wmt15_eval to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping models/wmt15_eval.zip.
# [nltk_data]    | Downloading package mwa_ppdb to
# [nltk_data]    |     /home/ec2-user/nltk_data...
# [nltk_data]    |   Unzipping misc/mwa_ppdb.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# Collecting en-core-web-sm==3.1.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.1.0/en_core_web_sm-3.1.0-py3-none-any.whl (13.6 MB)
#      |████████████████████████████████| 13.6 MB 6.0 MB/s eta 0:00:01
# Requirement already satisfied: spacy<3.2.0,>=3.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from en-core-web-sm==3.1.0) (3.1.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.8.2)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.3.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (4.61.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.4.1)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (20.9)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.8)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.5)
# Requirement already satisfied: pathy>=0.3.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.6.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.8.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.5)
# Requirement already satisfied: numpy>=1.15.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.19.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.25.1)
# Requirement already satisfied: thinc<8.1.0,>=8.0.8 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (8.0.10)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.7.4)
# Requirement already satisfied: jinja2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.11.3)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (49.6.0.post20210108)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.0.5)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.7.4.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.6)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from catalogue<2.1.0,>=2.0.4->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.4.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from packaging>=20.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.4.7)
# Requirement already satisfied: dataclasses<1.0,>=0.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pathy>=0.3.5->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.8)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pathy>=0.3.5->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (5.2.1)
# Requirement already satisfied: idna<3,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.26.6)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.4)
# Requirement already satisfied: contextvars<3,>=2.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from thinc<8.1.0,>=8.0.8->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.4)
# Requirement already satisfied: immutables>=0.9 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from contextvars<3,>=2.4->thinc<8.1.0,>=8.0.8->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.15)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from typer<0.4.0,>=0.3.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from jinja2->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.1.1)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.1.0
# WARNING: You are using pip version 21.1.3; however, version 21.2.4 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import os
import random
import string
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pickle
import seaborn as sns
from datetime import datetime
import boto3
import dask.dataframe as dd
import tempfile



# %matplotlib inline
# %matplotlib notebook


pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 5000)
pd.set_option('display.float_format', str)
matplotlib.rcParams['figure.figsize'] = (10, 10)
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

working_dir = '/home/ec2-user/SageMaker'
base_dir = '/home/ec2-user/SageMaker/topic_modelling/'
# s3_data_path = 's3://bucket-sushant/bangla-character-recognition/'

## For reproducible results
seed_value = 18
os.environ['PYTHONHASHSEED'] = str(seed_value)
random.seed(seed_value)
np.random.seed(seed_value)
# https://stackoverflow.com/questions/5836335/consistently-create-same-random-numpy-array/5837352#5837352
random_state = np.random.RandomState(seed=seed_value)
s3 = boto3.client('s3')

def read_from_s3(file_path):
    bucket_name = file_path.split('/')[2]
    key = '/'.join(file_path.split('/')[3:])
    response = s3.get_object(Bucket=bucket_name, Key=key)
    body = response['Body'].read()
    return body

def read_pickle_from_s3(file_path):
    data = pickle.loads(read_from_s3(file_path))
    return data

# def read_csv_from_s3(file_path):
#     data = pd.read_csv(file_path, low_memory=False)
#     return data

def store_object_to_s3_as_pickle(data, file_path):
    bucket_name = file_path.split('/')[2]
    key = '/'.join(file_path.split('/')[3:])
#     # uses lot of memory
#     pickle_obj = pickle.dumps(data)
#     return s3.put_object(Key=key, Bucket=bucket_name, Body=pickle_obj)
    # using tmp file
    fd, path = tempfile.mkstemp()
    try:
        with open(path, 'wb') as pointer:
            pickle.dump(data, pointer)
        with open(path, "rb") as pointer:
            s3.upload_fileobj(pointer, bucket_name, key)
    finally:
        os.remove(path)

# %%
import nltk
from pandas import option_context
import ast
from urlextract import URLExtract
import string

from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import WordNetLemmatizer 
from nltk.stem import PorterStemmer 
import spacy
from nltk.corpus import stopwords
import re
import contractions
import enchant

# %%
# !pwd
# Out:
# /home/ec2-user/SageMaker/tam_topic_modelling/topic_modelling/DataCleaning

# %% [markdown]
# # Data Load

# %%
base_dir = "/home/ec2-user/SageMaker/tam_topic_modelling/topic_modelling/"

# %%
data = pd.read_excel(f'{base_dir}/Data/EC2_India_Cases_WithTS-Latest.xlsx',engine='openpyxl', skiprows=2)
print(data.shape)
data.head()
# data.style.set_properties(subset=['comm_body'], **{'width': '300px'})
# Out:
# (14595, 11)
#       case_id                     customer_name  \
# 0  7380196011                  RBL Bank Limited
# 1  7380196011                  RBL Bank Limited
# 2  7380196011                  RBL Bank Limited
# 3  7380321081  Edelweiss Financial Services Ltd
# 4  7380321081  Edelweiss Financial Services Ltd
#
#                                  service case_billing_region  \
# 0    Elastic Compute Cloud (EC2 - Linux)                APAC
# 1    Elastic Compute Cloud (EC2 - Linux)                APAC
# 2    Elastic Compute Cloud (EC2 - Linux)                APAC
# 3  Elastic Compute Cloud (EC2 - Windows)                APAC
# 4  Elastic Compute Cloud (EC2 - Windows)                APAC
#
#   customer_billing_country_name comm_owner_agent_login  \
# 0                         INDIA                rayaans
# 1                         INDIA                    NaN
# 2                         INDIA                rayaans
# 3                         INDIA                 shrmjj
# 4                         INDIA                 shrmjj
#
#                                            comm_body case_creation_cal_date  \
# 0  Hi Team,  we have instance currently undergoin...           Sep 14, 2020
# 1  Hi Team,  we have instance currently undergoin...           Sep 14, 2020
# 2  {"transcript":[{"action":"TRANSCRIPT_START","d...           Sep 14, 2020
# 3  Hi team,  we are not able to fetch ec2 system ...           Sep 14, 2020
# 4                         Phone call: you and Amazon           Sep 14, 2020
#
#                            comm_subject               comm_date_utc  \
# 0  Chat: high cpu utilization of server  September 14, 2020 6:40:59
# 1  Chat: high cpu utilization of server  September 14, 2020 7:03:26
# 2                                   NaN  September 14, 2020 7:03:36
# 3     Call: unable to fetch system logs  September 14, 2020 7:11:41
# 4                          Inbound Call  September 14, 2020 7:14:29
#
#    case_severity
# 0              4
# 1              4
# 2              4
# 3              4
# 4              4

# %%
with option_context('display.max_colwidth', 10000):
    display(data.comm_body.head(1))
# Out:
# 0    Hi Team,  we have instance currently undergoing with high cpu utilization. After checking top process I found that application java is currently using maximum of its cpu. But I'm not able to find that exactly which file or process within it is utilizing cpu. Can you please help me to find out about same? Instance ID(s): i-03a21c5ec8fc1df57
# Name: comm_body, dtype: object

# %% [markdown]
# ---

# %% [markdown]
# # Parsing dictionaries in the rows if they are there

# %%
def check_dict(v):
    try:
        evald = ast.literal_eval(v)
        if isinstance(evald, dict):
            return True
        else:
            return False
    except:
        return None

t = data.comm_body.apply(lambda x: check_dict(x))
t.value_counts(dropna=False)

data.comm_body.str[-10:].head(2140)
# Out:
# 0       ec8fc1df57
# 1       ec8fc1df57
# 2       e you are
# 3       M:SS UTC):
# 4       and Amazon
# 5       -services/
# 6       ec8fc1df57
# 7       ":"1","tim
# 8       ==========
# 9       549a66edd3
# 10            data
# 11      kay checki
# 12      ew server.
# 13      598315}}]}
# 14         Hi Team
# 15      ==========
# 16       on the sa
# 17      ort-HMD-No
# 18      -services/
# 19      cfa7c960f3
# 20      connecting
# 21      ng looks f
# 22      connecting
# 23      "action":"
# 24      4e2d31023e
# 25      shot added
# 26      nstance i-
# 27      -services/
# 28      age please
# 29      "timestamp
# 30      n.com/mana
# 31      ance mode.
# 32      and Amazon
# 33      -services/
# 34      state -> A
# 35      401&langua
# 36       for this.
# 37      Amrutha KS
# 38      mestamp":1
# 39      sconnected
# 40      622867}}]}
# 41      -services/
# 42      and Amazon
# 43      nce ID(s):
# 44       guide us.
# 45      ":{"text":
# 46       suddenly,
# 47      and Amazon
# 48      ining/  AW
# 49       Support C
# 50      M:SS UTC):
# 51      and Amazon
# 52      -services/
# 53      onsole.aws
# 54      -services/
# 55      8e6963d128
# 56      rod-sgpr-1
# 57      -services/
# 58      WS capacit
# 59      console.aw
# 60       the same.
# 61      t on call.
# 62      -services/
# 63      t on call.
# 64      779641}}]}
# 65             PFA
# 66      t on call.
# 67      184551}}]}
# 68      cddc04c996
# 69      -services/
# 70      ort-HMD-No
# 71      ==========
# 72      est ID(s):
# 73      -services/
# 74      -services/
# 75      -services/
# 76      i-1a942ebe
# 77       looking i
# 78      52bd1feae7
# 79      e error yo
# 80      75580f8852
# 81      0160962604
# 82      ur feedbac
# 83      -services/
# 84      d causing
# 85       configura
# 86      M:SS UTC):
# 87      and Amazon
# 88      -services/
# 89       over SSH.
# 90      ,"timestam
# 91      rds, Varun
# 92      articipant
# 93      -services/
# 94       via chat?
# 95      6}},{"acti
# 96      0b27f9ac9e
# 97      91890}},{"
# 98       regards,
# 99      mentation:
# 100     d further
# 101     that time.
# 102     mestamp":1
# 103     nce ID(s):
# 104      Dev team.
# 105     tance and
# 106     4a072959fa
# 107     4a072959fa
# 108     text":"It
# 109     hecks/nitr
# 110     ow the lin
# 111     :33:20 IST
# 112     ion":"MESS
# 113     M:SS UTC):
# 114     nstance","
# 115     ating Chat
# 116     ","data":{
# 117     ID is 1135
# 118     nce ID(s):
# 119     476234}}]}
# 120     lease help
# 121     ~]$","lang
# 122     this case,
# 123     s to which
# 124     M:SS UTC):
# 125     e time ","
# 126     aining: ht
# 127     r in AWS ?
# 128     ==========
# 129      singapore
# 130     lease shar
# 131     413ee4497d
# 132     SAGE","dat
# 133      as well.
# 134     ement: htt
# 135     -services/
# 136     ==========
# 137     M:SS UTC):
# 138     and Amazon
# 139     a12c6a7215
# 140     g connecti
# 141     2.micro ca
# 142     ort-HMD-No
# 143     experience
# 144     s, Sudipta
# 145     so be rate
# 146     73fb3b54d5
# 147     7302698045
# 148     rse","lang
# 149     entation:
# 150     nce ID(s):
# 151     ay ","lang
# 152     ssistance.
# 153     all option
# 154     ssistance.
# 155     -services/
# 156     is API too
# 157     to fix it?
# 158     64-bit x86
# 159     M:SS UTC):
# 160     good thank
# 161     ssistance.
# 162     ttps://con
# 163     -services/
# 164     his graph.
# 165     ://aws.ama
# 166     14bff91648
# 167     t":"yes co
# 168     -services/
# 169     e of that?
# 170     "from":"2"
# 171     ease help.
# 172     er is low.
# 173     nce ID(s):
# 174     ","data":{
# 175     M:SS UTC):
# 176     ,"from":"6
# 177     AWS Suppor
# 178     M:SS UTC):
# 179     ,"from":"1
# 180     -services/
# 181     ntation: h
# 182     M:SS UTC):
# 183     and Amazon
# 184     cc6946451d
# 185     ":"","from
# 186     volume-req
# 187      some info
# 188     and Amazon
# 189     -services/
# 190     M:SS UTC):
# 191     ","timesta
# 192     -services/
# 193      AWS Suppo
# 194      this case
# 195     g the netw
# 196     nding to t
# 197     Best regar
# 198     ease check
# 199     ut 1 hour)
# 200     ave launch
# 201     p servers.
# 202     M:SS UTC):
# 203     adba4de560
# 204     initiating
# 205     p servers.
# 206     36985}},{"
# 207     72020-09-1
# 208     initiating
# 209     910568}}]}
# 210     -services/
# 211     -services/
# 212     ontinue ou
# 213     ning/  AWS
# 214     le.  I hop
# 215     7f43f632dd
# 216     -services/
# 217     ce failed.
# 218     166b3e26f5
# 219     M:SS UTC):
# 220      you would
# 221     a652104e3c
# 222     initiating
# 223     a652104e3c
# 224      Services:
# 225     n instance
# 226     GE","data"
# 227     initiating
# 228     w call fro
# 229     in the ASG
# 230      this ","l
# 231     r.  This i
# 232     ":"MESSAGE
# 233     lication a
# 234      earliest?
# 235      earliest?
# 236     nce ID(s):
# 237     694070}}]}
# 238     -services/
# 239      earliest?
# 240     he case an
# 241     us again a
# 242     /knowledge
# 243     9039663672
# 244     and Amazon
# 245     -services/
# 246     -services/
# 247     -services/
# 248     n  Note, t
# 249     nce type.
# 250     -services/
# 251     ut 1 hour)
# 252     5}},{"acti
# 253     nce ID(s):
# 254     -services/
# 255     .ap-southe
# 256     om please?
# 257     slow ECR i
# 258     nce ID(s):
# 259     so be rate
# 260     ged or not
# 261     66392177}}
# 262      PST) or (
# 263     ==========
# 264     ged or not
# 265     :"MESSAGE"
# 266     hots.html
# 267     ooks good.
# 268     and Amazon
# 269     -services/
# 270     M:SS UTC):
# 271     -services/
# 272     30930b3939
# 273     se feel fr
# 274     Namespace:
# 275      resolved.
# 276     ort-HMD-No
# 277      like the
# 278     o validate
# 279     select dis
# 280     doing IEM.
# 281     -services/
# 282     ai region.
# 283     ang":"","f
# 284     ect again.
# 285     lang":"","
# 286     41ae4bf61d
# 287     "data":{"t
# 288     e Needful.
# 289     and Amazon
# 290     raining: h
# 291     -services/
# 292     nd i-015e7
# 293     k_trace":
# 294     t 2 hours)
# 295     s activity
# 296      us-east-1
# 297     tion":"MES
# 298     ==========
# 299      my instan
# 300     43146dc06d
# 301     ues that c
# 302     b Services
# 303     nce ID(s):
# 304     he source
# 305     b Services
# 306     ssions on
# 307     7b67f08785
# 308     MESSAGE","
# 309     -services/
# 310     M:SS UTC):
# 311     0}},{"acti
# 312     r support.
# 313     ort-HMD-No
# 314     b Services
# 315     b Services
# 316     -services/
# 317            PFA
# 318     spondence.
# 319     let me gen
# 320     -south-1c.
# 321     nd throwin
# 322     ==========
# 323     essfully u
# 324     M:SS UTC):
# 325     m",     "u
# 326     84a20b51c2
# 327     on":"MESSA
# 328     b Services
# 329     t  # cd /b
# 330     nce ID(s):
# 331     and Amazon
# 332     the issue.
# 333     .  Thanks,
# 334     .  Thanks,
# 335     ows EC2 in
# 336     the issue.
# 337     e.  Thanks
# 338      Revanth S
# 339     b Services
# 340     b Services
# 341     and Amazon
# 342     sh Panchal
# 343     re the ins
# 344     -services/
# 345     -services/
# 346     4b41ddd6e9
# 347     and Amazon
# 348     the issue.
# 349     the issue.
# 350     -services/
# 351      System Ch
# 352     sent from
# 353     d, I'll be
# 354     b Services
# 355     ee0fa76d9f
# 356     -services/
# 357     42195c5a1f
# 358      in server
# 359     {"action":
# 360     M:SS UTC):
# 361     94a73afd39
# 362      you ","la
# 363     .com/premi
# 364     ervices  =
# 365      session m
# 366     nce ID(s):
# 367      AWS side.
# 368     the SSH se
# 369     .amazon.co
# 370      . . . . :
# 371      : 255.255
# 372      443.  * n
# 373     b Services
# 374     nce ID(s):
# 375     estamp":16
# 376     b Services
# 377     WS Cost Ma
# 378     -services/
# 379      (25 days)
# 380      Windows i
# 381      ; add-rou
# 382     ks, Rakesh
# 383     nks/-Imran
# 384     -services/
# 385     nce ID(s):
# 386     and Amazon
# 387     -services/
# 388     11eb25bbbe
# 389     and Amazon
# 390     /‎2020 IST
# 391     -services/
# 392     10bf7b7641
# 393     ,"data":{"
# 394     =======  T
# 395     rvices  ==
# 396     e drives a
# 397      S. Amazon
# 398     e on it ??
# 399      Ashick. A
# 400     b Services
# 401     b Services
# 402     WS-VSR-055
# 403     b Services
# 404     WS-VSR-055
# 405     his issue.
# 406     e crontab.
# 407     oudSupport
# 408      an addres
# 409     and Amazon
# 410     03d3%22%7d
# 411     rompt=true
# 412     b Services
# 413     ocs.aws.am
# 414     ether we h
# 415           chat
# 416     17}},{"act
# 417     M:SS UTC):
# 418     and Amazon
# 419     -services/
# 420     b Services
# 421     please fol
# 422     er/  AWS D
# 423     ss/Domain:
# 424     and Amazon
# 425     b Services
# 426     gramdata\a
# 427     hanks Amit
# 428     /training/
# 429     hanks Amit
# 430     ter/ec2-wi
# 431      return to
# 432     M:SS UTC):
# 433     "from":"2"
# 434     ious snaps
# 435     ext steps.
# 436     amp":16008
# 437      1/2 check
# 438     and Amazon
# 439     -services/
# 440     nks/-Imran
# 441     b Services
# 442     share your
# 443           call
# 444     lus001.txt
# 445     lus002.txt
# 446     his image.
# 447     b Services
# 448     b Services
# 449     Amit Kumar
# 450     and Amazon
# 451     -services/
# 452     .amazon.co
# 453     -services/
# 454     reference.
# 455     -services/
# 456     -services/
# 457      response.
# 458     919771}}]}
# 459     ny update?
# 460     cher.servi
# 461     b Services
# 462     of errors.
# 463     and Amazon
# 464     ort-HMD-No
# 465     45fc9cf34e
# 466     -services/
# 467     VAPPS007))
# 468     ","timesta
# 469     FATAL="no"
# 470     ole.aws.am
# 471     ort-HMD-No
# 472     ort-HMD-No
# 473     meter Regi
# 474     e followin
# 475     Amit Kumar
# 476     and Amazon
# 477     -services/
# 478     M:SS UTC):
# 479     and Amazon
# 480     ks, Girish
# 481     ort-HMD-No
# 482     he followi
# 483     ort-HMD-No
# 484     he launch
# 485     -services/
# 486     see events
# 487     nce ID(s):
# 488     629598}}]}
# 489             ++
# 490              +
# 491     t that the
# 492     -services/
# 493              +
# 494     21}},{"act
# 495     b Services
# 496     .aws.amazo
# 497     M:SS UTC):
# 498     ,"timestam
# 499     ess to it,
# 500     5debe4cb31
# 501     "lang":"",
# 502          0.00
# 503     :/mnt/ebs#
# 504     nce ID(s):
# 505     g":"","fro
# 506     es with Sl
# 507     -services/
# 508     b Services
# 509     1c2878c611
# 510     892}},{"ac
# 511     191&langua
# 512     re region.
# 513     re I will
# 514     4a63f535ca
# 515     "MESSAGE",
# 516     -services/
# 517     for AWS-Ru
# 518     ort-HMD-No
# 519     2d17972c3d
# 520     and Amazon
# 521     rsists thr
# 522     -services/
# 523     42570e2f5b
# 524     xt":"Sure,
# 525     uth-1~metr
# 526     e service.
# 527      AWS Manag
# 528     ort-HMD-No
# 529     um~start~%
# 530     ort-HMD-No
# 531     ort-HMD-No
# 532     aa71b05d30
# 533     ,"timestam
# 534     b Services
# 535     on launch.
# 536     r support.
# 537     est ID(s):
# 538      and may I
# 539     and Amazon
# 540     -services/
# 541     ort-HMD-No
# 542     ning: http
# 543     s keys, or
# 544     b Services
# 545     -services/
# 546     b Services
# 547     -services/
# 548     gtharia",
# 549     s us know.
# 550     -services/
# 551      7.7 & 8.1
# 552     a184f84e71
# 553     "action":"
# 554     often usef
# 555     il changed
# 556     ort-HMD-No
# 557     b Services
# 558     o the help
# 559     .336838]
# 560     b Services
# 561     b Services
# 562     b Services
# 563     570f82af3f
# 564     -services/
# 565     ort-HMD-No
# 566     b Services
# 567     b Services
# 568     ort-HMD-No
# 569     b Services
# 570       [1] http
# 571     b Services
# 572     M:SS UTC):
# 573      launched
# 574     &language=
# 575     5b5d527d87
# 576     ort-HMD-No
# 577     ort-HMD-No
# 578     ort-HMD-No
# 579     b Services
# 580     ort-HMD-No
# 581     ort-HMD-No
# 582     b Services
# 583     i Tatituri
# 584     ort-HMD-No
# 585     b9c2b92c32
# 586     M:SS UTC):
# 587     ","data":{
# 588     -services/
# 589     azon.com/m
# 590     nce ID(s):
# 591     "data":{"t
# 592     ort-HMD-No
# 593     ort-HMD-No
# 594     arding AMI
# 595     "from":"7"
# 596     ort-HMD-No
# 597     ssistance.
# 598     ws-cost-ma
# 599      help ASAP
# 600     ort-HMD-No
# 601     M:SS UTC):
# 602     ":"1","tim
# 603     connecting
# 604     then insta
# 605     connecting
# 606     action":"M
# 607     7303332976
# 608     7303332976
# 609     e attached
# 610     b Services
# 611      faster tr
# 612     their end
# 613     ort-HMD-No
# 614     a1nbucp001
# 615     ed support
# 616     or support
# 617     and Amazon
# 618     08e09ac9d3
# 619     -services/
# 620     d not appe
# 621     ypes/  We
# 622     ort-HMD-No
# 623     -services/
# 624     ==========
# 625     ort-HMD-No
# 626     en Nilofer
# 627     559043}}]}
# 628     559802}}]}
# 629     -services/
# 630     9619573314
# 631     ted? Was t
# 632     .30 PM IST
# 633     eady open.
# 634     ":"I under
# 635     b3dab1c32e
# 636     on":"MESSA
# 637     -services/
# 638     -services/
# 639     a2a9dd9055
# 640     535334}},{
# 641     b Services
# 642     39.96.0/20
# 643     ess in tho
# 644     gn fault t
# 645     t M. Amazo
# 646     b Services
# 647     ntu Server
# 648      help ASAP
# 649     531}},{"ac
# 650     erver ASAP
# 651     ntu Server
# 652     stamp":160
# 653     9891960567
# 654     14.04 ASAP
# 655      how are y
# 656     e within t
# 657     9344bb3e0a
# 658     nything","
# 659     our needs.
# 660     remiumsupp
# 661     nt.json  C
# 662     rver 14.04
# 663     imestamp":
# 664     s, Shubham
# 665     and Amazon
# 666     s Srikanth
# 667     -services/
# 668     rver 14.04
# 669     679029}}]}
# 670     ort-HMD-No
# 671     02717cae72
# 672     and Amazon
# 673       Regards,
# 674     ge-center/
# 675      cannot de
# 676      examples?
# 677     ort-HMD-No
# 678     ==========
# 679     t.com/kb/v
# 680     -services/
# 681     he link ab
# 682     -services/
# 683     ort-HMD-No
# 684     -services/
# 685     ort-HMD-No
# 686     ort-HMD-No
# 687     ort-HMD-No
# 688     ort-HMD-No
# 689     b Services
# 690     ort-HMD-No
# 691     ort-HMD-No
# 692     b Services
# 693     3ab669f407
# 694     404abadf3f
# 695     :"8","time
# 696     ://aws.ama
# 697     ort-HMD-No
# 698     ort-HMD-No
# 699     ment/  AWS
# 700     M:SS UTC):
# 701     2557}},{"a
# 702     nce ID(s):
# 703     554629}}]}
# 704     ot accept
# 705     /aws.amazo
# 706     r/  AWS Do
# 707      this e-ma
# 708     nce ID(s):
# 709     vailabilit
# 710     b Services
# 711      earliest.
# 712     m doing go
# 713     -services/
# 714     M:SS UTC):
# 715     the end of
# 716     jar:4.4.10
# 717     2","lang":
# 718     M:SS UTC):
# 719     059879}}]}
# 720     b Services
# 721     -services/
# 722     nter/  AWS
# 723     region~%27
# 724     t backend?
# 725     080065}}]}
# 726     ork issue.
# 727     imestamp":
# 728     e instance
# 729     0f791f5ba4
# 730     hich resul
# 731     .conf file
# 732     ort-HMD-No
# 733     .conf file
# 734     b Services
# 735     ssistance.
# 736     ssistance.
# 737     rvices: ht
# 738     c7907285fa
# 739     c7907285fa
# 740     {"action":
# 741     -services/
# 742     ac8eb9b2cd
# 743     imestamp":
# 744     ars in top
# 745     -services/
# 746     ort-HMD-No
# 747     e-mail was
# 748     xperience
# 749     nce ID(s):
# 750     ng":"","fr
# 751     each corre
# 752      spikes ov
# 753     b Services
# 754     cation is
# 755     rity Group
# 756     C2 to CORP
# 757     matically.
# 758     and Amazon
# 759     upport sho
# 760     -services/
# 761     S Support
# 762     s the air.
# 763     ort-HMD-No
# 764     esolve it?
# 765      for same.
# 766     b Services
# 767     b Services
# 768     nce ID(s):
# 769     71}},{"act
# 770     27c0f4cea0
# 771     ose volume
# 772     41afbb415b
# 773     ervices  =
# 774     ssistance.
# 775     isbank.com
# 776     Managed Se
# 777     nce ID(s):
# 778     e session.
# 779     e connect?
# 780     -services/
# 781     -services/
# 782     respondenc
# 783     indly help
# 784     mestamp":1
# 785     indly help
# 786     e running
# 787     -services/
# 788     -services/
# 789     ort seeing
# 790     nce ID(s):
# 791     xt":"Sure"
# 792     mran Singh
# 793     ort-HMD-No
# 794     nce ID(s):
# 795     lang":"","
# 796     ==========
# 797      sudo su -
# 798     "from":"1"
# 799     daemon (ss
# 800     hanks Dave
# 801     correspond
# 802     b Services
# 803     ort-HMD-No
# 804      solution.
# 805     getting In
# 806     e follow t
# 807     ntering in
# 808     the issue.
# 809     rom":"1","
# 810     M:SS UTC):
# 811     -services/
# 812     M:SS UTC):
# 813     and Amazon
# 814     ce 'i-0fd1
# 815     apsapemp05
# 816     8}},{"acti
# 817     s://aws.am
# 818     zon.com/pr
# 819     nce ID(s):
# 820      reconnect
# 821     END","data
# 822     M:SS UTC):
# 823     ublic subn
# 824     891992}}]}
# 825      reconnect
# 826      reconnect
# 827     "data":{"t
# 828     d relevant
# 829     -services/
# 830     sh Panchal
# 831     estamp":16
# 832     nce ID(s):
# 833     this ASAP.
# 834             hi
# 835     {"text":"W
# 836     -services/
# 837     ort-HMD-No
# 838     ort-HMD-No
# 839     w the link
# 840     lso be rat
# 841     -services/
# 842     nce ID(s):
# 843     tamp":1601
# 844     :57 ip-10-
# 845     ve to resp
# 846     b Services
# 847     s   Thanks
# 848     }},{"actio
# 849     ssue ASAP.
# 850     and Amazon
# 851     nother cal
# 852     -services/
# 853     e.aws.amaz
# 854     b Services
# 855     b Services
# 856     -services/
# 857     ort-HMD-No
# 858     b Services
# 859     ove to res
# 860     -services/
# 861     b Services
# 862     eing loade
# 863     ort-HMD-No
# 864     ort-HMD-No
# 865     b Services
# 866     -services/
# 867     b Services
# 868     limit of c
# 869     b Services
# 870     b Services
# 871     share now.
# 872     ang":"","f
# 873     dwath log.
# 874     ort-HMD-No
# 875     b Services
# 876     b Services
# 877     d8bf533ff4
# 878     hanks for
# 879     mran Singh
# 880     letion, I
# 881     ort-HMD-No
# 882     b Services
# 883     ort-HMD-No
# 884      Next, usi
# 885     ort-HMD-No
# 886     -services/
# 887     b Services
# 888     10d6b8ccea
# 889     text":"ok"
# 890     9920341992
# 891      case, ple
# 892     ort-HMD-No
# 893     fcb5cf895a
# 894     ances in t
# 895     rget Group
# 896     ort-HMD-No
# 897     ef99829079
# 898     x, Parveen
# 899     r contact
# 900     -services/
# 901     ing badly?
# 902     "1","times
# 903     Z 1a)  Thx
# 904     -services/
# 905     -services/
# 906     gent error
# 907     ":"","from
# 908     ws.amazon.
# 909     ==========
# 910     54f70238b1
# 911     and Amazon
# 912     -services/
# 913      Load Bala
# 914     nce ID(s):
# 915      database.
# 916     ort-HMD-No
# 917     and Amazon
# 918     ll me back
# 919     sconnected
# 920     and Amazon
# 921     =  AWS Sup
# 922     20-10-03T0
# 923     ase, pleas
# 924     ort-HMD-No
# 925     ort-HMD-No
# 926     ort-HMD-No
# 927     ort-HMD-No
# 928     ort-HMD-No
# 929     b Services
# 930     ort-HMD-No
# 931     ort-HMD-No
# 932     ort-HMD-No
# 933     ort-HMD-No
# 934     b Services
# 935     M:SS UTC):
# 936     mentioned
# 937     ==========
# 938     b Services
# 939     bda6276fa9
# 940      persisten
# 941     isbank.com
# 942     ssistance.
# 943     also be ra
# 944     M:SS UTC):
# 945     ng PIN: 36
# 946     -services/
# 947     spond from
# 948     ds, Piyush
# 949     GE","data"
# 950     81f260d882
# 951     from":"5",
# 952     ds, Piyush
# 953     MESSAGE","
# 954     4cfc00a439
# 955     sudden. Th
# 956     low the li
# 957     instance ?
# 958     rom":"1","
# 959     er, should
# 960     ort-HMD-No
# 961     567265e03e
# 962     {"action":
# 963     8090714030
# 964     ----------
# 965     ort-HMD-No
# 966     b Services
# 967     tance. Sto
# 968     ort-HMD-No
# 969     b Services
# 970     f1eb412503
# 971     nce ID(s):
# 972     ICIPANT_CH
# 973     sconnected
# 974     premiumsup
# 975      gcc -y  6
# 976     -services/
# 977     ort-HMD-No
# 978     azon.com/a
# 979     b Services
# 980     form same?
# 981     319580}}]}
# 982     form same?
# 983     648511}}]}
# 984     nce ID(s):
# 985     Mangaonkar
# 986     g":"","fro
# 987     -services/
# 988     his ASAP ?
# 989     timestamp"
# 990     -services/
# 991     t with him
# 992     MESSAGE","
# 993     M:SS UTC):
# 994      memory an
# 995     b Services
# 996            PFA
# 997     ps://docs.
# 998     -services/
# 999     your feedb
# 1000    auto-upgra
# 1001    -services/
# 1002    b Services
# 1003    12ac8fda7.
# 1004     for delay
# 1005    ort-HMD-No
# 1006    -135-149:~
# 1007    nnect now.
# 1008    -services/
# 1009    -services/
# 1010    URL: https
# 1011     URL: http
# 1012    -services/
# 1013    and Amazon
# 1014    h cake php
# 1015    s details.
# 1016    timestamp"
# 1017    cbb0e2a48f
# 1018     connect t
# 1019    , I do not
# 1020    se issues.
# 1021    b Services
# 1022    t session.
# 1023    ssistance.
# 1024    nce ID(s):
# 1025    re both 'n
# 1026    b Services
# 1027    nce ID(s):
# 1028    ssistance.
# 1029    est ID(s):
# 1030    ssistance.
# 1031    est ID(s):
# 1032    ssistance.
# 1033    nce type o
# 1034    gion~%27ap
# 1035    adly assis
# 1036    espondence
# 1037    tamp":1601
# 1038    b Services
# 1039    b Services
# 1040    b Services
# 1041    b Services
# 1042    [   +0ns]
# 1043    b Services
# 1044    nce ID(s):
# 1045    ow. Note:
# 1046    gards, Eri
# 1047    S account.
# 1048    79661}},{"
# 1049    unning ec2
# 1050    1896491\n"
# 1051    k. Please
# 1052    -services/
# 1053    nce ID(s):
# 1054    nce ID(s):
# 1055    it?","lang
# 1056    -services/
# 1057    b Services
# 1058    /case/?dis
# 1059    b Services
# 1060    b Services
# 1061    his issue?
# 1062     please le
# 1063    trawberry)
# 1064    er issues?
# 1065    M:SS UTC):
# 1066    azon.com/
# 1067    -services/
# 1068    M:SS UTC):
# 1069    112668}}]}
# 1070            HI
# 1071    ta":{"text
# 1072    e on this.
# 1073    ":"MESSAGE
# 1074     R. Amazon
# 1075    rs about l
# 1076          Call
# 1077    and Amazon
# 1078    s failure.
# 1079    ssistance.
# 1080    nce ID(s):
# 1081    "action":"
# 1082    -services/
# 1083    ive action
# 1084    t instance
# 1085    -aAXv --ex
# 1086     us again
# 1087    es, DB etc
# 1088     deploymen
# 1089    b Services
# 1090    97da4efced
# 1091    and Amazon
# 1092    c207080fc5
# 1093    hose logs.
# 1094    he logs fo
# 1095    -services/
# 1096    llow the l
# 1097    go to the
# 1098    -services/
# 1099     the end o
# 1100    ab44cc1b39
# 1101    some hardw
# 1102    12b8b9b2c9
# 1103    =======  A
# 1104    nce ID(s):
# 1105     the regio
# 1106    ort-HMD-No
# 1107    b Services
# 1108    technology
# 1109    ==========
# 1110    -services/
# 1111    anguage=en
# 1112    -services/
# 1113    ort-HMD-No
# 1114    nse Bindu.
# 1115    ort-HMD-No
# 1116    sad Bavkar
# 1117    M:SS UTC):
# 1118    -services/
# 1119    shok Singh
# 1120    ng":"","fr
# 1121    b Services
# 1122    .com/AWSEC
# 1123    ort-HMD-No
# 1124    nce ID(s):
# 1125    -services/
# 1126    -services/
# 1127    814bfd3cb6
# 1128    "text":"Ok
# 1129    e.internal
# 1130    e.internal
# 1131    BsO-W2Z1ir
# 1132    b Services
# 1133    626b20edc2
# 1134    mestamp":1
# 1135    nce ID(s):
# 1136    "timestamp
# 1137    case as cl
# 1138    b Services
# 1139    -services/
# 1140    o_script]#
# 1141    ","lang":"
# 1142    V2:graph=~
# 1143    ase, pleas
# 1144    Mangaonkar
# 1145    _CHANGE","
# 1146    Mangaonkar
# 1147    her?As we
# 1148    ssistance.
# 1149    acut -f -v
# 1150    10.8.2.175
# 1151    -services/
# 1152    b Services
# 1153    ided link.
# 1154    9717995943
# 1155    b Services
# 1156     access ke
# 1157    tes from p
# 1158    a13b2989b7
# 1159    -services/
# 1160    -services/
# 1161    and Amazon
# 1162    -services/
# 1163    s 25297 (r
# 1164    -services/
# 1165    nce ID(s):
# 1166    rk limits.
# 1167    nce ID(s):
# 1168    2166363316
# 1169    nce ID(s):
# 1170     name or a
# 1171    M:SS UTC):
# 1172    data":{"te
# 1173    -services/
# 1174    b Services
# 1175    3e4fe1c462
# 1176    t":"it is
# 1177    onnectiong
# 1178    t the end
# 1179    ort-HMD-No
# 1180    onnectiong
# 1181    done, I ha
# 1182     customer.
# 1183    timestamp"
# 1184     Cost Mana
# 1185    om/premium
# 1186    b Services
# 1187    IPv6: ADDR
# 1188    nce ID(s):
# 1189    -services/
# 1190     above to
# 1191       23 [14]
# 1192    ddress tha
# 1193    b Services
# 1194    b Services
# 1195    azon.com/m
# 1196    0b:34:f4
# 1197    29.123 80]
# 1198    n":"MESSAG
# 1199    -services/
# 1200     happened.
# 1201    ort-HMD-No
# 1202    isbank.com
# 1203    ort-HMD-No
# 1204    ort-HMD-No
# 1205    l at once?
# 1206    :"9","time
# 1207    roland.com
# 1208    m":"1","ti
# 1209    ort-HMD-No
# 1210    -services/
# 1211      AWS Trai
# 1212    -services/
# 1213    -services/
# 1214    ab=details
# 1215     Impacted.
# 1216    M:SS UTC):
# 1217     disk spac
# 1218    ==========
# 1219     attention
# 1220    h correspo
# 1221    ds, Girish
# 1222    ssistance.
# 1223    ort-HMD-No
# 1224    -services/
# 1225    b Services
# 1226    hanks Dave
# 1227    ort-HMD-No
# 1228    ort-HMD-No
# 1229    ort-HMD-No
# 1230    ort-HMD-No
# 1231    ort-HMD-No
# 1232    ort-HMD-No
# 1233    b Services
# 1234    42a89e49ff
# 1235    ed retirem
# 1236     Events -
# 1237    te, this e
# 1238    ort-HMD-No
# 1239    ort-HMD-No
# 1240    ort-HMD-No
# 1241    i-0d8092b0
# 1242    see there
# 1243    sad Bavkar
# 1244    9be79ad716
# 1245    and Amazon
# 1246    -services/
# 1247    sad Bavkar
# 1248    ort-HMD-No
# 1249    y an issue
# 1250    7a70e57185
# 1251    b Services
# 1252    within the
# 1253    M:SS UTC):
# 1254    and Amazon
# 1255    -services/
# 1256    e:    If Y
# 1257    b Services
# 1258    9079ee9579
# 1259    263259}}]}
# 1260    nce on it.
# 1261            hi
# 1262    imestamp":
# 1263    .aws.amazo
# 1264    ort-HMD-No
# 1265    sad Bavkar
# 1266    and Amazon
# 1267    -services/
# 1268    sad Bavkar
# 1269    -services/
# 1270    ort-HMD-No
# 1271    ian Kanwar
# 1272    and Amazon
# 1273    -services/
# 1274    b Services
# 1275    sad Bavkar
# 1276    get notifi
# 1277    ort-HMD-No
# 1278    ort-HMD-No
# 1279    ort-HMD-No
# 1280     Harsimran
# 1281    sad Bavkar
# 1282    2 minimum.
# 1283    d what you
# 1284    -services/
# 1285    -services/
# 1286    ort-HMD-No
# 1287    -services/
# 1288    ing of ssm
# 1289    and Amazon
# 1290    spondence
# 1291    -services/
# 1292    t scale. Y
# 1293    ort-HMD-No
# 1294    ort-HMD-No
# 1295    eds specif
# 1296    ugh the me
# 1297    cessing LB
# 1298    "4","times
# 1299    nce ID(s):
# 1300    SSAGE","da
# 1301    -services/
# 1302    s.html#ec2
# 1303    orner of e
# 1304    nce ID(s):
# 1305    sh Panchal
# 1306    timestamp"
# 1307     on users.
# 1308    stamp":160
# 1309    nnot accep
# 1310    nce ID(s):
# 1311    bfc46cb207
# 1312    ng":"","fr
# 1313    rough ADFS
# 1314     as ADFS?"
# 1315    &language=
# 1316     on call ?
# 1317    and Amazon
# 1318    to make su
# 1319    35f9f3226d
# 1320     please fo
# 1321    b Services
# 1322    =====  How
# 1323    RL: https:
# 1324    M:SS UTC):
# 1325    "instance
# 1326    -services/
# 1327    ort-HMD-No
# 1328    M:SS UTC):
# 1329    -services/
# 1330     experienc
# 1331    M:SS UTC):
# 1332    nce ID(s):
# 1333    sues insta
# 1334    low issue.
# 1335    nce using
# 1336    ort-HMD-No
# 1337    -services/
# 1338    9ecd74e80f
# 1339    that canno
# 1340    ating this
# 1341    _System~%2
# 1342    ticket now
# 1343    M:SS UTC):
# 1344    ools?","la
# 1345    78dde8da6d
# 1346    ort-HMD-No
# 1347    M:SS UTC):
# 1348    ":"yes","l
# 1349    king well.
# 1350    m/support/
# 1351    .    Addit
# 1352    b Services
# 1353     your expe
# 1354    b Services
# 1355    -adpauser)
# 1356    -services/
# 1357    ances/ [3]
# 1358    7fbce78dde
# 1359    nstances .
# 1360    ce in AWS
# 1361     Anitha M.
# 1362    and Amazon
# 1363    b Services
# 1364    73b68b1ac8
# 1365    and Amazon
# 1366    -services/
# 1367    raining/
# 1368    -services/
# 1369    -services/
# 1370    -services/
# 1371    ort-HMD-No
# 1372    b Services
# 1373    b Services
# 1374    b Services
# 1375    ort-HMD-No
# 1376    e instance
# 1377    ilable to
# 1378    ng the fol
# 1379    M:SS UTC):
# 1380    bout this
# 1381    &language=
# 1382    aws.amazon
# 1383    b Services
# 1384    ort-HMD-No
# 1385    ort-HMD-No
# 1386    b Services
# 1387     schedule.
# 1388    ent","disp
# 1389    d33ed462e2
# 1390    and Amazon
# 1391    -services/
# 1392     contact m
# 1393    t in sync.
# 1394    and Amazon
# 1395    12 months)
# 1396    895413}},{
# 1397    mazon.com/
# 1398     best to a
# 1399    M:SS UTC):
# 1400    M:SS UTC):
# 1401     call to t
# 1402    ort-HMD-No
# 1403    b Services
# 1404    -services/
# 1405    -services/
# 1406    b Services
# 1407    e suggest.
# 1408    our server
# 1409    "","from":
# 1410    ps_reset_p
# 1411    sh Panchal
# 1412    -services/
# 1413    8879719949
# 1414     per hour.
# 1415    uivalent i
# 1416    respondenc
# 1417    -services/
# 1418     Since the
# 1419    .536531 20
# 1420    auth.goibi
# 1421    sh Panchal
# 1422    ort-HMD-No
# 1423    b Services
# 1424    nce ID(s):
# 1425    ta":{"text
# 1426    9619573314
# 1427    and Amazon
# 1428    , Suhas S.
# 1429    rors shoul
# 1430    roup Name:
# 1431    azon Web S
# 1432    sad Bavkar
# 1433    b Services
# 1434    nce ID(s):
# 1435    -services/
# 1436    he end of
# 1437    -services/
# 1438    ----------
# 1439    8cabf48a80
# 1440    6027006260
# 1441     network .
# 1442    b Services
# 1443    78cabf48a8
# 1444    e replacin
# 1445    s, Sudipta
# 1446    ":{"text":
# 1447    .  Thanks.
# 1448    ,"lang":""
# 1449    k with any
# 1450    b Services
# 1451    nd queue l
# 1452    9ea231efff
# 1453    M:SS UTC):
# 1454    ng":"","fr
# 1455    -services/
# 1456    x86_64-gp2
# 1457    an you ple
# 1458    -services/
# 1459    -services/
# 1460    rresponden
# 1461    -services/
# 1462    help on it
# 1463    amazon.com
# 1464    scheduled"
# 1465    "MESSAGE",
# 1466    b Services
# 1467    b Services
# 1468     TusharbP.
# 1469    and Amazon
# 1470    .13.38.179
# 1471    nd. In mea
# 1472    formation
# 1473    d on the s
# 1474    nce ID(s):
# 1475    "","from":
# 1476    nce ID(s):
# 1477    700947}},{
# 1478    connecting
# 1479    n. anythin
# 1480    b Services
# 1481    b Services
# 1482    b Services
# 1483    f you have
# 1484    , Suhas S.
# 1485    M:SS UTC):
# 1486    ge the pas
# 1487    ==========
# 1488    ort-HMD-No
# 1489    -services/
# 1490    instances
# 1491     forcefull
# 1492     increase?
# 1493    he way for
# 1494    b Services
# 1495    -services/
# 1496    8879719949
# 1497    b Services
# 1498    b Services
# 1499    ces: https
# 1500    b Services
# 1501    -services/
# 1502    b Services
# 1503    used issue
# 1504     we reboot
# 1505    8432fb943d
# 1506    0282459982
# 1507    ssistance.
# 1508    ead. Be sa
# 1509    creenshot.
# 1510    5610869}},
# 1511    b Services
# 1512            Hi
# 1513    t":{"userN
# 1514    nce ID(s):
# 1515    test/userg
# 1516    ts... Done
# 1517    nstance ha
# 1518    e summery.
# 1519    321850}}]}
# 1520            hi
# 1521    ,{"action"
# 1522    a increase
# 1523    and Amazon
# 1524    -services/
# 1525    ap done: 1
# 1526    41dff7d9b2
# 1527    , Faijal T
# 1528    and Amazon
# 1529    and Amazon
# 1530    ards, Ajay
# 1531     http://aw
# 1532    t from an
# 1533    ployment.
# 1534    ort-HMD-No
# 1535    ort-HMD-No
# 1536    -services/
# 1537    b Services
# 1538    56c0321ecd
# 1539    t/UserGuid
# 1540    se do feel
# 1541    ort-HMD-No
# 1542    ort-HMD-No
# 1543    ort-HMD-No
# 1544    ort-HMD-No
# 1545    b Services
# 1546    a/sa15 # s
# 1547    ort-HMD-No
# 1548    b Services
# 1549    ort-HMD-No
# 1550    ort-HMD-No
# 1551    Mangaonkar
# 1552    ","data":{
# 1553    ort-HMD-No
# 1554    nce within
# 1555    ort-HMD-No
# 1556    12b8b9b2c9
# 1557    and Amazon
# 1558    -services/
# 1559    ort-HMD-No
# 1560    b Services
# 1561    ort-HMD-No
# 1562    7e2330a1d3
# 1563    ort-HMD-No
# 1564    ort-HMD-No
# 1565    b Services
# 1566    s, but ple
# 1567    ort-HMD-No
# 1568    ort-HMD-No
# 1569    ort-HMD-No
# 1570    b Services
# 1571    ort-HMD-No
# 1572    b Services
# 1573    ort-HMD-No
# 1574    ort-HMD-No
# 1575    b Services
# 1576    ort-HMD-No
# 1577    ort-HMD-No
# 1578    f53cc5bf).
# 1579    },{"action
# 1580     instance
# 1581    immachalam
# 1582    -services/
# 1583    b Services
# 1584    18dfc2a290
# 1585    nnect chat
# 1586    agent","di
# 1587    ort-HMD-No
# 1588    nce ID(s):
# 1589    "text":"Fr
# 1590    isbank.com
# 1591    ort-HMD-No
# 1592    ==========
# 1593     instance.
# 1594    sV2:graph=
# 1595    3633391&la
# 1596    ase, pleas
# 1597    ort-HMD-No
# 1598    b Services
# 1599     the time
# 1600    1cbf03f00b
# 1601    rds, Vinay
# 1602    6903341&la
# 1603     the same.
# 1604    -services/
# 1605    ort-HMD-No
# 1606    g/  AWS Ma
# 1607    b Services
# 1608    b Services
# 1609    ort-HMD-No
# 1610    ovide with
# 1611    b Services
# 1612    b Services
# 1613    ----------
# 1614    est ID(s):
# 1615    am","lang"
# 1616    ssistance.
# 1617    ort-HMD-No
# 1618    -services/
# 1619    ort-HMD-No
# 1620    nce ID(s):
# 1621    ular type.
# 1622    azon.com/s
# 1623    M:SS UTC):
# 1624    oing good
# 1625    b Services
# 1626    b Services
# 1627    ==========
# 1628    b Services
# 1629    ort-HMD-No
# 1630    M:SS UTC):
# 1631    e case ","
# 1632    ace period
# 1633    bdul Imra.
# 1634    rds, Vinay
# 1635    nce ID(s):
# 1636    b Services
# 1637    ser/.Xclie
# 1638    in docs...
# 1639    ou need he
# 1640    baf10a56bf
# 1641    E","data":
# 1642    not match
# 1643    25630d1485
# 1644    connect...
# 1645    text":"I a
# 1646    and Amazon
# 1647    -services/
# 1648    b Services
# 1649    ease share
# 1650    ort-HMD-No
# 1651    nce ID(s):
# 1652    interface.
# 1653     the insta
# 1654    b Services
# 1655    b Services
# 1656    e and that
# 1657    ondence. E
# 1658    th this...
# 1659    ou've been
# 1660    -services/
# 1661    ed we were
# 1662    b Services
# 1663    help asap!
# 1664    cat /etc/f
# 1665    f44232e05a
# 1666    me you fac
# 1667    8462c6990f
# 1668    MESSAGE","
# 1669    ssistance.
# 1670    a4157ae88f
# 1671    and Amazon
# 1672    nce ID(s):
# 1673    ","lang":"
# 1674     same box.
# 1675    ort-HMD-No
# 1676    5227476596
# 1677    b Services
# 1678    his issue.
# 1679    v/xvda2\n"
# 1680    k to us.
# 1681    terrupted.
# 1682    his issue.
# 1683    ":"MESSAGE
# 1684    -services/
# 1685    d stay saf
# 1686    -services/
# 1687    tacked~fal
# 1688    9920341992
# 1689    -services/
# 1690    setfacl" c
# 1691    e with ssh
# 1692    743684}}]}
# 1693    e with ssh
# 1694    2020 from
# 1695    e with ssh
# 1696    Id":"1","s
# 1697    ort-HMD-No
# 1698    6bb6e35027
# 1699    919670}}]}
# 1700    -services/
# 1701    ort-HMD-No
# 1702    . Retrying
# 1703    ng issues
# 1704    er as we d
# 1705    8fee794ba1
# 1706    out you?",
# 1707    b Services
# 1708    e performa
# 1709    b Services
# 1710    t us again
# 1711    rminates t
# 1712    8759554895
# 1713    on issues.
# 1714    SAGE","dat
# 1715    ort-HMD-No
# 1716    -services/
# 1717    use Firefo
# 1718    ng Officer
# 1719    b Services
# 1720    ort-HMD-No
# 1721    -services/
# 1722    i-020a28e6
# 1723    ang":"","f
# 1724    ge)}  Note
# 1725    -services/
# 1726    r using th
# 1727    ort-HMD-No
# 1728    452d9df4b
# 1729    other reas
# 1730    l: [16689.
# 1731    -services/
# 1732    ort-HMD-No
# 1733     solution.
# 1734    ing lambda
# 1735    okay","lan
# 1736    0fe1e0d5a7
# 1737    "from":"9"
# 1738    erminate a
# 1739    -services/
# 1740    ort-HMD-No
# 1741    ing resour
# 1742    equired...
# 1743    9619573314
# 1744    b Services
# 1745    ort-HMD-No
# 1746    ort-HMD-No
# 1747    b Services
# 1748    ort-HMD-No
# 1749    ttps://aws
# 1750    tall%20it.
# 1751    Check now.
# 1752    b Services
# 1753    ort-HMD-No
# 1754    b Services
# 1755    ort-HMD-No
# 1756    PowerShell
# 1757    ort-HMD-No
# 1758    M:SS UTC):
# 1759    "from":"2"
# 1760    M:SS UTC):
# 1761    967540}}]}
# 1762    lease help
# 1763    "data":{"p
# 1764     port on w
# 1765     this end?
# 1766    source ins
# 1767    -services/
# 1768    b Services
# 1769    e474b9c498
# 1770    console lo
# 1771    2 instance
# 1772    and Amazon
# 1773    ort-HMD-No
# 1774    b Services
# 1775     close the
# 1776    k packet I
# 1777    -services/
# 1778    espondence
# 1779    -services/
# 1780    46bc%22%7d
# 1781    nce ID(s):
# 1782    :"1","time
# 1783    ile of ssm
# 1784    r log file
# 1785    b3aa7937ff
# 1786    ,{"action"
# 1787            Hi
# 1788    837245}}]}
# 1789    creenShare
# 1790    ort-HMD-No
# 1791    ement.   I
# 1792    utes. You
# 1793    n SG also.
# 1794    ang":"","f
# 1795    References
# 1796    s.amazon.c
# 1797    ort-HMD-No
# 1798    ort-HMD-No
# 1799    b Services
# 1800    ort-HMD-No
# 1801    ort-HMD-No
# 1802    -services/
# 1803    s observed
# 1804    o connect.
# 1805    and Amazon
# 1806    -services/
# 1807    ==========
# 1808    -services/
# 1809    b Services
# 1810    ort-HMD-No
# 1811    ort-HMD-No
# 1812    ort-HMD-No
# 1813    M:SS UTC):
# 1814    and Amazon
# 1815    -services/
# 1816    center/  A
# 1817     = (Get-Da
# 1818    M:SS UTC):
# 1819    -services/
# 1820    ch corresp
# 1821    ndly check
# 1822    ort-HMD-No
# 1823    ort-HMD-No
# 1824    cbdf463687
# 1825    ish Mishra
# 1826    ort-HMD-No
# 1827    ort-HMD-No
# 1828     script.
# 1829    b Services
# 1830    5e9bbc22d0
# 1831    9d790e440c
# 1832     on ec2 se
# 1833    -services/
# 1834    ity basis.
# 1835    b Services
# 1836    b Services
# 1837    rom your A
# 1838    ration. It
# 1839    b Services
# 1840    b Services
# 1841    ort-HMD-No
# 1842    nce ID(s):
# 1843    can you he
# 1844    ss that ca
# 1845    ort-HMD-No
# 1846    b Services
# 1847    share your
# 1848    ..  Thanks
# 1849    b Services
# 1850    b Services
# 1851    pp server.
# 1852    -services/
# 1853    ontact us
# 1854    be63f74f2d
# 1855    ackage int
# 1856    ort-HMD-No
# 1857    nks, Mitch
# 1858    es  ======
# 1859    and reboot
# 1860    417664}}]}
# 1861    ssistance.
# 1862    2e9e4fccc0
# 1863    ":16037558
# 1864    eturn "Tcp
# 1865    ssistance.
# 1866    e stars in
# 1867    ss failed.
# 1868    b Services
# 1869    M:SS UTC):
# 1870    ... Imran.
# 1871    b Services
# 1872    providing
# 1873    e metrics.
# 1874    b Services
# 1875    73826a9ba3
# 1876     problems
# 1877    M:SS UTC):
# 1878    0380105423
# 1879    Mangaonkar
# 1880    heck for y
# 1881     out soon.
# 1882    ==========
# 1883     the same.
# 1884    ,{"action"
# 1885    ons, I sus
# 1886
# 1887    ort-HMD-No
# 1888    b Services
# 1889    ed intent.
# 1890     at the en
# 1891     executed.
# 1892    g the Clou
# 1893     the newly
# 1894    ?  Thanks.
# 1895    b Services
# 1896    6e8f442c33
# 1897    n":"MESSAG
# 1898    ote, this
# 1899    e99b955cd3
# 1900    ing URL: h
# 1901      To share
# 1902    ach[5] the
# 1903    lease help
# 1904    rred\nsnap
# 1905    r. Manish.
# 1906    his, pleas
# 1907    c0ed3b5639
# 1908    se allow m
# 1909    ssistance.
# 1910    ort-HMD-No
# 1911    ort-HMD-No
# 1912    ort-HMD-No
# 1913    -services/
# 1914    b Services
# 1915    and your u
# 1916    nce ID(s):
# 1917    899047}},{
# 1918    eeb96d99a7
# 1919    b Services
# 1920    ll me back
# 1921     Revanth S
# 1922    ,"from":"1
# 1923    imit ASAP.
# 1924    -services/
# 1925    e reason .
# 1926    :"sure","l
# 1927     Revanth S
# 1928     10.23.53.
# 1929    b Services
# 1930    ort Center
# 1931    viewed the
# 1932    in Parker!
# 1933    ort-HMD-No
# 1934    eck those
# 1935    com/traini
# 1936    b Services
# 1937    ort-HMD-No
# 1938    f150e2e672
# 1939    and Amazon
# 1940    -services/
# 1941    ort-HMD-No
# 1942    -services/
# 1943    d8dcf18f65
# 1944    ,"data":{"
# 1945    se connect
# 1946    :{"userNam
# 1947    ort-HMD-No
# 1948    attachmemt
# 1949    b Services
# 1950     Revanth S
# 1951     AWS Cost
# 1952    , please l
# 1953    ort-HMD-No
# 1954    6cc0df911d
# 1955    ort-HMD-No
# 1956    not accept
# 1957    M:SS UTC):
# 1958    and Amazon
# 1959    nderful da
# 1960    w generati
# 1961    ort-HMD-No
# 1962    fc9d15ea95
# 1963    :"1","time
# 1964    lease help
# 1965    ort-HMD-No
# 1966    nd "servic
# 1967    0.00
# 1968    4dbfb0afca
# 1969     the case.
# 1970    ssistance.
# 1971    -services/
# 1972    M:SS UTC):
# 1973    ating vuln
# 1974    n which yo
# 1975    ne. Thanks
# 1976    ort-HMD-No
# 1977    de591fbf21
# 1978    "action":"
# 1979    ort-HMD-No
# 1980    key alone.
# 1981    mp":160404
# 1982    connecting
# 1983    "timestamp
# 1984    om my end.
# 1985    ","from":"
# 1986    e log file
# 1987    b Services
# 1988    -services/
# 1989    t rsyslog
# 1990    M:SS UTC):
# 1991    tion issue
# 1992    se call me
# 1993    and Amazon
# 1994    st> tag. F
# 1995    b Services
# 1996    b Services
# 1997    151a1604d0
# 1998    seful. As
# 1999    M:SS UTC):
# 2000    uirement .
# 2001    -services/
# 2002     and which
# 2003    on.com/pre
# 2004    ort-HMD-No
# 2005    and Amazon
# 2006    ort-HMD-No
# 2007     Revanth S
# 2008    -services/
# 2009    5e98d99a2f
# 2010    009447}}]}
# 2011    //blog.e-z
# 2012    ying again
# 2013          Chat
# 2014    nce the ch
# 2015    a97caf8e4e
# 2016    307464}},{
# 2017     activated
# 2018    rom":"1","
# 2019    -services/
# 2020    ort-HMD-No
# 2021    -services/
# 2022    title.  In
# 2023    ort-HMD-No
# 2024    b Services
# 2025    nt copy AM
# 2026    ort-HMD-No
# 2027    7117048ff5
# 2028    ssistance.
# 2029    is corresp
# 2030    M:SS UTC):
# 2031    -services/
# 2032    M:SS UTC):
# 2033    ":"allow m
# 2034    ==========
# 2035    -services/
# 2036    ort-HMD-No
# 2037    ort-HMD-No
# 2038    ort-HMD-No
# 2039    ort-HMD-No
# 2040    b Services
# 2041    M:SS UTC):
# 2042    ction":"ME
# 2043    nt time.
# 2044    ort-HMD-No
# 2045    b Services
# 2046    t do that?
# 2047    ":{"text":
# 2048     cannot ac
# 2049    tput table
# 2050    ssistance.
# 2051    y mistake.
# 2052    imestamp":
# 2053    y before A
# 2054    and Amazon
# 2055     was sent
# 2056    M:SS UTC):
# 2057    tion asap.
# 2058    -services/
# 2059    M:SS UTC):
# 2060    and Amazon
# 2061    b Services
# 2062    b Services
# 2063    /docs.aws.
# 2064    :  ELB(s):
# 2065    ience or c
# 2066    ort-HMD-No
# 2067    c6cf62e838
# 2068    us on this
# 2069     it is not
# 2070    ort-HMD-No
# 2071    ort-HMD-No
# 2072    -services/
# 2073    h tickets.
# 2074    M:SS UTC):
# 2075    using SSH.
# 2076    and Amazon
# 2077    llowing UR
# 2078    -services/
# 2079    b Services
# 2080     commands.
# 2081    ort-HMD-No
# 2082    s://consol
# 2083    0.0.0.0/0'
# 2084    nstance no
# 2085    -services/
# 2086    -services/
# 2087    r the call
# 2088    r the call
# 2089    and Amazon
# 2090    -services/
# 2091    7ed32bb512
# 2092    ","from":"
# 2093    2ubuntu2.6
# 2094    ssist.  Th
# 2095    n quickly.
# 2096    fab10012d9
# 2097    om":"1","t
# 2098    -services/
# 2099    epleted th
# 2100    work issue
# 2101    "data":{"t
# 2102    -placement
# 2103    M:SS UTC):
# 2104    :{"text":"
# 2105    ort-HMD-No
# 2106    ort-HMD-No
# 2107    6e2aa1b81a
# 2108    ata":{"tex
# 2109    ler output
# 2110    M:SS UTC):
# 2111    75923}},{"
# 2112    s Parekodi
# 2113    s Parekodi
# 2114    -services/
# 2115    s Parekodi
# 2116    s Parekodi
# 2117    -services/
# 2118    nce 4 sept
# 2119    nstance.",
# 2120    rver-ver15
# 2121    ks Aashish
# 2122    ion":"MESS
# 2123    act us aga
# 2124    e.etl file
# 2125    -services/
# 2126    -services/
# 2127     your expe
# 2128    ssistance.
# 2129    orward wou
# 2130    imit ASAP?
# 2131    signment).
# 2132    management
# 2133    8218902503
# 2134    "","from":
# 2135    8aa46867d8
# 2136    wn","lang"
# 2137    il was sen
# 2138    p.  # e2fs
# 2139    1&language
# Name: comm_body, dtype: object

# %% [markdown]
# Dictionaries seem to be incomplete problem so, ignoring them

# %% [markdown]
# ---

# %% [markdown]
# # Ignoring the dictionaries

# %% [markdown]
# Total rows with dictionary are : 2131

# %%
data = data.loc[2131:].copy().reset_index(drop=True)

# %%
print(data.shape)
data.head()
# Out:
# (12103, 11)
#       case_id                    customer_name  \
# 0  8415574821                          Genpact
# 1  7938887601  Axiata Digital Services Sdn Bhd
# 2  7938887601  Axiata Digital Services Sdn Bhd
# 3  7938887601  Axiata Digital Services Sdn Bhd
# 4  7745171561         Tata Communications Ltd.
#
#                                service case_billing_region  \
# 0  Elastic Compute Cloud (EC2 - Linux)                APAC
# 1  Elastic Compute Cloud (EC2 - Linux)                APAC
# 2  Elastic Compute Cloud (EC2 - Linux)                APAC
# 3  Elastic Compute Cloud (EC2 - Linux)                APAC
# 4  Elastic Compute Cloud (EC2 - Linux)                APAC
#
#   customer_billing_country_name comm_owner_agent_login  \
# 0                         INDIA               gupmanav
# 1                         INDIA                arizona
# 2                         INDIA                 wadhwh
# 3                         INDIA                 wadhwh
# 4                         INDIA                arizona
#
#                                            comm_body case_creation_cal_date  \
# 0  Dear Team,  I am facing issue in one of the EC...          6/2/2021 0:00
# 1  Hello,  We haven't heard back from you regardi...          2/1/2021 0:00
# 2  while checking the instance the above instance...          2/1/2021 0:00
# 3  Hello,   We have looked into the issue and we ...          2/1/2021 0:00
# 4  Please let us know if we helped resolve your i...        12/16/2020 0:00
#
#      comm_date_utc      comm_subject  case_severity
# 0    6/2/2021 0:00    1/2 checks EC2              4
# 1    2/9/2021 0:00  1/2 status check              4
# 2    2/1/2021 0:00  1/2 status check              4
# 3    2/9/2021 0:00  1/2 status check              4
# 4  12/26/2020 0:00  2/2 check failed              3

# %% [markdown]
# ---

# %% [markdown]
# # Ignoring Nan in Comm Body

# %%
data = data.loc[~data.comm_body.isnull()]

# %% [markdown]
# ---

# %% [markdown]
# # Extracting URLs

# %%
print(data.shape)
data.head()
# Out:
# (12099, 11)
#       case_id                    customer_name  \
# 0  8415574821                          Genpact
# 1  7938887601  Axiata Digital Services Sdn Bhd
# 2  7938887601  Axiata Digital Services Sdn Bhd
# 3  7938887601  Axiata Digital Services Sdn Bhd
# 4  7745171561         Tata Communications Ltd.
#
#                                service case_billing_region  \
# 0  Elastic Compute Cloud (EC2 - Linux)                APAC
# 1  Elastic Compute Cloud (EC2 - Linux)                APAC
# 2  Elastic Compute Cloud (EC2 - Linux)                APAC
# 3  Elastic Compute Cloud (EC2 - Linux)                APAC
# 4  Elastic Compute Cloud (EC2 - Linux)                APAC
#
#   customer_billing_country_name comm_owner_agent_login  \
# 0                         INDIA               gupmanav
# 1                         INDIA                arizona
# 2                         INDIA                 wadhwh
# 3                         INDIA                 wadhwh
# 4                         INDIA                arizona
#
#                                            comm_body case_creation_cal_date  \
# 0  Dear Team,  I am facing issue in one of the EC...          6/2/2021 0:00
# 1  Hello,  We haven't heard back from you regardi...          2/1/2021 0:00
# 2  while checking the instance the above instance...          2/1/2021 0:00
# 3  Hello,   We have looked into the issue and we ...          2/1/2021 0:00
# 4  Please let us know if we helped resolve your i...        12/16/2020 0:00
#
#      comm_date_utc      comm_subject  case_severity
# 0    6/2/2021 0:00    1/2 checks EC2              4
# 1    2/9/2021 0:00  1/2 status check              4
# 2    2/1/2021 0:00  1/2 status check              4
# 3    2/9/2021 0:00  1/2 status check              4
# 4  12/26/2020 0:00  2/2 check failed              3

# %%
extractor = URLExtract()
def extract_url_from_data(x):
    try:
        url = extractor.find_urls(x)
        if len(url) > 0:
            return ','.join(url)
        else:
            return None
    except:
        print(x)

# %%
# comm_body = data.comm_body.values
# urls = []
# for d in comm_body:
#     urls.append(extract_url_from_data(d))

# %%
data['urls'] = data.comm_body.apply(lambda x: extract_url_from_data(x))

data['urls'].value_counts(dropna=False)
# Out:
# NaN                                                                                                                                                                                                                                                                                                                                                                                     5181
# Viatris.com                                                                                                                                                                                                                                                                                                                                                                                7
# 0.0.0.0/0                                                                                                                                                                                                                                                                                                                                                                                  6
# https://console.aws.amazon.com/support/home#/case/?displayId=7938558601&language=en,https://aws.amazon.com/premiumsupport/knowledge-center/,https://docs.aws.amazon.com/,https://aws.amazon.com/aws-cost-management/,http://aws.amazon.com/training/,https://aws.amazon.com/managed-services/                                                                                              6
# https://console.aws.amazon.com/support/home#/case/?displayId=7546654261&language=en,https://aws.amazon.com/premiumsupport/knowledge-center/,https://docs.aws.amazon.com/,https://aws.amazon.com/aws-cost-management/,http://aws.amazon.com/training/,https://aws.amazon.com/managed-services/                                                                                              6
#                                                                                                                                                                                                                                                                                                                                                                                         ...
# 172.27.45.179                                                                                                                                                                                                                                                                                                                                                                              1
# https://docs.aws.amazon.com/AWSEC2/latest/UserGuide/ec2-capacity-reservations.html                                                                                                                                                                                                                                                                                                         1
# https://console.aws.amazon.com/support/feedback?eventId=8113684091&language=en&questionnaireId=Support-HMD-Yes,https://console.aws.amazon.com/support/feedback?eventId=8113684091&language=en&questionnaireId=Support-HMD-No                                                                                                                                                               1
# https://console.aws.amazon.com/support/feedback?eventId=7344724061&language=en&questionnaireId=Support-HMD-Yes,https://console.aws.amazon.com/support/feedback?eventId=7344724061&language=en&questionnaireId=Support-HMD-No                                                                                                                                                               1
# https://aws.amazon.com/premiumsupport/knowledge-center/troubleshoot-iam-policy-issues/,https://console.aws.amazon.com/support/home#/case/?displayId=8321821041&language=en,https://aws.amazon.com/premiumsupport/knowledge-center/,https://docs.aws.amazon.com/,https://aws.amazon.com/aws-cost-management/,http://aws.amazon.com/training/,https://aws.amazon.com/managed-services/       1
# Name: urls, Length: 6560, dtype: int64

# %%
def remove_urls(row):
    if not pd.isnull(row['urls']):
        urls = row['urls'].split(',')
        d = row['comm_body'] 
        for u in urls:
            d = d.replace(u.strip(), ' ')
        return d
    return row['comm_body']

# %%
data['1_url_cleaned_comm_body'] = data.apply(lambda _row: remove_urls(_row), axis=1)
# data['1_url_cleaned_comm_body'].head(5).values

# %% [markdown]
# ## Removing words which do not mean anything

# %%
sentences = data['1_url_cleaned_comm_body'].unique()
words = dict()
for sent in sentences:
    sent = sent.lower().replace('\n', ' ').replace('\t', ' ')
    sent_tokens = sent_tokenize(sent)
    for s_token in sent_tokens:
        tokens = word_tokenize(s_token)
        for t in tokens:
            if t in words:
                words[t] += 1
            else:
                words[t] = 1

# %%
print(len(words))
# Out:
# 35375

# %% [markdown]
# ---
#
#
# words which are of the pattern "i-(0-9)words"

# %%
words_to_remove = []
for w in words:
    match = re.search('i-[0-9]\w+', w)
    if match:
        if words[w] > 5:
            print(match.string, words[w])
        words_to_remove.append(match.string)
# Out:
# i-04b6c49211713957a 7
# i-059d1a1009fd35d73 7
# i-09c88615ffc5b0ca6 15
# i-0f5132ec4afad9364 13
# i-09b0cdbecf72224cb 6
# i-06983d10fcba71498 6
# i-005f131e3c567648b 12
# i-0c27554a82026ead7 7
# i-0ef724ab7fc1b2e69 9
# i-0d73994dcdb72a38d 12
# i-0a5f16475cb4aaf5c 9
# i-03a20a0076d31e514 6
# i-0beec32116a2693e8 6
# i-0c1734712b8b9b2c9 7
# i-09e46ba27318d150e 8
# i-08363e917874c7560 6
# i-08d5d95b040cc9d89 13
# i-09e79f6f13979da13 12
# i-0ca54f7d1809fb59a 6
# i-0b085da52bf68d27b 7
# i-0a93406eb813b0a4b 8
# i-08128d8eefacb10ca 6
# i-067f813183a8f516c 6
# i-0ce313a417b1ee1e2 13
# i-06e7dcd54f70238b1 9
# i-0e2b8f26fdb3e948b 6
# i-0056b930a5d56f608 10
# i-07d1b96631391ddfb 7
# i-0f7b2e7735aa0387e 8
# i-0ebeb8802717cae72 9
# i-0cb2c3f9541efc2aa 7
# i-0ce3a60de46db7522 7
# i-042838ac3c4e32ddc 9
# i-04699d80622ea743c 8
# i-0269a0b0823d403b9 6
# i-0812e232104f2f48f 8
# i-0cd325021dfc8e4d6 7
# i-006fb0e6eca439bd2 13
# i-0b7a8ea755207a2b3 8
# i-0c68498b654180b03 8
# i-0b525f5106eebb334 8
# i-052626c80f61de1eb 7
# i-064121555b548146a 6
# i-02b8705f8ff02bb6c 8
# i-0cf3cdfeeaf898bb7 8
# i-04bc615e4a57639ae 8
# i-071183e46a8694159 7
# i-0e60fa85f988bcf31 7
# i-06fe232b8266db8f1 7
# i-0d6ecd7c8ee4036ac 10
# i-0df0c495603b77908 6
# i-0d4c23277fe21d744 8
# i-041c9be2a31f8a18e 6
# i-09f9b32e909101166 8
# i-0ed5e9591a400b758 7
# i-088adb17632719fec 6
# i-07ee9dac4f8a28828 6
# i-072f53c49f35745d0 6
# i-000f335c639a001a1 6
# i-0c440643fdd8e6c8e 8
# i-022b73a4ce4987398 8
# i-0dfa957e465902dc7 8
# i-0fb4fc728728e0eb7 8
# i-0e184f16e82b4882e 7
# i-0b55f947b74d1d0ab 6
# i-050b5d74c7c67ecf7 7
# i-0ad503d14f351a11c 10
# i-0acee79480715274b 8
# i-08346b19797bd22a2 12
# i-0639f7db704212259 7
# i-005369b41b2e7e010 6
# i-081c016b14485ab5e 12
# i-00db93f0c89afd55e 6
# i-0adf1ed46fe630a52 7
# i-00e514d047e12d900 6
# i-02f68db698967e505 7
# i-0abdbd4bb791c2951 7
# i-0f6b41422fcfa6c16 7
# i-0787ff675f76b3b62 6
# i-0fe5b7b1ce9ee998a 7
# i-07843388432fb943d 7
# i-0b8e6d0b9144095a1 8
# i-0fdfade6bb6e35027 6
# i-07ac67bb1272291b6 9
# i-0d6a250677712ef6f 6
# i-064b6e2c7907285fa 6
# i-0d5c1b0cb8ed4694f 6
# i-049b47ee4c4dc2b8b 7
# i-0d1dd590967ee0517 6
# ami-0d55b8cf27662650f 6
# i-082580ac3a6280508 7
# i-064b3bb887ac35de1 6
# i-019ee715af2577e41 10
# i-0a768755ad9c62f11 9
# i-0909e748e6963d128 6
# i-092769f570f82af3f 9
# i-069dcbc06d5a96e8f 8
# i-01d47480b64f0acf9 6
# i-09f75a7f14073f227 13
# i-0cbe267250c161da4 6
# i-0d8274b79c62e1e27 7
# i-088634924ef01dfa1 6
# i-03af972277e8cff14 6
# i-039f9025313cc057e 6
# i-0f75c3f85bfe618d3 6
# i-0c57253ef99829079 6
# i-030817730464a6a93 6
# i-0e64305a7cbe0d838 6
# i-05ba5590655a8ac39 6
# i-075e9c12f9af2562f 6
# i-02c44bea58e33455c 11
# i-0bb01cd89cca16354 8
# i-0798c00e07a1654c1 8
# i-0f410e643bef12b68 6
# i-08472656b8dc716e0 11
# i-01a268818381e867f 7
# i-0e749dcfc6229d282 6
# i-0408261937cb11405 8

# %%
print(len(words))
for w in words_to_remove:
    words.pop(w)
print(len(words))
# Out:
# 35375
# 32555

# %% [markdown]
# ---
#
# words which are sperated by atleast 1 ':'

# %%
words_to_remove = []
for w in words:
    match = re.search('\w+:\w+', w)
    if match:
        if words[w] > 5:
            print(match.string, words[w])
        words_to_remove.append(match.string)
# Out:
# ap-south-1:617558729962 11
# 3:30 11
# 3:00 7
# 3:20 7
# retry_handler.go:101 6
# retry_handler.go:57 9
# 00:44 17
# 19:00 7
# 5:30 11
# 00:00 14
# 03:50:12 12
# 17:00 10
# 18:30 8
# 259:1 9
# 259:2 8
# 259:0 9
# 259:3 7
# 19:37:13 7
# 15:19:36 16
# __ext4_get_inode_loc:4341 6
# 14:47:46 15
# 12:30 13
# 14:00 13
# 15:30 7
# gmt+5:30 7
# 10:30 7
# 11:30 11
# 01:00 6
# utc+5:30 15
# 14:16 27
# 13:40 8
# 11:00 8
# 00:00:00 29
# 9:30 7
# 15:00 15
# 10:00 8
# localhost:9097 6
# error:140770fc 6
# dpt:22 10
# 15:29 6
# 1:00 7
# 5:00 9
# 13:30 7
# 8:00 6
# 08:20:43 8
# 09:50:13 8
# 12:00:00 11
# 18:00 6
# 22:00 6
# 253:0 6
# 12:38:20 6
# 21:30 6
# 11:35 6
# 172.31.0.2:53 6
# 19:30 7
# 06:00 13
# 08:30 14
# 23:59 12
# 16:00 7
# 202:0 12
# 202:1 12
# 202:80 9
# 202:81 6
# file-rss:0kb 17
# 18:00:00 9
# shmem-rss:0kb 24
# 14:00:14 17
# 11:40:01 12
# 02:07:22 6
# 3:38:42 16
# 23:00 7
# 08:00 12
# 13:16:00 17
# 08:08:16 10
# 08:20 6
# 00:12:38 9
# 12:00:37 7
# 05:03:13 17
# 21:28:54 10
# uid:0 8
# 20:00 6
# 12:41:22 19
# 07:23:30 9
# 19:57:18 10
# start=09:34:20 12

# %%
print(len(words))
for w in words_to_remove:
    words.pop(w)
print(len(words))
# Out:
# 32555
# 30116

# %% [markdown]
# ---
#
# words which are sperated by atleast 2 '/'

# %%
words_to_remove = []
for w in words:
    match = re.search('\w+\/\w+\/\w+', w)
    if match:
        if words[w] > 5:
            print(match.string, words[w])
        words_to_remove.append(match.string)
# Out:
# /etc/ssh/ssh_config 12
# /opt/mssql/bin/mssql-conf 6
# /var/log/audit 9
# /var/log/messages 54
# /etc/default/grub 28
# /usr/bin/sudo 12
# /usr/bin/python 7
# 2019/12/09 11
# 2021/07/02 12
# /opt/aws/amazon-cloudwatch-agent/etc/amazon-cloudwatch-agent.json 8
# 2021/07/29 11
# /var/cache/apt/archives/nginx_1.20.0-1~xenial_amd64.deb 7
# /usr/bin/cloud-init 10
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py 13
# /usr/lib/python3/dist-packages/cloudinit/cmd/main.py 6
# /etc/ssh/sshd_config 30
# /etc/security/limits.conf 6
# /engage_mobile/rbl_user_batch/rbluserdatasync/rblsalslipsync.sh 7
# /var/log/secure 12
# 6/15/2021 6
# /shared/microfocus/cobol_40_pu10/lib 8
# /var/opt/stp/obe/obe3f/ 10
# /etc/cloud/cloud.cfg 18
# /var/log/syslog 19
# /etc/sysconfig/network-scripts/ifcfg-eth0 14
# /boot/grub2/grub.cfg 24
# /var/log/dmesg 10
# 2020/09/12 6
# /mnt/etc/fstab 6
# /var/empty/sshd 6
# /var/log/amazon/ssm/amazon-ssm-agent.log 11
# /proc/sys/kernel/hung_task_timeout_secs 7
# /usr/lib/libdl.so.2 6
# /opt/aws/amazon-cloudwatch-agent/bin/config.json 7
# /opt/aws/amazon-cloudwatch-agent/bin/amazon-cloudwatch-agent-ctl 7
# 12/15/2020 13
# /boot/grub/grub.conf 9
# ./aws/dist/lib/python3.8/config-3.8-x86_64-linux-gnu/makefile 8
# /run/systemd/generator/opt-allianz.mount 6
# /usr/bin/snap 6

# %%
print(len(words))
for w in words_to_remove:
    words.pop(w)
print(len(words))
# Out:
# 30116
# 29379

# %% [markdown]
# Note: there are words which can be of use which are seperated by just /
#
# ---
#
# words which are like patterns 'word/words/words'

# %%
words_to_remove = []
for w in words:
    match = re.search('.\/\w+\/\w+', w)
    if match:
#         if words[w] > 10:
#             print(match.string, words[w])
        print(match.string, words[w])
        words_to_remove.append(match.string)
# Out:
# '/tsa_api/copy_fares_of_version2 2
# ./lazypay_analytics/lp_mix_panel.ibd 1
# '/tmp/myfd=55 1
# ///home/containers.json 2
# '/home/containers.json 2
# '/home/ec2-user/ 1
# '/dev/disk 1
# :/home/testvm 1
# :/home/pradeep.bodlapati 1
# set-default=/boot/vmlinuz-3.10.0-957.10.1.el7.x86_64 1
# //etc/yum.repo.d/bak 1
# ~/downloads/rr-ops-uswest.pem 1
# all=/bin/bash 1
# '/bin/su 1
# 'boot_image=/boot/vmlinuz-4.4.0-1117- 1
# /tmp/spinnaker-0.repo 1
# /etc/yum.repos.d/ 1
# /etc/yum.repos.d/ 1
# downloaddir=/root/rpms/ 2
# '/dev/xvda 2
# â/dev/hugepagesâ 1
# â/dev/mqueueâ 1
# â/dev/shmâ 1
# disk=/dev/xvda 1
# '/etc/sudoers 1
# :/home/ubuntu 1
# /tmp/growpart.28805 1
# ./aws/install 1
# '/var/tmp/ 1
# '/dev/sdf 2
# '/grub2/i386-pc/increment.mod 1
# //./pipe/docker_engine 1
# '/etc/fstab 2
# libdir=/usr/lib 1
# '/dev/sdp 1
# prefix=/opt/nginx 1
# path=/home/ec2-user/.local/bin 1
# dir=/mysqlbackup/binary_logs/ 2
# set-default=/boot/vmlinuz-4.18.0-80.4.2.el8_1.x86_64 1
# meta-data=/dev/nvme1n1 1
# //bucket/backup/ 1
# '/efc/fstab 1
# '/boot/initramfs-3.10.0-1160.36.2.el7.x86_64.img 1
# '/etc/rc.local 1
# /tmp/snappy-1.1.7-d02f0031-e29b-499d-83ae-1d1617b23089-libsnappyjava.so 1
# //ad/evoc_fin_paypal_usrs_trs_rw 1
# pwd=/var/log 2
# command=/bin/grep 2

# %%
print(len(words))
for w in words_to_remove:
    words.pop(w)
print(len(words))
# Out:
# 29379
# 29331

# %% [markdown]
# ---
#
# words which are sperated by atleast 2 '-'

# %%
words_to_remove = []
for w in words:
    match = re.search('\w+-\w+-\w+', w)
    if match:
        if words[w] > 5:
            print(match.string, words[w])
#         print(match.string, words[w])
        words_to_remove.append(match.string)
# Out:
# us-west-2 26
# us-east-1 111
# eu-west-1 32
# eu-west-2 7
# ap-northeast-1 9
# yyyy-mm-dd 549
# ap-south-1 190
# 2021-02-19 7
# region=us-east-1 10
# modify-instance-metadata-options 6
# ap-southeast-1 57
# search-disabled-repos 8
# yum-config-manager 14
# 2021-02-21 8
# 2021-03-16 11
# us-east-1b 19
# +91-961-968-2411 9
# ip-10-102-113-249 17
# eu-west-1a 6
# ap-south-1c 51
# ap-south-1a 77
# ap-south-1b 44
# us-east-1a 24
# us-east-1c 8
# us-east-1f 8
# ip-10-0-0-221 8
# global-db-master-1 19
# aws-vsr-016 6
# 2021-05-30 33
# apeu-pp04-wfe01 7
# apeu-pp04-app01 7
# apeu-sp03-sch01 7
# apeu-pp04-wfe02 7
# ip-172-18-101-203 6
# gssapi-with-mic 9
# get-caller-identity 12
# modify-instance-attribute 20
# aws-vsr-032 6
# ssm-agent-worker 7
# eu-central-1 24
# eu-west-1c 8
# 2020-11-09 7
# content-transfer-encoding 34
# no-verify-ssl 13
# ap-southeast-1a 21
# decode-authorization-message 12
# prod-wedz-gtm-br-mongo-2 6
# describe-instance-information 8
# themis-ci-slave-2682ef81-8dd6-43ab-ac0c-ce7efae1da73-m5x9-3qx89 7
# ip-10-101-57-84.ap-southeast-1.compute.internal 6
# 94dd0e2b-03cc-11eb-8115-06b1f9269592 7
# 2021-02-01 26
# 2020-12-11 7
# describe-instance-type-offerings 14
# ip-10-3-11-114 12
# 2021-03-06 12
# ip-10-21-9-134 6
# us-east-2 7
# 2012-10-17 6
# ip-10-1-126-111 6
# nonprod-backend-node-insurance-v1-35-146 13
# 2021-07-09 14
# rh-amazon-rhui-client 6
# fsd-lms-rdp-sg 6
# 206-462-5569 138
# 855-552-4463 140
# up-to-date 6
# no-check-certificate 7
# \programdata\amazon\amazoncloudwatchagent\\amazon-cloudwatch-agent.json 6
# ip-x-x-x-x 10
# 2020-10-12 9
# ap-southeast-2 10
# 2020-10-03 8
# ip-172-31-10-57 11
# amazon-ssm-agent 17
# ip-172-30-5-126 17
# 2020-10-21 6
# cli-read-timeout 9
# 2020-11-08 13
# describe-iam-instance-profile-associations 7
# ip-10-20-5-164 6
# 2020-12-14 6
# x-aws-ec2-metadata-token 6
# hcplayhduk-2-zixi 20
# 2021-02-04 13
# af-south-1 9
# ip-10-23-28-39 10
# 2021-02-16 8
# 2021-03-15 7
# 2021-04-07 11
# 2021-04-12 19
# 2021-04-21 10
# 2021-04-23 16
# ip-172-31-18-98 7
# ip-172-16-150-75 9
# systemd-sysv-generator 12
# systemd-fstab-generator 12
# 2021-06-03 6
# ssm-session-worker 9
# 2021-06-30 12
# 2021-07-08 10
# 2021-07-26 6
# ip-172-31-31-143 6
# 2021-07-29 9
# 2021-08-10 9
# 2021-08-17 6
# ip-172-30-63-121.ec2.internal 7

# %%
print(len(words))
for w in words_to_remove:
    words.pop(w)
print(len(words))
# Out:
# 29331
# 27545

# %% [markdown]
# Note : there are words which can be useful and are seperated by single -
#
# ---
#
#
# words which are sperated by atleast 2 '.'

# %%
words_to_remove = []
for w in words:
    match = re.search('\w+\.\w+\.\w+', w)
    if match:
        if words[w] > 5:
            print(match.string, words[w])
#         print(match.string, words[w])
        words_to_remove.append(match.string)
# Out:
# 3.7.5 6
# 3.10.0-514.16.1. 19
# 1.14.0-0+xenial1 6
# 1.16.1-0+xenial1 6
# 5.3.18-24.64-def 8
# 4.14.198-152.320 26
# glibc-2.17-317.el7.i686 7
# 8.3.4 7
# v1.3.2.53 6
# _.errordetails.message 12
# x.x.x.x 6
# //aws.amazon.c 12
# 2.4.0 8
# 3.10.0-1160.25.1.el7.x86_64 6
# liblber-2.4.so.2 6
# 3.10.0-1127.8.2. 6
# :1.8.0_144 6

# %%
print(len(words))
for w in words_to_remove:
    words.pop(w)
print(len(words))
# Out:
# 27545
# 26746

# %% [markdown]
# Note there should be some words seperated by just 1 '.'
#
# ---
#
# matching the pattern with  "digits with words"

# %%
words_to_remove = []
for w in words:
    match = re.search('\d+', w)
    if match:
        if words[w] > 5:
            print(f"{match.string}  (count={words[w]})")
        words_to_remove.append(match.string)
# Out:
# ec2  (count=3361)
# 1.  (count=581)
# 2.  (count=542)
# 3.  (count=387)
# 4.  (count=246)
# 5.  (count=145)
# 1/2  (count=173)
# 6.  (count=89)
# 3  (count=1033)
# 72  (count=1364)
# 2/2  (count=50)
# 403  (count=40)
# 7  (count=270)
# 80  (count=107)
# 2  (count=2140)
# 256  (count=9)
# 25  (count=107)
# s3  (count=500)
# 10  (count=220)
# 16  (count=99)
# 2020  (count=154)
# -1  (count=31)
# 502  (count=10)
# tlsv1.2  (count=22)
# 0  (count=1033)
# http/1.1  (count=27)
# 26th  (count=12)
# 2021  (count=197)
# 100  (count=202)
# 1  (count=3135)
# linux2  (count=16)
# 5  (count=440)
# 6  (count=290)
# 300  (count=32)
# 60  (count=60)
# 48  (count=25)
# 22nd  (count=9)
# m5a  (count=21)
# r4  (count=33)
# 15  (count=110)
# 13th  (count=6)
# zee5  (count=6)
# t3a.xlarge  (count=12)
# 31st  (count=6)
# r5a.4xlarge  (count=7)
# +91  (count=119)
# m4  (count=58)
# c5  (count=58)
# 19  (count=34)
# 36  (count=16)
# 23  (count=48)
# 862423538905  (count=6)
# 1000  (count=36)
# 17  (count=44)
# 7.  (count=52)
# 8.  (count=41)
# 9.  (count=22)
# 5000  (count=10)
# 2017  (count=19)
# t2  (count=81)
# ec2-instance  (count=8)
# 22  (count=203)
# ec2-user  (count=115)
# debug1  (count=58)
# 47  (count=8)
# 22.  (count=18)
# m4.2xlarge  (count=14)
# r5.xlarge  (count=12)
# ec2rescue  (count=171)
# 63  (count=8)
# 504  (count=15)
# 2018.03  (count=7)
# eth1  (count=30)
# 200  (count=32)
# 89  (count=16)
# imdsv2  (count=33)
# 51  (count=22)
# w1102  (count=15)
# 767  (count=15)
# 30s  (count=21)
# m5.4xlarge  (count=6)
# x86_64  (count=81)
# 12  (count=107)
# 64-bit  (count=26)
# 33  (count=7)
# 11  (count=79)
# 0.00  (count=425)
# nvme1n1  (count=25)
# nvme2n1  (count=13)
# nvme3n1  (count=6)
# 0.01  (count=10)
# nvme0n1  (count=19)
# 8  (count=281)
# 6.10  (count=12)
# +1  (count=282)
# 30  (count=121)
# boto3  (count=29)
# 'ec2  (count=8)
# 200gb  (count=7)
# ext4  (count=72)
# 2pm  (count=7)
# 28  (count=46)
# 14  (count=63)
# 4  (count=640)
# 18  (count=63)
# 21  (count=40)
# 0/2  (count=7)
# c4.large  (count=18)
# t3.medium  (count=22)
# 5pm  (count=10)
# 12pm  (count=9)
# 4th  (count=20)
# 70  (count=11)
# 85  (count=9)
# 2019  (count=55)
# m5.8xlarge  (count=10)
# m5a.8xlarge  (count=9)
# 2.5  (count=6)
# gp2  (count=99)
# io2  (count=21)
# 3.4  (count=7)
# 2000  (count=23)
# c5.4xlarge  (count=16)
# c4.4xlarge  (count=6)
# 5xx  (count=13)
# 3389  (count=52)
# rhel8  (count=12)
# 04  (count=16)
# gmt+0530  (count=18)
# 20  (count=156)
# gpgcheck=1  (count=14)
# enabled=0  (count=10)
# +918329213520  (count=18)
# 2.0  (count=10)
# 7758958444  (count=6)
# m5.2xlarge  (count=16)
# 3389.  (count=6)
# m5.xlarge  (count=30)
# t2.micro  (count=31)
# 33mdepend  (count=23)
# 0m  (count=52)
# +0000  (count=21)
# 32m  (count=7)
# 31mfailed  (count=6)
# 18.04  (count=27)
# 100gb  (count=10)
# c5.large  (count=11)
# 14.04  (count=13)
# 15-20  (count=6)
# rohan3.sawant  (count=10)
# 0.0  (count=135)
# 86_64/os  (count=6)
# 2016  (count=104)
# gp3  (count=65)
# t3a.large  (count=6)
# 29  (count=53)
# 2965  (count=23)
# 53  (count=24)
# amd64  (count=38)
# 404  (count=22)
# i0529  (count=6)
# 62  (count=9)
# 77  (count=9)
# ec2metadata  (count=7)
# t3a.2xlarge  (count=12)
# c5a.4xlarge  (count=15)
# 443  (count=135)
# nvme0n1p1  (count=32)
# m5  (count=86)
# 24x7  (count=7)
# 500gb  (count=6)
# 2nd  (count=39)
# 1st  (count=26)
# 90  (count=58)
# 155852686413  (count=14)
# ipv4  (count=57)
# resize2fs  (count=35)
# /dev/nvme0n1p1  (count=19)
# c6g  (count=10)
# m4.4xlarge  (count=9)
# r4.4xlarge  (count=24)
# r5.4xlarge  (count=18)
# 32  (count=44)
# r4.8xlarge  (count=18)
# r5.8xlarge  (count=14)
# c5.9xlarge  (count=7)
# c4.8xlarge  (count=6)
# 150  (count=12)
# 128  (count=27)
# 3rd  (count=63)
# 2012  (count=89)
# al2  (count=6)
# c5.xlarge  (count=13)
# 99  (count=12)
# 50  (count=41)
# policy-0b9eb78c7de4f6d78  (count=7)
# 13  (count=39)
# :ec2  (count=9)
# 443.  (count=14)
# \windows\system32  (count=7)
# m4.large  (count=14)
# c5a.xlarge  (count=15)
# c4.xlarge  (count=11)
# 55  (count=6)
# 500  (count=31)
# 1500  (count=15)
# 8879719949  (count=24)
# debug2  (count=7)
# 1.2  (count=17)
# 1.0  (count=88)
# 8g  (count=12)
# /dev/nvme1n1  (count=34)
# /dev/nvme2n1  (count=22)
# /dev/nvme0n1  (count=21)
# 7th  (count=11)
# 30th  (count=6)
# 5.30  (count=6)
# 5th  (count=16)
# 6th  (count=9)
# 8th  (count=12)
# c4  (count=26)
# amazonec2  (count=12)
# 400  (count=22)
# db2  (count=12)
# ah00898  (count=11)
# ec2-classic  (count=13)
# ext4-fs  (count=53)
# 0x0010  (count=20)
# 0x0400  (count=7)
# dome9  (count=9)
# m6g  (count=12)
# 18th  (count=9)
# r4.2xlarge  (count=7)
# 20.04  (count=10)
# 07  (count=14)
# 1.08  (count=13)
# 3-4  (count=7)
# 10th  (count=10)
# c5.2xlarge  (count=20)
# c5a.2xlarge  (count=11)
# 30001  (count=6)
# 1433  (count=8)
# 26  (count=18)
# 58  (count=11)
# r5.2xlarge  (count=19)
# sp3  (count=11)
# sp2  (count=7)
# r5  (count=55)
# r5a  (count=8)
# 9000  (count=11)
# i3.large  (count=8)
# dev259-0  (count=14)
# 9  (count=140)
# x1.32xlarge  (count=10)
# i3  (count=8)
# 27  (count=37)
# 24  (count=80)
# 38  (count=6)
# php56  (count=11)
# 9th  (count=16)
# 2020.  (count=18)
# 2tb  (count=22)
# 3000  (count=39)
# m5.large  (count=19)
# awsdrerpapp01  (count=11)
# 7.9  (count=18)
# 31  (count=23)
# 7.7  (count=8)
# 27017  (count=9)
# 1127  (count=7)
# 45  (count=16)
# 101  (count=10)
# datasourceec2.py  (count=7)
# 52  (count=6)
# 16th  (count=17)
# t2.xlarge  (count=14)
# ttys0  (count=7)
# 2326  (count=21)
# 2569  (count=7)
# r4.xlarge  (count=17)
# 16.04  (count=28)
# r5a.xlarge  (count=16)
# 2008  (count=72)
# r2  (count=108)
# 25th  (count=11)
# charset=utf-8  (count=11)
# r5a.2xlarge  (count=13)
# m4.16xlarge  (count=9)
# r6g.8xlarge  (count=8)
# 34  (count=10)
# eth0  (count=120)
# s0  (count=6)
# 302  (count=6)
# 2048  (count=8)
# nvme6  (count=19)
# 35  (count=9)
# 56  (count=12)
# c5a  (count=17)
# 7.8  (count=20)
# 9920341992  (count=7)
# 120  (count=30)
# g4dn  (count=7)
# 01  (count=41)
# 361474736119  (count=10)
# pm2  (count=12)
# credentials=basesystem_module_x86_64  (count=6)
# ipv6  (count=20)
# 522  (count=19)
# amzn2-core  (count=8)
# 3.7  (count=7)
# 3.0  (count=9)
# c5a.8xlarge  (count=9)
# m5a.2xlarge  (count=13)
# t2.large  (count=13)
# 5666  (count=7)
# 15th  (count=10)
# aarch64  (count=7)
# i686  (count=7)
# shim-x64  (count=16)
# 7bit  (count=34)
# 755  (count=31)
# 700  (count=13)
# 600  (count=18)
# 19th  (count=15)
# vol-08f67c5a901ac5d27  (count=6)
# m4.xlarge  (count=19)
# hslpabsoa4  (count=6)
# 255  (count=8)
# 900  (count=7)
# 37  (count=8)
# 14th  (count=21)
# t3  (count=63)
# t3a  (count=14)
# 7.6  (count=10)
# python2  (count=11)
# 1.1  (count=11)
# r4.16xlarge  (count=8)
# 32-bit  (count=14)
# 64  (count=22)
# l2  (count=6)
# 42  (count=9)
# 31m*  (count=18)
# 0m  (count=9)
# 31m*  (count=8)
# \programdata\amazon\ec2-windows\launch\scripts\initializeinstance.ps1  (count=12)
# 2012r2  (count=12)
# 2019.  (count=10)
# arm64  (count=10)
# 2.2  (count=8)
# t2.medium  (count=16)
# 23rd  (count=16)
# 17th  (count=11)
# 94  (count=6)
# 187g  (count=6)
# 78  (count=10)
# 82  (count=6)
# 1.9g  (count=8)
# 50g  (count=9)
# 74g  (count=14)
# /dev/nvme3n1  (count=10)
# 44  (count=15)
# 20g  (count=11)
# 29th  (count=14)
# 4096  (count=8)
# \programdata\amazon\ec2-windows\launch\module\ec2launch.psd1  (count=9)
# t3a.medium  (count=10)
# 10.  (count=18)
# c4.2xlarge  (count=16)
# io1  (count=15)
# 1a  (count=6)
# 301  (count=6)
# 1m  (count=6)
# 93  (count=9)
# 512  (count=26)
# 2500  (count=6)
# debug3  (count=10)
# 12.  (count=10)
# 2.7  (count=10)
# v2  (count=21)
# /dev/sda1  (count=40)
# 750  (count=13)
# 711  (count=6)
# ec2-linux  (count=6)
# 98  (count=15)
# pts/3  (count=6)
# pts/4  (count=6)
# /dev/xvdj2  (count=11)
# /test2  (count=6)
# 1024  (count=7)
# 83  (count=9)
# g3.8xlarge  (count=6)
# g4dn.8xlarge  (count=10)
# 03  (count=13)
# 10gb  (count=6)
# python3  (count=12)
# 8000  (count=6)
# graviton2  (count=11)
# 4416  (count=12)
# t3.micro  (count=6)
# 1.90  (count=8)
# 2021.  (count=20)
# r4.large  (count=8)
# x509  (count=7)
# net.ifnames=0  (count=15)
# 560  (count=12)
# 573  (count=19)
# sha256  (count=8)
# pip3  (count=9)
# 993  (count=14)
# kb5003646  (count=6)
# x86  (count=28)
# resrac1  (count=7)
# resrac2  (count=6)
# db1  (count=6)
# srl1a5dat03  (count=6)
# 11th  (count=6)
# 12th  (count=14)
# 9am  (count=8)
# 11am  (count=6)
# 100g  (count=9)
# /data1  (count=6)
# 1.3  (count=10)
# r5ad.large  (count=6)
# 0/1  (count=8)
# c5a.large  (count=7)
# /home/ec2-user/  (count=11)
# il-s3  (count=6)
# 11.  (count=11)
# 6480  (count=10)
# 2009  (count=10)
# 0.000000  (count=6)
# 1883458pd-cs  (count=12)
# dhcp4  (count=12)
# 68  (count=14)
# 1b  (count=8)
# i-c9664647  (count=6)
# 1am  (count=9)
# 488  (count=6)
# awsprdindusdb01  (count=35)
# ac.worker_000  (count=7)
# 0x00000080  (count=9)
# i-b6dc3037  (count=10)
# ens3  (count=13)
# \u003cnil\u003e  (count=7)
# 21st  (count=9)
# 1522  (count=6)
# h-0c95e58ec28b6838b  (count=6)
# h-0ff9c492e831bd40b  (count=6)
# 3818  (count=6)
# 40  (count=22)
# ec2config  (count=58)
# route53  (count=13)
# rsm0  (count=9)
# inas1xdbuda01  (count=15)
# 1209  (count=12)
# /dev/nvme1  (count=6)
# /dev/nvme13  (count=6)
# vol-01828229ef528aa9e  (count=6)
# t3.small  (count=6)
# 43  (count=7)
# 59  (count=9)
# 401  (count=11)
# ens5  (count=21)
# vpc-0befdda0c54fcb569  (count=6)
# 49  (count=9)
# 9958237380  (count=9)
# 32/1  (count=7)
# 34/1  (count=7)
# 103  (count=9)
# 80667  (count=7)
# 28643  (count=7)
# 1800  (count=7)
# *7  (count=27)
# 0,0  (count=7)
# /dev/xvdf1  (count=31)
# 1,2  (count=11)
# dm-2  (count=7)
# grub2-mkconfig  (count=18)
# 10gbps  (count=7)
# 95  (count=9)
# ec2launch  (count=93)
# bp-6fa54006  (count=7)
# gmt+0100  (count=7)
# 57  (count=10)
# 00h  (count=37)
# 00m  (count=14)
# 50ms  (count=11)
# 1228  (count=17)
# /disk1  (count=9)
# h.323  (count=18)
# 1.05  (count=7)
# 786  (count=11)
# 3rd-party  (count=6)
# 80.  (count=10)
# ec2setpassword  (count=8)
# a1  (count=19)
# /dev/xvdf2  (count=8)
# 1688  (count=10)
# 250  (count=8)
# order=0  (count=12)
# mems_allowed=0  (count=8)
# 5gb  (count=11)
# t2.small  (count=12)
# 97  (count=8)
# awsec2-cloneinstanceandupgradewindows  (count=8)
# 4s  (count=9)
# 3747  (count=10)
# irq4  (count=6)
# m5n  (count=8)
# 7.4  (count=14)
# gmt-0500  (count=9)
# 02  (count=21)
# 2008r2  (count=8)
# gmt+0200  (count=10)
# +0ns  (count=38)
# 0ns  (count=18)
# 1.25  (count=7)
# xvda1  (count=8)
# 10g  (count=10)
# 99.99  (count=6)
# fe80  (count=7)
# 24/7  (count=13)
# /home/ec2-user  (count=11)
# /home/ec2-user/.ssh  (count=7)
# /home/ec2-user/.ssh/authorized_keys  (count=11)
# 71  (count=7)
# 1-  (count=28)
# ssh_key1.pem  (count=7)
# install.ps1  (count=8)
# 82599  (count=13)
# /dev/xvda2  (count=7)
# 0755  (count=8)
# 1777  (count=6)
# oom_score_adj=0  (count=11)
# 3333  (count=8)
# 2016/2019  (count=6)
# 1.5  (count=12)
# c8b.device  (count=7)
# 1min  (count=39)
# 751  (count=6)
# sp1  (count=12)
# 2018  (count=7)
# 2-  (count=24)
# 3-  (count=13)
# /dev/xvda1  (count=9)
# c5n  (count=6)
# c3  (count=9)
# 3,000  (count=9)
# iperf3  (count=8)
# 84  (count=6)
# ec2instance  (count=16)
# docker0  (count=11)
# 100.0  (count=10)
# 0.3  (count=24)
# 61  (count=6)
# 08  (count=14)
# glibc.i686  (count=10)
# python2.7  (count=7)
# 0ms  (count=55)
# 2966h  (count=8)
# 04m  (count=8)
# 33.172s  (count=6)
# 644  (count=6)
# /dev/nvme1n1p1  (count=7)
# vol-05cf1153c7816b9ea  (count=6)
# 240  (count=6)
# 12-03  (count=7)
# 12-04  (count=7)
# f2  (count=7)
# 01m  (count=19)
# imdsv1  (count=12)
# v1  (count=8)
# 91  (count=6)
# 7001  (count=11)
# net\.ifnames\=0\  (count=10)
# e2fsck  (count=12)
# /mnt1  (count=9)
# a1.4xlarge  (count=7)
# 7408h  (count=13)
# 56m  (count=15)
# 5685067.878447  (count=13)
# 14.347s  (count=7)
# 0000  (count=16)
# 21600  (count=6)
# gfp_mask=0x201da  (count=7)
# 00  (count=23)
# 125  (count=14)
# 2815  (count=6)
# 1437  (count=6)
# 9492  (count=10)
# tcp6  (count=7)
# 65  (count=6)
# 74  (count=11)
# 0a  (count=9)
# ec2net  (count=18)
# 20th  (count=7)
# 598  (count=7)
# 0.  (count=6)
# 88  (count=7)
# urllib3.connectionpool  (count=7)
# 674  (count=8)
# 75  (count=8)
# 0xc1900101  (count=10)
# 0x3000d  (count=6)
# bp-6ca54005  (count=6)
# 826  (count=6)
# 3677  (count=7)
# 11276h  (count=9)
# 42m  (count=9)
# 38.118s  (count=9)
# 1080  (count=14)
# 41  (count=9)
# 1001  (count=12)
# 1103  (count=18)
# 0x7e  (count=7)
# 13.093s  (count=9)
# 5283  (count=10)
# 5548  (count=10)
# 1454  (count=8)
# python3.6  (count=7)
# 07h  (count=8)
# 8090  (count=11)
# 0x0803b6  (count=10)
# 0x000008ad  (count=9)
# 3447  (count=11)
# server-1  (count=6)
# ec2messages  (count=8)
# server-2  (count=6)
# 5.3  (count=6)
# m548052  (count=6)
# 8192  (count=9)
# 1460  (count=9)
# 0x2  (count=6)
# 64bit  (count=6)
# 1695  (count=10)
# 5869  (count=6)
# /dev/xvdb1  (count=8)
# 03/06  (count=8)
# 02/06  (count=7)
# 4922  (count=10)
# 15.2  (count=11)
# 1111  (count=17)
# x000d  (count=26)
# x000a  (count=26)
# deependra_22028  (count=8)
# 2334  (count=11)
# ua5nbp002  (count=7)
# 0.4  (count=6)
# 14.6  (count=6)
# 10.3  (count=6)
# :531341628109  (count=6)
# w32tm  (count=6)
# jublsbxdb01  (count=9)
# 1565  (count=6)
# be/4  (count=21)
# 10700  (count=13)
# ppid=10693  (count=12)
# citytaxi-repose5  (count=6)

# %%
for element in ['ec2', 'ec2-user', "'ec2",  ]:
    words_to_remove.remove(element)

# %%
print(len(words))
for w in words_to_remove:
    words.pop(w)
print(len(words))
# Out:
# 26746
# 17841

# %% [markdown]
# ---
#
# matching the pattern with  "//"

# %%
words_to_remove = []
for w in words:
    match = re.search('//', w)
    if match:
        print(match.string, words[w])
        words_to_remove.append(match.string)
# Out:
# // 113
# //map.json 1
# //console 3
# //consol 3
# //a 3
# //www 1
# //con 2
# //aws.ama 5
# //aws.amazo 5
# //docs 4
# //aw 5
# //aws 6
# //blog.e-z 1
# //aws.amaz 6
# //d 2
# //mapping.json 1
# //pg-documents/ 1
# //ap-south 2
# //aws.a 5
# //*.windows 1
# //blanktarget 1
# //who.is/whois-ip/ip-address/ 1
# //c 2
# //do 2
# transitional//en 1
# unrestricted// 1
# //cons 2
# //doc 1
# //./administrators 1
# //./remote 1
# //ad/ 1
# //console.a 1

# %%
print(len(words))
for w in words_to_remove:
    words.pop(w)
print(len(words))
# Out:
# 17841
# 17809

# %% [markdown]
# ---
#
# matching the pattern with  "\\\\"

# %%
words_to_remove = []
for w in words:
    match = re.search("\\\\", w)
    if match:
#         if words[w] > 5:
#             print(f"{match.string}  (count={words[w]})")
        print(f"{match.string}  (count={words[w]})")
        words_to_remove.append(match.string)
# Out:
# \  (count=222)
# \programdata\amazon\ssm  (count=1)
# \program  (count=48)
# files\amazon\ssm  (count=1)
# \searchengine  (count=3)
# endlessaisle\image  (count=3)
# engine\server  (count=2)
# \t\  (count=3)
# files\amazon\xentools\liteagent.exe  (count=1)
# authority\system  (count=3)
# upload\download  (count=1)
# \users\pimappdev  (count=1)
# \users\pimappdev.edelcap  (count=1)
# disablerepo=\*  (count=1)
# \n  (count=11)
# \users\administrator  (count=1)
# \users\manjunath.n  (count=1)
# files\amazon\awscli\bin\  (count=1)
# files\amazon\awscli\runtime\lib\site-packages\awscli\clidrive  (count=6)
# files\amazon\awscli\runtime\lib\site-packages\botocore\sessio  (count=1)
# files\amazon\awscli\runtime\lib\site-packages\botocore\hooks  (count=3)
# files\amazon\awscli\runtime\lib\site-packages\awscli\customiz  (count=1)
# ations\  (count=1)
# ___|\___|___|  (count=1)
# exceeded\n\tstatus  (count=4)
# \users\ilawsadmin  (count=4)
# hkey_local_machine\software\microsoft\windows  (count=4)
# nt\currentversion\softwareprotectionplatform\  (count=3)
# programfiles\trend  (count=2)
# micro\deep  (count=2)
# agent\dsa_control  (count=2)
# \windows\logs\dism\dism.log  (count=2)
# denied\  (count=3)
# \windows\cluster\reports  (count=2)
# \n\tat  (count=13)
# \test\  (count=1)
# engine\server\python  (count=1)
# \test  (count=1)
# \test\ami.txt  (count=3)
# .\ami-shared.txt  (count=1)
# '/^grub\_cmdline\_linux  (count=1)
# hkey_local_machine\software\microsoft\windows\currentversion\setup\state  (count=2)
# \amazon\ssm\logs\errors.log  (count=3)
# \programdata\amazon\amazoncloudwatchagent\configs\ssm_cw_windows  (count=4)
# files\amazon\amazoncloudwatchagent  (count=5)
# \programdata\amazon\amazoncloudwatchagent  (count=4)
# cwaprogramfiles\config-downloader.exe  (count=1)
# \programdata\microsoft\windows\start  (count=1)
# menu\programs\startup  (count=1)
# \programdata\a  (count=1)
# hkey_users\default  (count=1)
# 'temp\reset.bat  (count=1)
# \temp  (count=1)
# \users\default  (count=3)
# microsoft\windows  (count=1)
# nt\currentversion\profilelist  (count=1)
# \windows\panther\setupact.log  (count=1)
# \windows.old\users\abhijitrradm.ratnakarbank\ntuser.dat  (count=1)
# page\  (count=4)
# of\  (count=2)
# topage\  (count=2)
# computer\hkey_local_machine\system\currentcontrolset\control\terminal  (count=1)
# server\winstations\rdp-tcp  (count=29)
# key\|value  (count=1)
# aws=\  (count=1)
# aws\  (count=1)
# id=\  (count=1)
# name=\  (count=1)
# region=\  (count=1)
# -f\  (count=5)
# '\  (count=1)
# value=\  (count=1)
# hkey_local_machine\system\currentcontrolset\control\terminal  (count=10)
# server\winstations\rdp-tcp\portnumber  (count=1)
# \users\administrator\desktop\drivers\awsenanetworkdriver  (count=1)
# \users\administrator\desktop\drivers\awsenanetworkdriver\ena.inf  (count=1)
# \windows\inf  (count=1)
# hklm\system\currentcontrolset\control\terminal  (count=22)
# hkey_local_machine\software\microsoft\windows\currentversion\internet  (count=1)
# settings\winhttp  (count=1)
# hklm\software\microsoft\windows  (count=2)
# panel\network  (count=1)
# internet\network  (count=1)
# \windows  (count=3)
# \users\geoffrey\ntuser.dat  (count=1)
# \windows\memory.dmp  (count=1)
# \microsoft  (count=1)
# server\xxx\tools\binn\rsconfigtool.exe  (count=1)
# files\microsoft  (count=1)
# services\shared  (count=1)
# sql\ssr  (count=1)
# \perflogs\perflog-short.blg  (count=1)
# \logicaldisk  (count=1)
# \*  (count=10)
# \memory\*  (count=1)
# \.net  (count=1)
# \cache\*  (count=1)
# \network  (count=1)
# \paging  (count=1)
# \physicaldisk  (count=1)
# \processor  (count=2)
# \process  (count=1)
# \thread  (count=1)
# \redirector\*  (count=1)
# \server\*  (count=1)
# \system\*  (count=1)
# \server  (count=2)
# \terminal  (count=1)
# services\*  (count=1)
# \software\policies\microsoft\windows  (count=1)
# /\tmenuentry  (count=1)
# \t  (count=5)
# \projectrepository\gam_applications\pdwfilesuploadscheduler\dev\filesuploadscheduler\filesuploadscheduler\uploaddata.cs  (count=2)
# '/^grub\_cmdline\_linux/s/\  (count=10)
# /\  (count=10)
# \+\|^udev-  (count=2)
# \+  (count=2)
# error\|fail\|fatal\|panic\|trace  (count=2)
# \administrator  (count=2)
# .\-jubleadmin  (count=1)
# files\amazon\awscli\botocore\vendored\requests\cacert.pem  (count=1)
# hklm\software\microsoft\windows\currentversion\policies\system\credssp\parameters  (count=1)
# files\amazon\awscli\runtime\lib\site-packages\awscli\  (count=1)
# files\amazon\awscli\runtime\lib\site-packages\botocore\  (count=1)
# \users\username\.aws\credentials  (count=1)
# apppool\  (count=1)
# \tightvnc.msi  (count=2)
# \windows\explorer.exe  (count=1)
# \vlactivationtype  (count=1)
# \windows\softwaredistribution\  (count=1)
# \windows\logs\cbs\cbs.log  (count=1)
# \panther  (count=1)
# \windows\panther  (count=1)
# \windows\softwaredistribution\datastore  (count=1)
# windows.~bt\sources\rollback\setupact.log  (count=2)
# windows.~bt\sources\rollback\setupact.err  (count=1)
# windows.~bt\sources\setuphost.exe  (count=1)
# 'hkey_local_machine\system\currentcontrolset\control\terminal  (count=1)
# server\winstations\rdp-tcp\  (count=1)
# \citrix\xentools  (count=2)
# \boot\bcd  (count=5)
# print\  (count=1)
# hkey_local_machine\software\microsoft\windows\currentversion\setup\sysprep\cleanup  (count=1)
# \net_trace.etl  (count=1)
# computer\hkey_local_machine\system\currentcontrolset\services\reset  (count=1)
# \test\awsenanetworkdriver/ena.inf  (count=1)
# \test\awsnvme/awsnvme.inf  (count=1)
# hkey_local_machine\conv_system\controlset\services\tcpip\parameters\interfaces\  (count=1)
# \cloudendure\migrate_script.txt  (count=1)
# \cloudendure\aws_nvme\awsnvme_dism.log  (count=1)
# \drivers.txt  (count=1)
# \python  (count=1)
# hkcu\software\microsoft\windows\currentversion\run  (count=1)
# files\docker\docker  (count=1)
# service\ssastelemetry  (count=1)
# service\sqltelemetry  (count=1)
# service\mssqlserverolapservice  (count=1)
# service\reportserver  (count=1)
# service\mssqlfdlauncher  (count=1)
# service\sqlserveragent  (count=1)
# service\mssqllaunchpad  (count=1)
# service\mssqlserver  (count=1)
# \mkdir  (count=1)
# \scratch  (count=1)
# hkey_local_machine\system\currentcontrols  (count=1)
# \awsenanetworkdriver\  (count=1)
# programdata\amazon\amazoncloudwatchagent\logs\configuration-validation.log  (count=2)
# files\apache  (count=2)
# foundation\tomcat  (count=2)
# .\localaccount  (count=1)
# nt\terminal  (count=2)
# \\fsxshare\data  (count=1)
# \\  (count=3)
# \share  (count=2)
# ilgicltd\username  (count=2)
# hkey_local_machine\system\currentcontrolset\control\session  (count=6)
# manager\memory  (count=6)
# enforcing\|permissive  (count=1)
# hklm\system\currentcontrolset\services\gpsvc  (count=1)
# \pci  (count=1)
# nt\currentversion\profilelist\  (count=1)
# .\adminback  (count=1)
# \\ipaddress_of_instance  (count=1)
# chat\call  (count=1)
# \g  (count=1)
# '\h  (count=1)
# '\c  (count=1)
# \\nreading  (count=1)
# \\nresolving  (count=1)
# \\n\\nproblem  (count=1)
# provided\\n  (count=1)
# \\n  (count=3)
# files\amazon  (count=1)
# \users\userx\documents\rootcert.pem  (count=1)
# \users\userx\documents\rootcert.der  (count=1)
# /applications/python\  (count=3)
# \sqlserversetup  (count=2)
# \test\instances.csv  (count=1)
# \test\cpuutil.csv  (count=1)
# hklm\software\policies\microsoft\windows\windowsupdate  (count=1)
# domainname\username  (count=1)
# =\  (count=1)
# date\  (count=1)
# ==============\n\n  (count=1)
# \n\n  (count=1)
# server\winstations\rdp-tcp/securitylayer  (count=1)
# server\winstations\rdp-tcp/userauthentication  (count=1)
# server\winstations\rdp-tcp/fallowsecprotocolnegotiation  (count=1)
# hkey_local_machine\software\policies  (count=1)
# hkey_local_machine\software\microsoft\windows\currentversion\policies  (count=1)
# hkey_current_user\software\policies  (count=1)
# hkey_current_user\software\microsoft\windows\currentversion\policies  (count=1)
# allowed\  (count=1)
# explicitdeny\  (count=1)
# matchedstatements\  (count=1)
# items\  (count=18)
# statementid\  (count=2)
# effect\  (count=2)
# deny\  (count=2)
# principals\  (count=2)
# principalgroups\  (count=2)
# value\  (count=13)
# actions\  (count=2)
# *\  (count=4)
# resources\  (count=2)
# conditions\  (count=3)
# key\  (count=6)
# values\  (count=5)
# viaawsservice\  (count=2)
# false\  (count=2)
# failures\  (count=1)
# context\  (count=1)
# principal\  (count=1)
# id\  (count=1)
# name\  (count=1)
# leadsquared.com\  (count=2)
# arn\  (count=1)
# action\  (count=1)
# copyimage\  (count=1)
# resource\  (count=1)
# :image/*\  (count=1)
# region\  (count=1)
# service\  (count=1)
# hklm\temphive  (count=1)
# hkey_local_machine\temphive\microsoft\windows  (count=1)
# nt\currentversion\schedule\taskcache\tasks\  (count=1)
# \\amazon  (count=1)
# |\t  (count=1)
# c\  (count=1)
# f\  (count=1)

# %%
# for element in [
#     'engine\server', 'authority\system', 'upload\download', "ations\\", "programfiles\trend", 'micro\deep',
#     'denied\\', 'microsoft\windows', 'page\\', 'of\\', 'aws\\', 'internet\network', 'panel\network', 'files\apache',
#     'foundation\tomcat', 'manager\memory', 'chat\call', '\\nreading', '\\nresolving', '\\n\\nproblem', 'provided\\n ',
#     'files\amazon'
# ]:
#     try:
#         words_to_remove.remove(element)
#     except:
#         print(element)

# %%
print(len(words))
for w in words_to_remove:
    words.pop(w)
print(len(words))
# Out:
# 17809
# 17559

# %% [markdown]
# ---
# pattern with ./

# %%
words_to_remove = []
for w in words:
    match = re.search('\./', w)
    if match:
#         if words[w] > 10:
#             print(f"{match.string}  (count={words[w]})")
        print(f"{match.string}  (count={words[w]})")
        words_to_remove.append(match.string)
# Out:
# ./install.sh  (count=2)
# ./p.pem  (count=1)
# ./nitro_check_script.sh  (count=1)
# ./configure  (count=7)
# ./*.rpm  (count=1)
# ./setup.exe  (count=1)
# ./install  (count=2)
# ./awscli-bundle/install  (count=1)
# ./installer_linux.py  (count=1)
# ./dockercli.exe  (count=1)

# %%
print(len(words))
for w in words_to_remove:
    words.pop(w)
print(len(words))
# Out:
# 17559
# 17549

# %% [markdown]
# ---
# pattern with pattern "/words/"

# %%
words_to_remove = []
for w in words:
    match = re.search('/\w+/', w)
    if match:
#         if words[w] > 10:
#             print(f"{match.string}  (count={words[w]})")
        print(f"{match.string}  (count={words[w]})")
        words_to_remove.append(match.string)
# Out:
# /users/shhjs/.ssh/config  (count=1)
# /home/jenkins  (count=3)
# /var/log/  (count=15)
# /etc/*release  (count=3)
# /var/log  (count=36)
# /var/tmp  (count=3)
# /dev/shm  (count=8)
# /usr/tmpdisk  (count=1)
# /bin/bash  (count=32)
# /proc/cpuinfo  (count=7)
# /dists/bionic-updates/inrelease  (count=1)
# /dists/bionic-backports/inrelease  (count=1)
# /dists/bionic-security/inrelease  (count=1)
# /bin/yum  (count=2)
# /latest/user-data  (count=4)
# /home/dansaha/.ssh/config  (count=2)
# /hana/shared  (count=5)
# /opt/adobe  (count=1)
# /opt/adobe-new  (count=1)
# /usr/local  (count=2)
# /dev/xvda  (count=30)
# /etc/fstab  (count=157)
# /etc/os-release  (count=4)
# /sbin/plymouthd  (count=1)
# /bin/rm  (count=1)
# /home/ubuntu  (count=8)
# /home/ubuntu/.ssh  (count=3)
# /home/ubuntu/.ssh/authorized_keys  (count=4)
# /tmp/agentdependencies  (count=4)
# /hana/log  (count=1)
# /hana/data  (count=4)
# /usr/sap  (count=1)
# /etc/resolv.conf  (count=21)
# /dev/sdz  (count=2)
# /dev/xvdj  (count=3)
# /proc/filesystems  (count=1)
# /dev/sd*  (count=1)
# /etc/rsyslog.d/  (count=1)
# /etc/rsyslog.d/*.conf  (count=1)
# /dev/console  (count=1)
# /etc/profile  (count=5)
# /mnt/ebs  (count=2)
# /etc/resolve.conf  (count=4)
# /etc/sudoers  (count=8)
# /simple/exchangelib/  (count=5)
# /tmp/bootstrap.log  (count=1)
# /opt/mic  (count=1)
# /mysqlbackup/binary_logs/  (count=2)
# /etc/yum.conf  (count=2)
# /etc/redhat-release  (count=2)
# /dev/null  (count=18)
# /etc/mongod.conf  (count=1)
# /scripts/local-bottom  (count=3)
# /scripts/init-bottom  (count=3)
# /dev/  (count=2)
# /dev/xvdf  (count=24)
# /bin/false  (count=3)
# /etc/passwd|grep  (count=2)
# /mnt/dev  (count=9)
# /mnt/run  (count=3)
# /mnt/proc  (count=9)
# /mnt/sys  (count=9)
# /sbin/init  (count=9)
# /bin/sh  (count=6)
# /mnt/  (count=13)
# /var/log/*  (count=2)
# /home/admin  (count=4)
# /home/admin/.ssh  (count=2)
# /home/admin/.ssh/authorized_keys  (count=2)
# /dev/sdf  (count=28)
# /dev/xvdg  (count=9)
# /dev/xvdh  (count=1)
# /dev/xvdi  (count=2)
# /etc/mongodb.conf  (count=5)
# /data/db  (count=1)
# /etc/apt  (count=1)
# /usr/bin  (count=2)
# /usr/sbin  (count=1)
# /etc/chrony.keys  (count=1)
# /tmp/  (count=6)
# /mount/dev  (count=3)
# /mount/run  (count=3)
# /mount/proc  (count=3)
# /mount/sys  (count=3)
# /usr/bin/  (count=1)
# /dev/pts  (count=5)
# /root/initbak  (count=2)
# /bin/systemctl  (count=2)
# /root/.local/~  (count=1)
# /usr/lib/~  (count=1)
# /dev/nvme  (count=7)
# /var/*  (count=2)
# /var/  (count=1)
# /boot/initramfs-  (count=1)
# /etc/netplan  (count=2)
# /dev/nvmexny  (count=1)
# /dev/xvdc  (count=1)
# /bin/cat  (count=2)
# /bin/touch  (count=2)
# /etc/group  (count=1)
# /etc/products.d  (count=1)
# /proc/meminfo  (count=1)
# /tmp/topresult  (count=2)
# /tmp/no_forwarding.log  (count=2)
# /tmp/forwarding.log  (count=2)
# /wasnd/  (count=3)
# /root/  (count=3)
# /dev/sdg  (count=5)
# /mnt/efs  (count=1)
# /home/forti-siem  (count=1)
# /etc/hosts  (count=12)
# /home/aero-user/.ssh/authorized_keys  (count=1)
# /home/client-user/.ssh/authorized_keys  (count=1)
# /etc/inittab  (count=1)
# /etc/login.defs  (count=1)
# /etc/apt/  (count=1)
# /usr/src  (count=1)
# /usr/src/  (count=6)
# /var/snap  (count=1)
# /etc/environment  (count=4)
# /home/ubuntu/.aws  (count=1)
# /bin/chown  (count=7)
# /bin/chmod  (count=3)
# /etc/sudoers.d  (count=3)
# /etc/sudoers.d/readme  (count=1)
# /etc/sysctl.conf  (count=1)
# /dev/tcp/  (count=1)
# /etc/pam.d/password-auth  (count=1)
# /etc/pam.d/system-auth  (count=2)
# /etc/pam.d/passw  (count=1)
# /etc/sudoers.d/cloud-init  (count=4)
# /etc/sudoers.d/cloud-ini  (count=1)
# /proc/partitions  (count=1)
# /mongodb/data  (count=3)
# /dev/xvdb  (count=18)
# /sbin/parted  (count=2)
# /etc/init.d/snmpd  (count=2)
# /latest/meta-data/instance-id  (count=2)
# /snap/core  (count=1)
# /dev/loopx  (count=1)
# /dev/sds  (count=1)
# /dev/xvdt  (count=1)
# /db/  (count=1)
# /etc/auditd.conf  (count=1)
# /etc/nsswitch.conf  (count=1)
# /etc/dnsmasq.conf  (count=1)
# /users/bsnghfn/.ssh/id_dsa  (count=2)
# /users/bsnghfn/.ssh/id_ecdsa  (count=2)
# /users/bsnghfn/.ssh/id_xmss  (count=2)
# /apps/websphere  (count=1)
# /was/logs  (count=1)
# /etc/rsyslogd.conf  (count=3)
# /etc/rsyslog.conf  (count=5)
# /dev/sda  (count=2)
# /lib/modules/  (count=7)
# /proc/cmdline  (count=1)
# /proc/modules  (count=1)
# /dev/sdb  (count=5)
# /etc/init.d/mmtwebd  (count=1)
# /etc/passwd  (count=3)
# /home/  (count=4)
# /tmp/ssm  (count=2)
# '/^kernel/s/  (count=1)
# /sbin/dhclient-script  (count=1)
# /etc/chrony.conf  (count=1)
# /mnt/rescue  (count=9)
# /var/www/  (count=1)
# /scripts/init-bottom/plymouth  (count=1)
# /bin/plymouth  (count=1)
# /etc/init  (count=2)
# /bin/init  (count=2)
# /home/stdadm/  (count=1)
# /dev/sdn  (count=1)
# /dev/sdm  (count=1)
# /dev/disk/..  (count=1)
# /mnt/etc  (count=2)
# /bin/aws  (count=1)
# /temp/proc  (count=1)
# /temp/dev  (count=1)
# /temp/sys  (count=1)
# /dev/sde  (count=1)
# /etc/ntp.conf  (count=2)
# /etc/rc.local  (count=7)
# /var/empty  (count=7)
# /etc/localtime  (count=2)
# /sbin/lsmod  (count=1)
# /etc/fstable  (count=1)
# /dev/xvd  (count=2)
# /etc/init.d/nginx  (count=1)
# /etc/logrotate.d/nginx  (count=1)
# /mnt/usr  (count=1)
# /mnt/boot  (count=1)
# /etc/hostname  (count=1)
# /etc/init.d/hostname  (count=2)
# /etc/init.d/collectd  (count=2)
# /etc/collectd.conf  (count=1)
# /home/centos/.ssh/authorized_keys  (count=5)
# /mnt/home  (count=1)
# /mnt/var  (count=1)
# /opt/  (count=1)
# /etc/ssh/  (count=2)
# /bin/curl  (count=1)
# /boot/initrd.img-  (count=1)
# /etc/initramfs-tools/modules  (count=1)
# /etc/system-release  (count=1)
# /etc/f  (count=1)
# /etc/hosts.deny  (count=1)
# /^class=/s/  (count=1)
# /bin/firewall-cmd  (count=1)
# /etc/suseconnect  (count=2)
# /etc/zypp/  (count=2)
# /mnt/nexus  (count=1)
# /etc/defaultgrub  (count=3)
# /etc/docker/  (count=1)
# /etc/nologin  (count=1)
# /run/nologin  (count=3)
# /etc/  (count=1)
# /dev/hd  (count=1)
# /mnt/var/  (count=1)
# /sbin/dhclient  (count=1)
# /root/boot_script.sh  (count=1)
# /dev/nvme*  (count=1)
# /etc/hosts.allow  (count=1)
# /etc/grub.conf  (count=1)
# /test/  (count=3)
# /bin/grep  (count=1)
# /run/lock  (count=1)
# /etc/rc.d/init.d/network  (count=1)
# /etc/motd  (count=1)
# /etc/shadow  (count=1)
# /etc/rshadow  (count=1)

# %%
print(len(words))
for w in words_to_remove:
    words.pop(w)
print(len(words))
# Out:
# 17549
# 17318

# %% [markdown]
# ---
# pattern with pattern "_words"

# %%
words_to_remove = []
for w in words:
    match = re.search('_[a-z]+', w)
    if match:
#         if words[w] > 10:
#             print(f"{match.string}  (count={words[w]})")
        print(f"{match.string}  (count={words[w]})")
        words_to_remove.append(match.string)
# Out:
# statuscheckfailed_system  (count=62)
# nitro_check  (count=1)
# dbschema_tables_info  (count=2)
# 'pageiolatch_ex  (count=1)
# id_like=  (count=5)
# version_id=  (count=7)
# pretty_name=  (count=7)
# ansi_color=  (count=6)
# cpe_name=  (count=6)
# home_url=  (count=6)
# kb_read/s  (count=1)
# kb_wrtn/s  (count=1)
# kb_read  (count=1)
# kb_wrtn  (count=1)
# profile_name='stag-mfa  (count=1)
# describe_output=  (count=1)
# user_xattr  (count=1)
# .skip_if_unavailable=true  (count=1)
# x_get_es_cache_info  (count=1)
# x_check_health  (count=1)
# x_check_disk  (count=1)
# m_events  (count=1)
# constant_tsc  (count=9)
# nonstop_tsc  (count=10)
# current_clocksource  (count=4)
# available_clocksource  (count=4)
# unioniq_services_ingenico_agreement_final_compressed.pdf  (count=1)
# unioniq_services_ingenico_agreement_final_compressed.json  (count=1)
# iepl_pg_me_kit_nifara  (count=1)
# iepl_pg_me_kit_nifara.json  (count=1)
# iepl_pg_me_kit_riya_cabs_trip_private_limited  (count=1)
# iepl_pg_me_kit_riya_cabs_trip_private_limited.json  (count=1)
# completion_date=  (count=1)
# doc_id=  (count=1)
# doc_json=  (count=1)
# doc_file=  (count=1)
# doc_aud_file=  (count=1)
# completion_date  (count=1)
# doc_id  (count=1)
# doc_json  (count=1)
# doc_file  (count=1)
# doc_aud_file  (count=1)
# grub_default=  (count=1)
# __init__.py  (count=2)
# tag_key  (count=1)
# enforced_for  (count=2)
# kms_full_access  (count=3)
# data_shams_spark  (count=3)
# /new_data  (count=4)
# generate_completion_cache  (count=2)
# pam_nologin  (count=4)
# command_table  (count=1)
# self._get_command_table  (count=1)
# _get_command_table  (count=1)
# self._command_table  (count=1)
# self._build_command_table  (count=1)
# _build_command_table  (count=1)
# command_object=self  (count=1)
# event_name  (count=2)
# aliased_event_name  (count=1)
# self._emit  (count=1)
# _emit  (count=1)
# mark_as_preview  (count=1)
# service_model  (count=1)
# self._get_service_model  (count=1)
# _get_service_model  (count=1)
# api_version  (count=1)
# 'api_versions  (count=1)
# image_management  (count=4)
# adc_demo  (count=2)
# 'cli_binary_format  (count=2)
# ssh_connect_direct  (count=2)
# update_complete  (count=1)
# cx_oracle  (count=1)
# 'infosec_user  (count=4)
# monitor_restart_service  (count=8)
# monitor_cleanup  (count=8)
# sdap_get_map  (count=2)
# ldap_service_proto  (count=1)
# ldap_service_entry_usn  (count=1)
# ad_set_sdap_options  (count=1)
# sdap_set_sasl_options  (count=1)
# select_principal_from_keytab  (count=1)
# find_principal_in_keytab  (count=10)
# old_desc_blocks  (count=2)
# new_desc_blocks  (count=2)
# health_check  (count=5)
# wait_until_running  (count=1)
# key_load_public  (count=7)
# total_retry_delay  (count=1)
# retries_attempted  (count=1)
# total_time  (count=1)
# rd_sec/s  (count=1)
# wr_sec/s  (count=1)
# not_null  (count=7)
# nitro_script  (count=3)
# variant_id=  (count=2)
# bug_report_url=  (count=4)
# oracle_bugzilla_product=  (count=2)
# oracle_support_product=  (count=2)
# url_helper.py  (count=3)
# load_entry_point  (count=17)
# 'console_scripts  (count=7)
# get_distribution  (count=5)
# .load_entry_point  (count=5)
# __import__  (count=4)
# self.module_name  (count=4)
# '__name__  (count=4)
# cloud_config  (count=1)
# cc_part  (count=1)
# get_loadjson  (count=2)
# 'lp_mix_panel  (count=1)
# vg_sys  (count=5)
# audit_printk_skb  (count=2)
# scontext=system_u  (count=1)
# system_r  (count=6)
# auditd_t  (count=5)
# tcontext=system_u  (count=1)
# subj=system_u  (count=4)
# initrc_t  (count=1)
# pdo_sqlserv  (count=3)
# icmp_seq  (count=5)
# msedcl_gg  (count=1)
# create_failed  (count=2)
# rollback_in_progress  (count=1)
# ad_adc_aapsync_soc  (count=1)
# request_spot_fleet  (count=2)
# unregister_netdevice  (count=11)
# extras_suggestions  (count=7)
# 'ansible_job_id  (count=1)
# 'results_file  (count=1)
# 'instance_tags  (count=1)
# 'instance_type  (count=1)
# 'vpc_subnet_id  (count=1)
# 'ansible_loop_var  (count=1)
# 'ansible_index_var  (count=1)
# aws_default_region  (count=1)
# cloud_final_modules  (count=16)
# credentials_old  (count=1)
# op_lombard  (count=3)
# sftp_user  (count=2)
# wrong_version_number  (count=2)
# _pp  (count=1)
# /prd_citibank  (count=1)
# /backup_temp  (count=1)
# mc_createmachinecataloginitialzation  (count=1)
# desktopstudio_errorid  (count=1)
# desktopstudio_powershellhistory  (count=1)
# 'citrix_poc_hsd  (count=2)
# citrix_poc_hsd  (count=3)
# ou=citrix_vdi_machine  (count=1)
# citrix_desktopstudio_identitypooluid  (count=1)
# setopt=jenkins.skip_if_unavailable=true  (count=1)
# ssh_connect  (count=1)
# setopt=protected_multilib=false  (count=2)
# mod_unload  (count=4)
# rx_queue_size  (count=1)
# instance_id  (count=11)
# rbl_website_asg  (count=1)
# authorized_keys  (count=31)
# xfs_admin  (count=1)
# cache_purge  (count=1)
# rsyslog_traditionalfileformat  (count=1)
# r_await  (count=4)
# w_await  (count=4)
# d_await  (count=1)
# netdev_up  (count=3)
# close_wait  (count=6)
# sig_id  (count=1)
# on_complete  (count=2)
# perform_with_redirection  (count=1)
# build_response  (count=1)
# run_request  (count=1)
# organization_repositories  (count=1)
# log_file=  (count=1)
# dep_env=prod  (count=1)
# bash_lineno  (count=1)
# write_log  (count=3)
# log_file  (count=1)
# log_file.  (count=1)
# version_installed=  (count=1)
# version_required  (count=1)
# version_installed  (count=1)
# dep_env=  (count=1)
# vault_token=  (count=1)
# dummy_string  (count=3)
# consul_token=  (count=1)
# service_name=  (count=1)
# http_proxy  (count=9)
# https_proxy  (count=8)
# no_proxy  (count=8)
# ld_library_path  (count=3)
# logger_name  (count=1)
# thread_name  (count=1)
# level_value  (count=1)
# stack_trace  (count=2)
# /data_logs  (count=2)
# working_dir  (count=1)
# last_io_errno  (count=1)
# last_io_error  (count=1)
# log_name  (count=1)
# file_size  (count=1)
# log_bin  (count=2)
# variable_name  (count=1)
# log_bin_basename  (count=1)
# log_bin_index  (count=1)
# log_bin_trust_function_creators  (count=1)
# binary_logs  (count=2)
# archived_logs  (count=1)
# shutil.disk_usage  (count=1)
# as_cdt_op_map_add  (count=3)
# write_master  (count=2)
# as_bin_cdt_stack_modify_from_client  (count=2)
# time_redirect  (count=2)
# time_pretransfer  (count=3)
# preserve_hostname  (count=8)
# aws_eip  (count=4)
# nat_eip  (count=4)
# _async_abort.html  (count=1)
# __name__  (count=2)
# node_exporter  (count=1)
# mysql_exporter  (count=1)
# error_code  (count=3)
# proxy_method=  (count=1)
# browser_only=  (count=1)
# _upvars  (count=6)
# checkeod_service-trigger  (count=1)
# growth_alerts  (count=1)
# insufficient_data  (count=1)
# etli_uat_az_a_aem_author  (count=1)
# msg_name=  (count=1)
# sa_family=af_netlink  (count=1)
# msg_iov=  (count=1)
# iov_base=  (count=1)
# type=rtm_newlink  (count=1)
# flags=nlm_f_request|nlm_f_ack  (count=1)
# ifi_family=af_unspec  (count=1)
# ifi_type=arphrd_netrom  (count=1)
# ifi_index=if_nametoindex  (count=1)
# nla_type=ifla_mtu  (count=1)
# _netdev  (count=8)
# port_num  (count=2)
# sig_key  (count=2)
# sig_hashalgo  (count=2)
# url_helper  (count=1)
# parse_http_list  (count=1)
# _parse_list_header  (count=1)
# role/qradar_siem_readonly  (count=3)
# xfs_growfs  (count=11)
# disk_name  (count=1)
# grub_cmdline_linux_default=  (count=3)
# systemd.log_level=debug  (count=1)
# systemd.log_target=console  (count=1)
# 'nonstop_tsc  (count=2)
# sles_sap  (count=2)
# statuscheckfailed_instance  (count=45)
# sshd_config  (count=8)
# 'test_user  (count=1)
# godigit/w_digitplus.git  (count=1)
# rhn_register  (count=2)
# wintel_sysadmin_ip_rpa  (count=4)
# bind_ip  (count=4)
# repo_upgrade  (count=3)
# app_user  (count=9)
# mem_cgroup_css_offline  (count=1)
# sysprepstate=image_state_undeployable  (count=2)
# image_state_undeployable  (count=2)
# image_state_complete  (count=2)
# ~/.ssh/ags_ml_west.pem  (count=1)
# tcp_nodelay  (count=4)
# nitro_check_script.sh  (count=4)
# nitro_check_script  (count=1)
# container_runtime_t  (count=1)
# xfs_repair  (count=8)
# 'xfs_repair  (count=1)
# region_name  (count=1)
# json_dir  (count=1)
# param_mode  (count=1)
# common_conig  (count=1)
# multi_config  (count=1)
# _critical_  (count=1)
# ssh_pwauth  (count=6)
# lock_passwd  (count=7)
# default_user  (count=1)
# httpd_can_network_connect  (count=12)
# access_log  (count=2)
# gfp_kernel  (count=1)
# inventoryaudit_prod_app  (count=1)
# metrics_collected  (count=3)
# metrics_aggregation_interval  (count=1)
# statuscheckfailed_instances  (count=1)
# id_here  (count=1)
# hkey_users  (count=1)
# offline_rw  (count=1)
# offline_user  (count=1)
# 'add_drivers+=  (count=3)
# ipcmni_extend  (count=1)
# _setting  (count=1)
# _kernel.sem__  (count=1)
# xfs_repiar  (count=1)
# techm_iam_role_application_engineer  (count=2)
# drop_device  (count=2)
# append_dimensions  (count=1)
# aggregation_dimensions  (count=1)
# used_percent  (count=1)
# metrics_collection_interval  (count=4)
# mem_used_percent  (count=10)
# no_proxy=  (count=1)
# hkey_local_machine  (count=2)
# lc_ctype  (count=1)
# lc_messages  (count=1)
# lc_time  (count=1)
# sles_sap.prod  (count=1)
# alien_key_location  (count=1)
# ip_of_your_new_server  (count=2)
# ssh_msg_userauth_failure  (count=1)
# private_key  (count=1)
# type=bin_t  (count=4)
# _blank  (count=3)
# ad_adc_aapsync_soc  (count=1)
# ad_adc_aapsync_soc  (count=2)
# /yes_bank  (count=1)
# _return  (count=1)
# 'sort_by  (count=1)
# systemstatuscheck_failed  (count=1)
# reg_dword  (count=33)
# oom_reaper  (count=3)
# .ssh/id_rsa  (count=1)
# .ssh/id_rsa.pub  (count=1)
# ~/.ssh/id_rsa.pub  (count=1)
# ~/.ssh/authorized_keys  (count=2)
# ~/.ssh/id_rsa  (count=1)
# .ssh/authorized_keys  (count=1)
# grubby_prune_debug  (count=1)
# /ameyo_mnt  (count=2)
# aws_itam_master  (count=1)
# request_spot_instance  (count=1)
# gateway.trusted_hosts  (count=1)
# panic_on_oom  (count=1)
# sysprep_generalize_pnp  (count=3)
# dsa_filter_hook  (count=4)
# kernel_version  (count=1)
# add_ig_eips  (count=1)
# ip_prefix  (count=2)
# network_border_group  (count=2)
# fs.nr_open  (count=4)
# teams_osx_s  (count=1)
# add_drivers+=  (count=1)
# sg_cor_hris-linux_admin  (count=1)
# pam_unix  (count=6)
# pam_sss  (count=1)
# key_local_machine  (count=1)
# mem_used  (count=3)
# http_proxy=  (count=3)
# your_proxy_ip  (count=2)
# https_proxy=  (count=3)
# gfp_highuser_movable|__gfp_cold  (count=1)
# nm_controlled  (count=1)
# nm_controlled=no  (count=2)
# sec_e_internal_error  (count=1)
# spark_job  (count=1)
# grub_cmdline_linux  (count=5)
# pan_task  (count=1)
# cpu_usage_system  (count=1)
# disk_used_percent  (count=1)
# grub_cmdline_linux_default  (count=2)
# /creating_ebsbacked_winami.html  (count=1)
# hung_task  (count=1)
# lc_collate=c  (count=1)
# aws_ca_bundle  (count=5)
# ssh_exchange_identification  (count=3)
# package_name=  (count=2)
# package_version=  (count=2)
# build_kernel=  (count=2)
# built_module_name  (count=2)
# built_module_location=  (count=2)
# dest_module_location  (count=2)
# dest_module_name  (count=2)
# get_meta  (count=13)
# remove_rules  (count=1)
# cwoc_status  (count=1)
# cwoc_starttime  (count=1)
# cwoc_configstatus  (count=1)
# space_left  (count=1)
# space_left_action  (count=2)
# admin_space_left  (count=1)
# admin_space_left_action  (count=1)
# disk_full_action  (count=1)
# disk_error_action  (count=1)
# ebs_snapshot_management  (count=1)
# lm_sensors.service  (count=2)
# ip_tables.jpg  (count=1)
# ansible_user  (count=5)
# pam_open_session  (count=2)
# certificate_verify_failed  (count=7)
# certificate_verify_failed  (count=1)
# statuscheckfailed_instance-  (count=1)
# statuscheckfailed_system-  (count=1)
# centos_mantisbt_project=  (count=1)
# centos_mantisbt_project_version=  (count=1)
# redhat_support_product=  (count=1)
# redhat_support_product_version=  (count=1)
# /app_home  (count=1)
# ds_agent  (count=2)
# _make_api_call  (count=2)
# error_class  (count=1)
# parsed_response  (count=1)
# operation_name  (count=2)
# ssh_cofig  (count=2)
# bw_in_allowance_exceeded  (count=1)
# all_my_snapshot.txt  (count=1)
# _instance  (count=2)
# text_file.txt  (count=1)
# instance_healthcheck  (count=1)
# sysprepstate=image_state_specialize_reseal_to_oobe  (count=1)
# imagestate=image_state_complete  (count=1)
# value_of_password=mainpass  (count=2)
# id_resolver  (count=1)
# r_asg_instance_role  (count=1)
# volume_kmsclient  (count=1)
# hkey_local_machine  (count=7)
# prod_influx  (count=1)
# prod_grafana  (count=1)
# sysprep_generalize_mistreamprov  (count=3)
# first_boot  (count=3)
# migrate_data  (count=6)
# m_currenthostsurrogate-  (count=1)
# sp_polybase_join_group  (count=1)
# load_entry_poin  (count=1)
# infosec_user  (count=13)
# create_clidriver  (count=2)
# event_hooks=s  (count=1)
# 'nitro_check_script.sh  (count=1)
# parport_pc  (count=1)
# /raw_ckyc  (count=1)
# /ckyc_docs  (count=1)
# time_namelookup  (count=2)
# time_connect  (count=3)
# time_appconnect  (count=2)
# time_starttransfer  (count=3)
# time_total  (count=3)
# 'filter=ansible_kernel  (count=1)
# ansible_facts  (count=1)
# ansible_kernel  (count=1)
# skip_if_unavailable=true  (count=1)
# cpu_utilization  (count=2)
# 'sp_cdc_create_functions  (count=1)
# dsa_filter|ds_agent|redirfs|gsch  (count=1)
# o_rdonly|o_cloexec  (count=1)
# ldflags_nodist  (count=1)
# cflags_nodist  (count=1)
# _not_  (count=1)
# configure_ldflags_nodist=  (count=1)
# configure_ldflags=  (count=1)
# py_ldflags=  (count=1)
# configure_ldflags  (count=1)
# py_ldflags_no  (count=1)
# clearing_pcm  (count=2)
# .bash_history  (count=1)
# ssl_connect  (count=2)
# ssl_error_syscall  (count=1)
# s_client  (count=3)
# __gi_abort  (count=1)
# :report_and_die  (count=1)
# jvm_handle_linux_signal  (count=1)
# siginfo_t*  (count=1)
# profile_load  (count=1)
# apparmor_parser  (count=1)
# 'share_ami.pdf  (count=1)
# /jenkins_data  (count=1)
# safe_os  (count=2)
# detect_asset_changes  (count=1)
# response=client.describe_snapshots  (count=1)
# sort_keys=true  (count=1)
# sql_connect.png  (count=1)
# sql_security.png  (count=1)
# serio_raw  (count=1)
# ib_iser  (count=1)
# rdma_cm  (count=1)
# iw_cm  (count=1)
# ib_cm  (count=1)
# ib_sa  (count=1)
# ib_mad  (count=1)
# ib_core  (count=1)
# ib_addr  (count=1)
# iscsi_tcp  (count=1)
# libiscsi_tcp  (count=1)
# scsi_transport_iscsi  (count=1)
# async_memcpy  (count=1)
# async_pq  (count=1)
# async_xor  (count=1)
# async_tx  (count=1)
# ghash_clmulni_intel  (count=2)
# aesni_intel  (count=2)
# glue_helper  (count=1)
# ablk_helper  (count=1)
# express_sdb_celery_sms_worker  (count=1)
# safe_ports  (count=1)
# ssl_ports  (count=2)
# :database_migrations  (count=1)
# platform_name=android_mobile  (count=1)
# user_language=bn  (count=1)
# user_type=registered  (count=1)
# nvme_reset_work  (count=1)
# nvme_core  (count=1)
# grub_cmdline_linux=  (count=2)
# 'nvme_core.io_timeout  (count=1)
# 'grub_cmdline_linux=  (count=1)
# aws_access_key_id  (count=1)
# image_name=  (count=1)
# image_version=  (count=1)
# image_arch=  (count=1)
# image_file=  (count=1)
# cloud_init_modules  (count=1)
# amazonlinux_repo_https  (count=1)
# paste_encoded_error_message_here  (count=1)
# binfmt_misc  (count=1)
# sb_edac  (count=1)
# pcc_cpufreq  (count=1)
# ip_tables  (count=2)
# x_tables  (count=1)
# ata_piix  (count=1)
# xen_blkfront  (count=1)
# crypto_simd  (count=1)
# cc_scripts_user.py  (count=3)
# ssh_msg_recv  (count=3)
# msg_len  (count=1)
# recv_rexec_state  (count=1)
# mod_mime  (count=1)
# err_access_denied  (count=2)
# 'grub_cmdline_linux  (count=1)
# new_hostname  (count=5)
# 'bw_in_allowance_exceeded  (count=1)
# 'preserve_hostname  (count=1)
# how_snapshots_work  (count=1)
# do_exec_no_pty  (count=2)
# without-http_rewrite_module  (count=1)
# grub_default='advanced  (count=1)
# elastic_ip_addresses  (count=1)
# egg_info  (count=1)
# sign_and_send_pubkey  (count=1)
# gsch_get_event_ex  (count=1)
# user_buffer_size  (count=1)
# xfs_undelete  (count=2)
# binlog_delete  (count=2)
# describe_auto_scaling_instances  (count=1)
# client.describe_auto_scaling_instances  (count=1)
# infosec_usern  (count=1)
# get_uptime=true  (count=2)
# dhclient_set_hostname='yes  (count=4)
# remote_ipaddr=  (count=1)
# cloud_netconfig_manage='yes  (count=1)
# interactive_timeout  (count=1)
# net_read_timeout  (count=1)
# disk_used  (count=1)
# 'script_infosec_user.txt  (count=1)
# total_vm  (count=1)
# nr_ptes  (count=1)
# nr_pmds  (count=1)
# oom_score_adj  (count=5)
# support_url=  (count=1)
# var_log  (count=1)
# src_tmp/*  (count=1)
# src_var/*  (count=1)
# git_data_dirs  (count=1)
# git_data_dir  (count=1)
# grub_distributor=  (count=1)
# grub_default=saved  (count=1)
# grub_disable_submenu=true  (count=1)
# grub_terminal_output=  (count=1)
# access_key  (count=2)
# secret_key  (count=2)
# account_management  (count=1)
# .ip_prefix  (count=1)
# statuscheck_failed  (count=1)
# sync_remote_users  (count=3)
# pluginname=standard_stream  (count=5)
# ~/.bash_history  (count=1)
# grub_disable_recovery=  (count=1)
# grub_terminal=  (count=1)
# grub_serial_command=  (count=1)
# 'attaching_root_volume.png  (count=1)
# oyo_prod_microservice  (count=1)
# version_number  (count=1)
# bugcheck_code  (count=1)
# read_address  (count=1)
# process_name  (count=1)
# symbol_name  (count=1)
# module_name  (count=1)
# image_name  (count=1)
# stack_command  (count=1)
# bucket_id_func_offset  (count=1)
# failure_bucket_id  (count=1)
# av_awsnvme  (count=1)
# unknown_function  (count=1)
# os_version  (count=1)
# buildlab_str  (count=1)
# winblue_ltsb  (count=1)
# osplatform_type  (count=1)
# status_checks_failed_system  (count=1)
# vg_sys-lv_home  (count=1)
# vg_sys-lv_tmp  (count=1)
# vg_sys-lv_var  (count=1)
# vg_sys-lv_var_log  (count=2)
# vg_sys-lv_apps  (count=1)
# vg_sys-lv_var_tmp  (count=1)
# vg_sys-lv_var_log_audit  (count=1)
# vg_sys-lv_docker  (count=1)
# mask_to_net_prefix  (count=1)
# log_time  (count=1)
# status_wrapper  (count=1)
# atomic_helper.write_json  (count=1)
# status_path  (count=1)
# write_json  (count=1)
# write_file  (count=2)
# ds_am  (count=1)
# pps_allowance_exceeded  (count=1)
# scope_of_aws_support  (count=1)
# role/emr_defaultrole  (count=1)
# my_copied_file.ext  (count=1)
# record.exc_text  (count=1)
# record.exc_info  (count=1)
# traceback.print_exception  (count=1)
# print_exception  (count=1)
# _format_exception_iter  (count=2)
# _iter_chain  (count=1)
# exc.__context__  (count=1)
# '__context__  (count=1)
# pem_file  (count=1)
# wired_interface  (count=3)
# values=instance_type_and_size  (count=1)
# region_id  (count=1)
# ami_id  (count=1)
# egress_spoofed_ip_drops  (count=1)
# instance.instance_id  (count=1)
# dimension.set_name  (count=1)
# dimension.set_value  (count=1)
# snapshot_list=  (count=1)
# snapshot_list  (count=2)
# owner_ids=self  (count=1)
# owner_ids  (count=1)
# packselector_autoscaling_group  (count=2)
# rhel_product.pem  (count=1)
# dac_override  (count=1)
# boot_script.sh  (count=2)
# reboot_script.service  (count=1)
# size_download  (count=1)
# http_code  (count=1)
# il_iam_fasttracksftp_du  (count=1)
# allow_as_dependency  (count=1)
# root_certificate.pem  (count=2)
# pem_read_bio  (count=1)
# prod_bgserver  (count=1)
# standard_stream  (count=6)
# standard_stream  (count=1)
# device_name  (count=2)
# standard_stream  (count=1)
# java_home  (count=1)
# generated_name  (count=1)
# asg_name  (count=1)
# sqs_arn  (count=1)
# generated_unique_id  (count=1)
# kmem_alloc  (count=3)
# http_access  (count=2)
# aws_sts_regional_endpoints=regional  (count=1)
# aws_sts_regional_endpoints  (count=1)
# sts_regional_endpoints  (count=1)
# wintel_sysadmin_ips  (count=2)
# in_public_allow  (count=3)
# evoc_fin_paypal_usrs_trs_ro  (count=1)
# packet_write_wait  (count=1)
# protected_multili  (count=1)
# region_name=region  (count=1)
# found_instance  (count=2)
# dsa_filter  (count=1)
# create_or_reencrypt_evk  (count=1)
# compute_geometry  (count=1)
# 'user_xattr  (count=2)
# pagerduty_cw_alarm_event_transformer  (count=1)
# role/lambda_pagerduty_cw_alarm  (count=1)
# lambda_pagerduty_cw_alarm  (count=1)
# receive_packet  (count=1)
# _osc  (count=1)
# ae_not_found  (count=1)
# aws_opsworks_agent  (count=2)
# sync_remoter_users  (count=2)
# read_timeout  (count=3)
# __iter__  (count=2)
# self._make_request  (count=1)
# current_kwargs  (count=1)
# _make_request  (count=2)
# self._method  (count=1)
# **current_kwargs  (count=1)
# _api_call  (count=1)
# self._make_api_call  (count=1)
# operation_model  (count=3)
# request_dict  (count=3)
# request_context  (count=1)
# make_request  (count=1)
# self._send_request  (count=1)
# _send_request  (count=1)
# success_response  (count=1)
# _needs_retry  (count=1)
# caught_exception=caught_exception  (count=1)
# request_dict=request_dict  (count=1)
# self._emitter  (count=1)
# cancelled_running  (count=1)
# ssm_cm_windows  (count=1)
# aws_instance.default  (count=2)
# swiftshader_indirect  (count=2)
# build_id  (count=1)
# android_sdk_root/emulator  (count=2)
# crashhandler_die  (count=1)
# sec_error_unknown_issuer  (count=1)
# rewrite_rules  (count=1)
# builtin_op_kernels  (count=1)
# :optimized_ops  (count=2)
# :depthwise_conv  (count=2)
# input_data_a  (count=1)
# _load_libzmq  (count=2)
# __aarch  (count=1)
# associate_address  (count=1)
# default_ciphers  (count=1)

# %%
print(len(words))
for w in words_to_remove:
    words.pop(w)
print(len(words))
# Out:
# 17318
# 16595

# %% [markdown]
# ---
# words of length 3 or less

# %%
words_to_remove = []
for w in words:
    if len(w) < 3:
        print(f"{w}  (count={words[w]})")
        words_to_remove.append(w)
# Out:
# ,  (count=52022)
# i  (count=16729)
# am  (count=1685)
# in  (count=12328)
# of  (count=14742)
# (  (count=8324)
# )  (count=8873)
# it  (count=7142)
# is  (count=13333)
# up  (count=1133)
# .  (count=62331)
# at  (count=5671)
# pm  (count=328)
# to  (count=48397)
# :  (count=32061)
# ``  (count=6474)
# ''  (count=7080)
# id  (count=3200)
# s  (count=3050)
# we  (count=15738)
# a  (count=14413)
# us  (count=6159)
# no  (count=3030)
# on  (count=11897)
# if  (count=9187)
# be  (count=9407)
# do  (count=3413)
# so  (count=2900)
# as  (count=9622)
# !  (count=1734)
# hi  (count=3041)
# r  (count=985)
# an  (count=5604)
# me  (count=2117)
# my  (count=2486)
# &  (count=562)
# by  (count=7492)
# 'm  (count=440)
# or  (count=6009)
# -  (count=5221)
# {  (count=715)
# ip  (count=1240)
# s.  (count=375)
# '  (count=2308)
# az  (count=158)
# ?  (count=3752)
# c  (count=1139)
# >  (count=2002)
# 's  (count=961)
# v.  (count=84)
# %  (count=731)
# ;  (count=917)
# 'd  (count=100)
# ad  (count=69)
# hh  (count=548)
# mm  (count=548)
# ss  (count=552)
# vm  (count=54)
# /  (count=400)
# db  (count=133)
# [  (count=7528)
# ]  (count=7398)
# ~  (count=260)
# $  (count=1205)
# os  (count=1058)
# =  (count=602)
# |  (count=641)
#   (count=205)
# --  (count=14963)
# eg  (count=19)
# ie  (count=50)
# @  (count=642)
# wo  (count=42)
# ok  (count=148)
# t.  (count=115)
# #  (count=3137)
# <  (count=836)
# he  (count=61)
# -c  (count=35)
# /f  (count=20)
# }  (count=612)
# d  (count=765)
# cp  (count=34)
# g  (count=298)
# ca  (count=123)
# -i  (count=133)
# -v  (count=65)
# *  (count=479)
# pv  (count=173)
# m.  (count=369)
# d-  (count=2)
# nt  (count=16)
# t  (count=1483)
# gb  (count=87)
# ks  (count=2)
# -a  (count=50)
# o  (count=1177)
# ms  (count=237)
# ·  (count=1)
#   (count=77)
# u  (count=600)
# +  (count=588)
# im  (count=8)
# rw  (count=5)
# kb  (count=35)
# oe  (count=6)
# sg  (count=90)
# e  (count=1975)
# go  (count=345)
# fw  (count=6)
# lb  (count=24)
# tg  (count=3)
# +e  (count=1)
# x  (count=81)
# cl  (count=5)
# es  (count=9)
# ==  (count=41)
# ||  (count=33)
# rc  (count=6)
# dr  (count=10)
# ps  (count=52)
# tb  (count=40)
# b  (count=352)
# m  (count=393)
# wc  (count=8)
# -l  (count=66)
# fi  (count=17)
# `  (count=243)
# -f  (count=84)
# -r  (count=61)
#   (count=85)
# ..  (count=42)
# n.  (count=81)
# z  (count=44)
# -s  (count=110)
# y.  (count=22)
# nc  (count=21)
# **  (count=22)
# et  (count=1)
# -w  (count=9)
# w  (count=271)
# ^  (count=84)
# su  (count=34)
# h  (count=672)
# l  (count=538)
# n  (count=1150)
# p  (count=370)
# f  (count=347)
# vs  (count=12)
# tv  (count=2)
# mi  (count=3)
# lt  (count=9)
# ey  (count=1)
# de  (count=3)
# py  (count=3)
# ls  (count=107)
# yo  (count=9)
# va  (count=8)
# js  (count=4)
# bo  (count=8)
# -q  (count=18)
# -o  (count=82)
# rm  (count=51)
# ro  (count=22)
# -u  (count=16)
# .i  (count=4)
# na  (count=3)
# tt  (count=1)
# eu  (count=6)
# ui  (count=6)
# -y  (count=97)
# '^  (count=11)
# hr  (count=5)
# rt  (count=3)
# om  (count=2)
# -m  (count=34)
# rk  (count=1)
# ol  (count=2)
# /o  (count=6)
# '+  (count=1)
# sy  (count=14)
# ni  (count=12)
# wa  (count=17)
# si  (count=11)
# st  (count=17)
# av  (count=6)
# j.  (count=56)
# ga  (count=2)
# pf  (count=1)
# mu  (count=1)
# vg  (count=7)
# o.  (count=25)
# xy  (count=1)
# ut  (count=1)
# ri  (count=29)
# mk  (count=2)
# k.  (count=173)
# lo  (count=31)
# sp  (count=14)
# -+  (count=162)
# er  (count=1)
# k  (count=139)
# ce  (count=17)
# _|  (count=1)
# df  (count=58)
# -h  (count=45)
# qr  (count=4)
# rd  (count=20)
# ra  (count=4)
# se  (count=17)
# v  (count=187)
# ha  (count=7)
# y  (count=275)
# _  (count=19)
# q  (count=36)
# jq  (count=9)
# ec  (count=10)
# -p  (count=75)
# fs  (count=29)
# mr  (count=1)
# rx  (count=10)
# ii  (count=28)
# ws  (count=3)
# -x  (count=15)
# mq  (count=8)
# -t  (count=31)
# ag  (count=12)
# qq  (count=1)
# io  (count=104)
# sn  (count=2)
# gp  (count=2)
# kt  (count=1)
# sh  (count=7)
# /*  (count=2)
# xb  (count=1)
# y-  (count=1)
# m-  (count=2)
# tr  (count=5)
# -d  (count=14)
# -n  (count=31)
# cw  (count=28)
# §  (count=3)
# /g  (count=4)
# g.  (count=78)
# cs  (count=7)
# ex  (count=10)
# |+  (count=11)
# cd  (count=63)
# hb  (count=1)
# sa  (count=7)
# qa  (count=3)
# i.  (count=35)
# p.  (count=144)
# ^c  (count=7)
# dh  (count=1)
# dc  (count=12)
# vi  (count=28)
# c.  (count=157)
# nw  (count=7)
# -k  (count=23)
# mb  (count=12)
# '-  (count=2)
# b.  (count=208)
# a.  (count=164)
# r.  (count=118)
# h.  (count=64)
# fl  (count=1)
# ht  (count=14)
# th  (count=35)
# -e  (count=21)
# f.  (count=37)
# w.  (count=21)
# d.  (count=100)
# lv  (count=7)
#   (count=20)
# eb  (count=3)
# l.  (count=59)
# ln  (count=8)
# ac  (count=5)
# ff  (count=1)
# i-  (count=1)
# wq  (count=1)
# aw  (count=15)
# en  (count=8)
# l_  (count=1)
# +-  (count=1)
# mv  (count=8)
# ou  (count=4)
#   (count=18)
# /b  (count=1)
# ch  (count=4)
# ma  (count=3)
# ab  (count=5)
# sl  (count=2)
# yb  (count=2)
# li  (count=2)
# ov  (count=1)
# ^*  (count=3)
# ke  (count=1)
# tx  (count=8)
# bu  (count=2)
# fo  (count=7)
# e  (count=2)
# ur  (count=11)
# du  (count=15)
# -b  (count=6)
# vf  (count=8)
# ug  (count=6)
# gw  (count=6)
# rs  (count=1)
# -j  (count=9)
#   (count=7)
# tl  (count=1)
# ux  (count=1)
# da  (count=3)
# j  (count=15)
# /v  (count=27)
# /t  (count=22)
# /d  (count=22)
# ry  (count=1)
# '*  (count=1)
# ×  (count=1)
# re  (count=16)
# ta  (count=1)
# fa  (count=2)
# s/  (count=1)
# ty  (count=1)
# co  (count=16)
# pe  (count=3)
# o  (count=1)
# yi  (count=1)
# ae  (count=3)
# fd  (count=3)
# |^  (count=2)
# iv  (count=8)
# al  (count=1)
# u.  (count=23)
# q.  (count=5)
# wu  (count=1)
# gr  (count=1)
# ne  (count=2)
# ho  (count=2)
# -z  (count=1)
# ti  (count=1)
# gs  (count=1)
# ds  (count=1)
# sw  (count=2)
# ml  (count=1)
# ev  (count=1)
# -g  (count=3)
# pc  (count=12)
# ft  (count=2)
# pl  (count=8)
# fu  (count=2)
# fb  (count=1)
# '/  (count=1)
# e.  (count=15)
# /a  (count=1)
# ns  (count=2)
# uh  (count=3)
# ye  (count=2)
# ^d  (count=2)
# +r  (count=1)
# /i  (count=3)
# /y  (count=1)
# ll  (count=10)
# ph  (count=1)
# +x  (count=5)
# qm  (count=1)
# bh  (count=1)
# e-  (count=4)
# ee  (count=3)
# pp  (count=1)
# ef  (count=1)
#   (count=13)
# tz  (count=2)
# ci  (count=1)
# y_  (count=1)
# cx  (count=1)
# a-  (count=1)
# bt  (count=1)
# vo  (count=1)
# hu  (count=1)
# wh  (count=1)
# kc  (count=1)
#   (count=3)
# /.  (count=1)
# .*  (count=2)
# */  (count=2)
# mt  (count=1)
# au  (count=1)
# /s  (count=3)
# qu  (count=1)
# wv  (count=1)
# hw  (count=2)
# ar  (count=1)
# xp  (count=1)
# /e  (count=1)
# s  (count=1)
# dm  (count=1)
# y|  (count=1)
# /q  (count=1)
# fe  (count=4)
# dn  (count=1)
# ea  (count=1)
# ,g  (count=1)
# wi  (count=5)
# ot  (count=1)
# ve  (count=2)
# pt  (count=3)
# r+  (count=1)
# gl  (count=1)
# ++  (count=3)
# fy  (count=1)
# cf  (count=1)
# eh  (count=1)
# ay  (count=1)
# mo  (count=1)
# lr  (count=1)
# xi  (count=1)
# cr  (count=1)
# /r  (count=1)
# z.  (count=2)
# x.  (count=1)
# tp  (count=1)
# un  (count=1)
# kn  (count=1)
# ei  (count=2)
# *  (count=1)
# ld  (count=1)
# ts  (count=4)
# gt  (count=2)
# gu  (count=1)
# ._  (count=1)
# nf  (count=2)
# bf  (count=1)
# cc  (count=1)
# fr  (count=1)
# eq  (count=3)
# ir  (count=1)
# np  (count=2)
# pw  (count=2)
# c  (count=1)
# ic  (count=1)
# .-  (count=6)
# nr  (count=1)
# qf  (count=1)
# lp  (count=2)
# yf  (count=1)
# dk  (count=1)
# bq  (count=1)
# ~y  (count=1)
# £  (count=1)
# s|  (count=1)
#   (count=1)
# .b  (count=1)
# ´  (count=1)
# gn  (count=1)
# wm  (count=1)
# =t  (count=1)
# vr  (count=1)
# u=  (count=1)
# cm  (count=1)
# r/  (count=1)
# lx  (count=1)
# di  (count=1)
# bc  (count=1)

# %%
print(len(words))
for w in words_to_remove:
    words.pop(w)
print(len(words))
# Out:
# 16595
# 16128

# %%
language_dict = enchant.Dict("en_US")
words_to_remove = []
for w in words:
    if len(w) < 4 and not language_dict.check(w):
        print(f"{w}  (count={words[w]})")
        words_to_remove.append(w)
# Out:
# ec2  (count=3361)
# ist  (count=398)
# ami  (count=1756)
# ebs  (count=885)
# kms  (count=129)
# cmk  (count=53)
# aws  (count=22912)
# n't  (count=3638)
# url  (count=3695)
# rca  (count=54)
# api  (count=573)
# anu  (count=55)
# sdk  (count=42)
# asg  (count=191)
# ips  (count=151)
# cli  (count=389)
# iam  (count=397)
# cpu  (count=874)
# arn  (count=214)
# acm  (count=1)
# sla  (count=15)
# nat  (count=128)
# vpc  (count=458)
# eip  (count=107)
# utc  (count=1372)
# kie  (count=2)
# sr.  (count=2)
# gmt  (count=46)
# emr  (count=33)
# ott  (count=1)
# raj  (count=3)
# dec  (count=103)
# plz  (count=8)
# ena  (count=437)
# n/w  (count=4)
# ssm  (count=604)
# tcp  (count=214)
# sql  (count=363)
# rtm  (count=2)
# sai  (count=60)
# iad  (count=2)
# cwe  (count=2)
# nic  (count=43)
# dns  (count=248)
# efs  (count=48)
# .if  (count=1)
# rds  (count=128)
# vpn  (count=100)
# 've  (count=335)
# npm  (count=26)
# ssl  (count=93)
# smp  (count=15)
# mon  (count=19)
# aug  (count=28)
# id=  (count=6)
# oct  (count=95)
# adr  (count=1)
# sar  (count=57)
# tps  (count=3)
# ecr  (count=19)
# cmd  (count=31)
# pls  (count=79)
# acl  (count=49)
# sme  (count=10)
# sns  (count=27)
# whe  (count=1)
# wih  (count=1)
# gpl  (count=6)
# pci  (count=31)
# thu  (count=29)
# feb  (count=72)
# tue  (count=42)
# apr  (count=73)
# fri  (count=22)
# sep  (count=34)
# ali  (count=8)
# txn  (count=1)
# cve  (count=15)
# rdp  (count=469)
# vod  (count=3)
# tim  (count=8)
# azs  (count=30)
# msg  (count=23)
# pfa  (count=38)
# sri  (count=4)
# sys  (count=21)
# tsc  (count=9)
# iss  (count=2)
# sps  (count=1)
# igw  (count=44)
# hii  (count=8)
# e.g  (count=42)
# awk  (count=13)
# dms  (count=2)
# ecs  (count=41)
# vss  (count=1)
# pre  (count=9)
# ***  (count=11)
# nla  (count=71)
# ios  (count=3)
# eni  (count=178)
# pem  (count=29)
# gui  (count=33)
# lts  (count=32)
# mr.  (count=4)
# ble  (count=1)
# -zv  (count=8)
# b/s  (count=20)
# tes  (count=1)
# eks  (count=21)
# clr  (count=2)
# uid  (count=18)
# elb  (count=78)
# iis  (count=29)
# dnf  (count=9)
# gpo  (count=12)
# vip  (count=1)
# eed  (count=1)
# amd  (count=38)
# sev  (count=1)
# asv  (count=8)
# qid  (count=28)
# waf  (count=3)
# ngf  (count=1)
# qos  (count=1)
# dss  (count=1)
# dlm  (count=10)
# pst  (count=20)
# jha  (count=5)
# 're  (count=150)
# nov  (count=69)
# cis  (count=15)
# tls  (count=95)
# ie.  (count=1)
# sim  (count=5)
# maj  (count=19)
# xfs  (count=62)
# cft  (count=10)
# sso  (count=3)
# sts  (count=63)
# env  (count=30)
# lvm  (count=68)
# rhn  (count=1)
# pid  (count=70)
# tid  (count=11)
# ibm  (count=20)
# ldd  (count=9)
# nad  (count=1)
# fou  (count=1)
# smb  (count=5)
# gpu  (count=29)
# eva  (count=1)
# prd  (count=1)
# i/o  (count=110)
# uat  (count=7)
# rpa  (count=5)
# chs  (count=3)
# jan  (count=59)
# unc  (count=2)
# hvm  (count=44)
# hvr  (count=5)
# rmq  (count=2)
# clw  (count=1)
# gbs  (count=1)
# nvm  (count=3)
# dev  (count=42)
# nfs  (count=64)
# pcs  (count=7)
# fyi  (count=15)
# wrt  (count=2)
# r/w  (count=2)
# php  (count=58)
# -qa  (count=15)
# oim  (count=3)
# yuo  (count=1)
# oel  (count=1)
# cpe  (count=9)
# '++  (count=3)
# kib  (count=9)
# mem  (count=10)
# -sr  (count=1)
# smi  (count=1)
# teh  (count=7)
# 'no  (count=3)
# 'll  (count=408)
# avc  (count=2)
# svc  (count=8)
# cds  (count=7)
# .we  (count=6)
# irq  (count=6)
# puc  (count=1)
# har  (count=9)
# o/p  (count=2)
# -ef  (count=4)
# tgw  (count=12)
# nps  (count=5)
# ntp  (count=31)
# ris  (count=11)
# pmm  (count=3)
# ppk  (count=4)
# els  (count=6)
# jul  (count=32)
# udp  (count=19)
# to=  (count=1)
# ror  (count=1)
# ork  (count=1)
# qbr  (count=1)
# __|  (count=1)
# ecc  (count=2)
# pnp  (count=5)
# lsb  (count=19)
# gib  (count=65)
# no  (count=6)
# src  (count=7)
# .so  (count=1)
# soa  (count=1)
# sgs  (count=8)
# abc  (count=1)
# vsa  (count=3)
# mhz  (count=2)
# xen  (count=35)
# dsa  (count=7)
# tty  (count=4)
# .it  (count=2)
# rmc  (count=1)
# pim  (count=1)
# cvo  (count=6)
# ese  (count=13)
# -mh  (count=1)
# -/+  (count=1)
# mcs  (count=1)
# -ou  (count=1)
# i.e  (count=111)
# -hn  (count=1)
# pam  (count=19)
# rss  (count=4)
# pfb  (count=4)
# nlb  (count=7)
# sms  (count=15)
# scp  (count=30)
# -nl  (count=1)
# icc  (count=1)
# cbs  (count=2)
# h/w  (count=2)
# vnc  (count=17)
# spc  (count=1)
# cdo  (count=1)
# mqm  (count=22)
# fip  (count=2)
# sbs  (count=1)
# kly  (count=1)
# prv  (count=1)
# .sh  (count=1)
# mfp  (count=1)
# dax  (count=1)
# bpf  (count=1)
# 'ls  (count=2)
# gcc  (count=10)
# g++  (count=2)
# r/s  (count=4)
# w/s  (count=4)
# d/s  (count=1)
# ssd  (count=22)
# sqs  (count=20)
# aes  (count=1)
# tib  (count=22)
# oci  (count=3)
# att  (count=2)
# faq  (count=17)
# -ne  (count=3)
# ahs  (count=2)
# rdk  (count=5)
# rac  (count=1)
# nfr  (count=1)
# csv  (count=24)
# www  (count=3)
# edt  (count=19)
# wie  (count=1)
# spf  (count=1)
# eod  (count=5)
# sgp  (count=2)
# -+|  (count=8)
# pdf  (count=8)
# zou  (count=1)
# -du  (count=4)
# asd  (count=6)
# xmt  (count=5)
# jni  (count=1)
# dba  (count=3)
# okd  (count=3)
# thx  (count=3)
# o.s  (count=8)
# ver  (count=11)
# lsq  (count=1)
# ipl  (count=2)
# mds  (count=1)
# smt  (count=8)
# taa  (count=1)
# alo  (count=2)
# knw  (count=2)
# dnt  (count=1)
# sfc  (count=20)
# sss  (count=3)
# dll  (count=12)
# dxc  (count=10)
# c^c  (count=1)
# xml  (count=8)
# n/a  (count=8)
# +++  (count=5)
# ada  (count=1)
# xyz  (count=3)
# mtu  (count=17)
# 'df  (count=7)
# iso  (count=5)
# vtc  (count=3)
# pps  (count=17)
# asm  (count=1)
# pos  (count=2)
# dto  (count=2)
# cts  (count=2)
# up  (count=1)
# poc  (count=4)
# sid  (count=21)
# -/-  (count=1)
# ttl  (count=14)
# -vz  (count=8)
# hpe  (count=1)
# san  (count=2)
# lun  (count=1)
# mtr  (count=22)
# myt  (count=2)
# vis  (count=2)
# efa  (count=6)
# eac  (count=2)
# isv  (count=2)
# vfs  (count=20)
# thi  (count=7)
# 'cc  (count=1)
# htt  (count=7)
# jon  (count=3)
# phd  (count=31)
# aki  (count=1)
# arp  (count=21)
# -al  (count=23)
# -rw  (count=4)
# eus  (count=1)
# -rf  (count=10)
# usi  (count=3)
# im  (count=24)
# cls  (count=1)
# ===  (count=77)
# ste  (count=1)
# rpc  (count=10)
# pvs  (count=6)
# vgs  (count=2)
# lvs  (count=3)
# tra  (count=1)
# cen  (count=4)
# sed  (count=21)
# leo  (count=2)
# -il  (count=5)
# ide  (count=3)
# -xf  (count=6)
# */*  (count=4)
# lin  (count=4)
# isp  (count=5)
# fsx  (count=9)
# zoe  (count=1)
# mbr  (count=28)
# gpt  (count=24)
# csm  (count=2)
# vgw  (count=8)
# iem  (count=4)
# ype  (count=1)
# usb  (count=1)
# dcx  (count=1)
# dst  (count=2)
# oom  (count=37)
# gw/  (count=1)
# amz  (count=1)
# dsc  (count=1)
# 'or  (count=1)
# rrs  (count=1)
# thr  (count=1)
# mfa  (count=13)
# iex  (count=24)
# iwr  (count=12)
# cst  (count=3)
# o.k  (count=1)
# ok.  (count=13)
# rtb  (count=1)
# sho  (count=2)
# sos  (count=14)
# -pn  (count=5)
# pdt  (count=24)
# ple  (count=7)
# mno  (count=32)
# ldf  (count=1)
# mea  (count=2)
# sto  (count=8)
# id  (count=7)
# eri  (count=1)
# joe  (count=9)
# +/-  (count=19)
# tha  (count=5)
# 'on  (count=1)
# vms  (count=10)
# hoc  (count=1)
# clo  (count=2)
# -eq  (count=1)
# ely  (count=3)
# mnt  (count=1)
# srv  (count=1)
# tmp  (count=2)
# usr  (count=5)
# |wc  (count=1)
# rfc  (count=2)
# msi  (count=11)
# exe  (count=1)
# sig  (count=1)
# saf  (count=2)
# a=r  (count=7)
# fsr  (count=2)
# '-a  (count=1)
# elr  (count=1)
# dat  (count=2)
# txt  (count=4)
# uim  (count=1)
# sus  (count=1)
# hte  (count=1)
# uri  (count=3)
# tsm  (count=6)
# ebl  (count=1)
# wou  (count=1)
# aga  (count=2)
# esk  (count=1)
# -sl  (count=5)
# adc  (count=4)
# vpx  (count=3)
# rsp  (count=3)
# cdn  (count=1)
# ack  (count=1)
# sha  (count=4)
# 'ip  (count=1)
# mmc  (count=3)
# -xb  (count=6)
# snt  (count=5)
# mvn  (count=2)
# os=  (count=1)
# ip=  (count=2)
# -ve  (count=2)
# -qf  (count=1)
# acc  (count=2)
# oth  (count=2)
# -nn  (count=2)
# wmi  (count=3)
# sta  (count=1)
# -fv  (count=1)
# als  (count=2)
# -si  (count=1)
# kdc  (count=2)
# i++  (count=2)
# j++  (count=1)
# vif  (count=2)
# -ay  (count=2)
# su  (count=1)
# -  (count=1)
# ryo  (count=8)
# dpd  (count=9)
# cgw  (count=4)
# eth  (count=1)
# lom  (count=1)
# oas  (count=1)
# tnc  (count=6)
# rax  (count=1)
# rbx  (count=1)
# rcx  (count=1)
# rdx  (count=1)
# rsi  (count=1)
# rdi  (count=1)
# rbp  (count=1)
# nda  (count=5)
# dro  (count=2)
# -vv  (count=2)
# icu  (count=1)
# del  (count=3)
# an  (count=3)
# o+x  (count=1)
# eos  (count=1)
# -xe  (count=2)
# inv  (count=1)
# cn=  (count=1)
# /db  (count=2)
# -va  (count=1)
# pma  (count=1)
# wre  (count=1)
# 'nc  (count=1)
# w  (count=1)
# yun  (count=2)
# ser  (count=3)
# sal  (count=1)
# pve  (count=1)
# bai  (count=2)
# ama  (count=2)
# ina  (count=1)
# sam  (count=7)
# cau  (count=2)
# cwd  (count=1)
# dri  (count=1)
# kbs  (count=2)
# eof  (count=1)
# ufw  (count=10)
# aht  (count=1)
# zwi  (count=2)
# p.v  (count=3)
# -ei  (count=1)
# ret  (count=3)
# -cn  (count=1)
# wil  (count=2)
# cbc  (count=3)
# bom  (count=2)
# esx  (count=2)
# ovf  (count=5)
# wmf  (count=1)
# hav  (count=2)
# -cp  (count=1)
# duc  (count=4)
# swf  (count=1)
# wer  (count=3)
# mig  (count=12)
# hr=  (count=2)
# dur  (count=1)
# ln=  (count=2)
# md=  (count=1)
# dt=  (count=1)
# sel  (count=1)
# dvi  (count=5)
# ppa  (count=8)
# rmi  (count=1)
# pmu  (count=1)
# ord  (count=2)
# cou  (count=1)
# sni  (count=1)
# bgp  (count=1)
# nss  (count=2)
# cdc  (count=4)
# -th  (count=1)
# 'su  (count=1)
# cho  (count=2)
# cfn  (count=3)
# -ld  (count=3)
# hpc  (count=2)
# cas  (count=3)
# '-h  (count=1)
# dir  (count=1)
# ach  (count=2)
# my  (count=4)
# ip  (count=4)
# tgz  (count=2)
# eol  (count=3)
# 'dd  (count=1)
# 'an  (count=1)
# -c|  (count=1)
# -fs  (count=1)
# dbs  (count=1)
# -m  (count=1)
# dcv  (count=1)
# poe  (count=2)
# lrw  (count=1)
# gic  (count=1)
# -ik  (count=1)
# las  (count=1)
# dfs  (count=1)
# ise  (count=1)
# wsf  (count=1)
# rav  (count=4)
# ppp  (count=2)
# chr  (count=1)
# cer  (count=1)
# paa  (count=2)
# mib  (count=4)
# cpy  (count=1)
# ip  (count=1)
# as  (count=1)
# ptr  (count=2)
# ls  (count=1)
# spu  (count=1)
# eot  (count=2)
# rbe  (count=1)
# gdb  (count=1)
# .in  (count=1)
# e  (count=1)
# jdk  (count=2)
# rsa  (count=6)
# b  (count=3)
# jmx  (count=3)
# id  (count=1)
# vel  (count=2)
# swe  (count=6)
# mss  (count=13)
# nop  (count=29)
# tos  (count=9)
# -ie  (count=1)
# a.m  (count=1)
# /or  (count=1)
# -ir  (count=3)
# kno  (count=1)
# ndv  (count=3)
# 'ps  (count=2)
# kvm  (count=5)
# edr  (count=1)
# srm  (count=1)
# c++  (count=2)
# sna  (count=1)
# ter  (count=1)
# isn  (count=2)
# aml  (count=2)
# u+x  (count=1)
# fal  (count=1)
# jre  (count=3)
# duw  (count=1)
# dou  (count=1)
# hre  (count=1)
# pmd  (count=6)
# tsl  (count=2)
# scc  (count=5)
# sle  (count=2)
# '/^  (count=2)
# op=  (count=1)
# bel  (count=1)
# mai  (count=1)
# bac  (count=1)
# und  (count=1)
# fra  (count=1)
# c.i  (count=1)
# gon  (count=1)
# oss  (count=2)
# ses  (count=6)
# mta  (count=1)
# esc  (count=1)
# dbo  (count=1)
# sio  (count=1)
# 'vg  (count=1)
# 'lv  (count=1)
# fst  (count=1)
# gpg  (count=3)
# der  (count=4)
# hup  (count=1)
# che  (count=1)
# edw  (count=1)
# oui  (count=6)
# ..p  (count=2)
# mak  (count=1)
# abe  (count=1)
# scv  (count=1)
# dcs  (count=2)
# tis  (count=1)
# pwd  (count=2)
# tb  (count=1)
# tou  (count=1)
# onl  (count=1)
# abi  (count=1)
# o/s  (count=1)
# len  (count=1)
# .py  (count=1)
# uti  (count=1)
# nes  (count=1)
# -rh  (count=1)
# rms  (count=1)
# bsi  (count=3)
# bsc  (count=2)
# m/s  (count=11)
# k/s  (count=12)
# sfr  (count=2)
# atm  (count=1)
# kod  (count=1)
# gps  (count=1)
# lbd  (count=1)
# zzc  (count=1)
# svy  (count=1)
# e=_  (count=1)
# s=w  (count=1)
# -fc  (count=1)
# r~l  (count=1)
# b.i  (count=1)
# qsm  (count=1)
# qvt  (count=1)
# adp  (count=1)
# v*j  (count=1)
# drm  (count=1)
# asn  (count=1)
# fyr  (count=1)
# .as  (count=1)
# oem  (count=2)

# %%
for element in [
    'ec2', 'ami', 'ebs', 'kms', 'aws', 'cmk', 'url', 'web', 'oem', 'asn', 'gps', 'jre', 'isn', 'jmx', 'gdb', 'eol', 'gpt', 'mbr', 
    'isp', 'ide', 'phd', 'faq', 'gcc', 'vnc', 'udp', 'ntp', 'nfs', 'gpu', 'pid', 'lvm', 'gui', 'ecs', 'pem', 'awk', 'ecs', 'dms',
    'msg', 'pfa', 'rdp', 'pci', 'sep', 'fri', 'tue', 'feb', 'thu', 'gpl', 'sns', 'sme', 'acl', 'cmd', 'ecr', 'aug', 'mon', 'vpn', 
    'ssl', 'npm', 'vpn', 'rds', 'efs', 'dns', 'tcp', 'sql', 'ena', 'dec', 'emr', 'gmt', 'vpc', 'nat', 'acm', 'arn', 'cli', 'sdk',
    'api'
]:
    try:
        words_to_remove.remove(element)
    except:
        print(element)
# Out:
# web
# ecs
# vpn

# %%
print(len(words))
for w in words_to_remove:
    words.pop(w)
print(len(words))
# Out:
# 16128
# 15504

# %% [markdown]
# ---
# words starting with : or - or has = in them

# %%
words_to_remove = []
for w in words:
    match = re.search('^:\w+|^-\w+|\w+=\w+', w)
    if match:
#         if words[w] > 10:
#             print(f"{match.string}  (count={words[w]})")
        print(f"{match.string}  (count={words[w]})")
        words_to_remove.append(match.string)
# Out:
# -ano  (count=5)
# circle=all  (count=2)
# operator=all  (count=2)
# mode=app  (count=2)
# :describeinstances  (count=14)
# key=team  (count=1)
# value=hmsexp  (count=1)
# -version  (count=6)
# label=cloudimg-rootfs  (count=2)
# errors=remount-ro  (count=1)
# -euo  (count=1)
# -like  (count=3)
# baseurl=file  (count=1)
# gpgkey=file  (count=5)
# enablerepo=offline-httpd  (count=1)
# -gt  (count=5)
# -instance  (count=2)
# :instance  (count=2)
# -computername  (count=10)
# -port  (count=25)
# -if  (count=4)
# name=instanceid  (count=1)
# -vvv  (count=11)
# -testing  (count=5)
# :describeavailabilityzones  (count=1)
# -arn  (count=3)
# tclass=capability  (count=1)
# success=yes  (count=1)
# -ll  (count=1)
# :natgateway  (count=2)
# :cloudformation  (count=1)
# :stack  (count=1)
# mailer=esmtp  (count=1)
# stat=deferred  (count=1)
# setopt=docke  (count=1)
# name=docker  (count=9)
# -way  (count=1)
# -linux  (count=1)
# -keygen  (count=1)
# -https  (count=2)
# key=name  (count=4)
# key=aws  (count=2)
# -ling  (count=1)
# -adminaddress  (count=7)
# -bearertoken  (count=6)
# -source  (count=1)
# -starttime  (count=1)
# -text  (count=1)
# -allocationtype  (count=1)
# -isremotepc  (count=1)
# -loggingid  (count=3)
# -minimumfunctionallevel  (count=1)
# -name  (count=6)
# -persistuserchanges  (count=1)
# -provisioningtype  (count=1)
# -scope  (count=2)
# -sessionsupport  (count=1)
# -zoneuid  (count=2)
# -allowunicode  (count=1)
# -domain  (count=1)
# -identitypoolname  (count=1)
# -namingscheme  (count=1)
# -namingschemetype  (count=1)
# ou=citrix  (count=1)
# dc=bloom  (count=1)
# dc=ad  (count=1)
# -catalogid  (count=1)
# -value  (count=1)
# -provisioningschemename  (count=1)
# disablerepo=jenkins  (count=1)
# disable=jenkins  (count=1)
# :ami  (count=1)
# :keypair  (count=1)
# :securitygroup  (count=1)
# :subnet  (count=1)
# nooverwritedirnondir=true  (count=2)
# -prem  (count=1)
# -netframwork  (count=1)
# -rdp  (count=1)
# -id  (count=2)
# -bash  (count=15)
# color=auto  (count=2)
# -memory  (count=1)
# -sharmila  (count=1)
# -chat  (count=1)
# connect=none  (count=5)
# read=none  (count=5)
# redirect=none  (count=5)
# status=none  (count=5)
# name=instance-type  (count=10)
# -ltrh  (count=1)
# -server  (count=1)
# -logs  (count=1)
# -xvzf  (count=1)
# bootproto=dhcp  (count=5)
# onboot=yes  (count=5)
# type=ethernet  (count=5)
# userctl=no  (count=4)
# -madhur  (count=1)
# key=backup  (count=1)
# value=backup  (count=1)
# -amrik  (count=1)
# -vivek  (count=1)
# -ikl  (count=3)
# expires=thu  (count=2)
# info=all  (count=4)
# -localport  (count=1)
# -references  (count=5)
# -loss  (count=4)
# -software  (count=2)
# -hardware  (count=2)
# -to  (count=2)
# -after  (count=3)
# sec-severity=critical  (count=1)
# -password  (count=1)
# -accountneverexpires  (count=1)
# -fullname  (count=1)
# -description  (count=1)
# -passwordneverexpires  (count=2)
# -axhawxs  (count=1)
# cgroup.memory=nokmem  (count=1)
# -scheduleperboot  (count=1)
# -rfp  (count=1)
# name=resource-id  (count=2)
# -the  (count=5)
# name=location  (count=1)
# -onprem  (count=3)
# key=instanceids  (count=1)
# -command  (count=2)
# -taskname  (count=3)
# -schedule  (count=4)
# -usebasicparsing  (count=12)
# -uri  (count=14)
# -fr  (count=5)
# -iv  (count=7)
# -tpln  (count=1)
# name=postgresql  (count=1)
# -tnpa  (count=1)
# :improperwkhtmltopdfexitstatus  (count=2)
# -aaxv  (count=1)
# :rds  (count=1)
# :dbinstance  (count=1)
# :vpngateway  (count=1)
# -pr  (count=3)
# -ivh  (count=4)
# :kms  (count=1)
# :key  (count=1)
# -shift  (count=1)
# -specific  (count=1)
# values=lt-xxxxxxxxxxxxxx  (count=1)
# -ht  (count=10)
# -sch  (count=1)
# -anptupo  (count=2)
# key=webserver  (count=1)
# value=yes  (count=1)
# key=stack  (count=1)
# value=production  (count=1)
# -this  (count=2)
# -while  (count=1)
# -next  (count=3)
# -however  (count=1)
# -net  (count=3)
# -pczf  (count=1)
# -tlpn  (count=1)
# -ssm  (count=1)
# -double  (count=1)
# -that  (count=1)
# -checked  (count=1)
# -filter  (count=3)
# :truncate  (count=1)
# :new  (count=1)
# -incorrect  (count=2)
# -exhausted  (count=2)
# -corrupted  (count=2)
# -incompatible  (count=2)
# name=name  (count=4)
# values=digital*  (count=1)
# values=splunk*  (count=2)
# -stop  (count=1)
# -create  (count=1)
# -detach  (count=1)
# -class  (count=3)
# -namespace  (count=3)
# name=red  (count=4)
# -date  (count=1)
# -time  (count=1)
# -timezone  (count=1)
# name=tag  (count=4)
# values=node-name  (count=1)
# -o=wide  (count=1)
# values=name  (count=1)
# values=internal-ip  (count=1)
# -wait  (count=3)
# eventname=describetags  (count=1)
# -restore  (count=1)
# /offwindir=d  (count=1)
# /offbootdir=d  (count=1)
# expires=wed  (count=1)
# samesite=lax  (count=2)
# expires=sun  (count=1)
# sort=formattedstate  (count=1)
# -rwxrwxrwx  (count=1)
# :xxxx  (count=1)
# :xxxxxx  (count=1)
# -path  (count=2)
# -zxvf  (count=1)
# -hiv  (count=1)
# type=remoteadmin  (count=1)
# mode=enable  (count=1)
# scope=all  (count=1)
# -fav  (count=1)
# -max  (count=1)
# -nvl  (count=1)
# proto=tcp  (count=3)
# -disk  (count=1)
# -there  (count=1)
# -or-  (count=2)
# -mongodb-mongo  (count=3)
# -nltp  (count=1)
# -avz  (count=1)
# -read  (count=1)
# values=development*  (count=1)
# -rwxr  (count=1)
# -xdmzt  (count=3)
# -pid  (count=1)
# -pant  (count=1)
# -natup  (count=1)
# dir=in  (count=2)
# action=allow  (count=2)
# -avp  (count=1)
# -ilv  (count=1)
# c=us  (count=1)
# o=amazon  (count=1)
# ou=server  (count=1)
# cn=amazon  (count=1)
# -tnlp  (count=1)
# -jubladmin  (count=1)
# name=instance-id  (count=5)
# enablerepo=epel  (count=1)
# :aws  (count=1)
# -xdev  (count=1)
# -type  (count=2)
# -size  (count=1)
# -exec  (count=1)
# -lhrt  (count=1)
# -to-date  (count=1)
# key=purpose  (count=1)
# -av  (count=2)
# name=volume-type  (count=1)
# -tulpn  (count=4)
# -we  (count=1)
# code=exited  (count=5)
# -qa|grep  (count=2)
# -outfile  (count=3)
# passwordexpires=false  (count=1)
# -clear  (count=1)
# -open  (count=2)
# -rename  (count=1)
# -dism  (count=1)
# -sfc  (count=1)
# -targeturi  (count=1)
# -certificatethumbprint  (count=1)
# -recurse  (count=3)
# -dcallmodelapi=true  (count=1)
# -xx  (count=2)
# -for  (count=3)
# -choose  (count=1)
# -select  (count=2)
# -under  (count=1)
# -aws  (count=1)
# :comgenericthreadinghostthreadproc  (count=1)
# :createinstance  (count=1)
# :reportevent  (count=1)
# :logstring  (count=1)
# :compat  (count=2)
# :appraiser  (count=2)
# :setupappraiser  (count=2)
# :updateexpiredavregistry  (count=2)
# -ivk  (count=2)
# -some  (count=1)
# -ts  (count=1)
# -triggers  (count=2)
# region=regionhere  (count=1)
# output=json  (count=1)
# -ltr  (count=4)
# -ilkv  (count=2)
# -connect  (count=3)
# -la  (count=4)
# /c=de/st=bavaria/l=nuremberg/o=suse/ou=public  (count=1)
# cloud/cn=update  (count=1)
# :ssl  (count=1)
# :sslerror  (count=1)
# state=error  (count=1)
# :abort  (count=1)
# partition=c  (count=5)
# -profile  (count=1)
# -enabled  (count=1)
# -anob  (count=1)
# -h.  (count=1)
# nexttoken=token  (count=1)
# default=str  (count=1)
# :launchmodule  (count=2)
# comment=cloudconfig  (count=2)
# values=yes  (count=2)
# -third  (count=1)
# :executeaction  (count=1)
# :executeactionlist  (count=1)
# :execute  (count=1)
# state=wb  (count=1)
# country=in  (count=1)
# translation=bn  (count=1)
# crashkernel=auto  (count=2)
# capture=yes  (count=1)
# tracefile=c  (count=1)
# filemode=circular  (count=1)
# overwrite=yes  (count=1)
# report=no  (count=1)
# -wi-a  (count=1)
# root=label=/  (count=2)
# keytable=us  (count=1)
# level=error  (count=3)
# plugin=kernelmodules  (count=1)
# component=metricsingestsender  (count=1)
# plugin=systemd  (count=1)
# -avr  (count=1)
# -switchdaemon  (count=1)
# -nnn  (count=1)
# enablerepo=extras  (count=1)
# name=vpc-id  (count=1)
# values=vpc-xyz  (count=1)
# protocol=tcp  (count=1)
# enable=yes  (count=1)
# profile=private  (count=1)
# network=host  (count=1)
# driver=bridge  (count=1)
# -zvxf  (count=1)
# launchtemplatename=test  (count=1)
# peerdns=yes  (count=1)
# -anp  (count=1)
# -output.txt  (count=2)
# -showcerts  (count=1)
# -force  (count=6)
# -assemblyname  (count=1)
# -erroraction  (count=3)
# :extracttodirectory  (count=1)
# -option  (count=1)
# func=functor  (count=2)
# values=test  (count=1)
# id=debian  (count=1)
# name=group-id  (count=1)
# -taupen  (count=1)
# -enable  (count=1)
# -check  (count=1)
# -expandproperty  (count=2)
# -lah  (count=2)
# -vvttttnns  (count=1)
# -xvf  (count=1)
# sbin-path=path  (count=1)
# conf-path=path  (count=1)
# -nalutp  (count=1)
# error=head  (count=4)
# text=back  (count=1)
# rd.emergency=poweroff  (count=1)
# credentials=su  (count=1)
# mode=mode  (count=1)
# -cvzf  (count=1)
# -executionpolicy  (count=1)
# -instanceid  (count=2)
# -enasupport  (count=1)
# -rw-r  (count=8)
# -cafile  (count=3)
# -you  (count=1)
# -investigating  (count=1)
# -in  (count=5)
# -attached  (count=1)
# -output  (count=1)
# -sh  (count=1)
# -inform  (count=3)
# -out  (count=4)
# -sighup  (count=1)
# -review  (count=1)
# -ensure  (count=1)
# -consider  (count=1)
# -append  (count=1)
# -encoding  (count=1)
# -metricname  (count=1)
# description=run  (count=1)
# type=simple  (count=1)
# -kso  (count=1)
# :periodic  (count=2)
# :unattended-upgrade  (count=2)
# -du/*  (count=1)
# -noout  (count=1)
# -modu  (count=1)
# -outform  (count=1)
# -tulpen  (count=1)
# -click  (count=1)
# -zavh  (count=3)
# width=device-width  (count=1)
# -snip  (count=1)
# -tunl  (count=3)
# -string  (count=1)
# -asplaintext  (count=1)
# -domainname  (count=1)
# -credential  (count=1)
# -newname  (count=1)
# -verbose  (count=1)
# -zxf  (count=1)
# lsm=selinux  (count=1)
# -admin  (count=1)
# -error  (count=2)
# -comp  (count=1)
# -ahx  (count=1)
# -hup  (count=1)
# -nexus  (count=1)
# filters=filters  (count=2)
# user=root  (count=2)
# -ports  (count=1)
# -avd  (count=1)
# -no-window  (count=1)
# -no-audio  (count=1)
# -gpu  (count=2)
# -show-kernel  (count=1)
# -proddeploymentnode  (count=1)
# -reachable  (count=4)
# :packmacroblock  (count=1)
# :depthwiseconvimplementation  (count=1)
# :depthwiseconvdepthmultiplication  (count=1)
# :packmacroblockneon  (count=1)
# :depthwiseconvdotprodparams*  (count=1)

# %%
print(len(words))
for w in words_to_remove:
    words.pop(w)
print(len(words))
# Out:
# 15504
# 15074

# %% [markdown]
# ---

# %%
_temp = [k for k,v in words.items() if v == 1]
print(len(_temp))
print(_temp)

# %% [markdown]
# ---

# %% [markdown]
# # Standard Cleaning

# %% [markdown]
# ---
# punctuations and unicode cleaning

# %%
punct_dict = {key: ' ' for key in string.punctuation}
def remove_punctuation(sent):
    sent = sent.lower().replace('\n', ' ').replace('\t', ' ')
    sent_tokens = sent_tokenize(sent)
    result = ''
    for s_token in sent_tokens:
        valid_tokens = []
        tokens = word_tokenize(s_token)
        for _t in tokens:
            if _t in words.keys():
                valid_tokens.append(_t)
        result = result + ' '.join(valid_tokens) + ' ' 
    result = result.translate(str.maketrans(punct_dict))
    result = ' '.join([x.strip() for x in result.split()])
    result = re.sub(r'[^\x00-\x7f]',r'', result) 
    return result

# %%
data['2_punctuation_removal'] = data['1_url_cleaned_comm_body'].apply(lambda x: remove_punctuation(x))
data['2_punctuation_removal'].head(5).values
# Out:
# array(['dear team facing issue one the ec2 not coming kindly required your help please join meeting action taken launch ec2 take ami use this ami launch ec2 change ebs kms from aws ebs cmk ec2 launched status checks comes trial times purpose want migrate into another aws account and this ec2 contain aws default kms thanks nilay talati instance',
#        'hello have heard back from you regarding case for while for continued support regarding the same issue you can contact any time using the following url please note that action required your part you wish this case resolved however you want close this case yourself you could via the support center have heard back from you within the next hours will mark the case resolved although you can re open the case any time using the link above best regards amazon web services',
#        'while checking the instance the above instance status check would like know the cause that the instance was status check that can take more preventive measures instance',
#        'hello have looked into the issue and are taking some actions towards think actions requires from your end you can surely close this case have now well known about the issue thank you',
#        'please let know helped resolve your issue yes click here click here'],
#       dtype=object)

# %%
data['1_url_cleaned_comm_body'].head(5).values
# Out:
# array(['Dear Team,  I am facing issue in one of the EC2 (i-0e797d5b0d54cc3f4) it is not coming up. Kindly required your help. please join meeting at 12:05 PM IST.    Action I taken to launch EC2 (i-0e797d5b0d54cc3f4).: 1. Take AMI of  : i-0afdd40d680d5ed41 2. use this AMI to launch EC2: ami-0d261c2dff85df4d9 3. Change EBS KMS from "aws/ebs" to "cmk: 76dc5c61-d789-4f80-ac0b-21db46de0e47" 4. EC2 launched: i-0e797d5b0d54cc3f4 5. Status : 1/2 Checks comes 6.  Trial : 3 times  Purpose: I want to migrate i-0afdd40d680d5ed41 into another AWS account. and this EC2 contain aws default kms.  Thanks, Nilay Talati +919429142780 Instance ID(s):',
#        "Hello,  We haven't heard back from you regarding case 7938887601 for a while. For continued support regarding the same issue, you can contact us any time using the following URL:    Please note that no action is required on your part if you wish this case to be resolved. However, if you want to close this case yourself, you could do so via the Support Center. If we haven't heard back from you within the next 72 hours we will mark the case as Resolved, although you can re-open the case any time using the link above.  Best Regards,  Amazon Web Services",
#        'while checking the instance the above instance is in 1/2 status check. We would like to know the cause, that the instance was on 1/2 status check. So that we can take more preventive measures. Instance ID(s): i-0e908c95ac4998ee3',
#        'Hello,   We have looked into the issue and we are taking some actions towards it. We think no actions requires from your end. You can surely close this case. As we have now well known about the issue.  Thank you!',
#        'Please let us know if we helped resolve your issue:   If YES, click here:    If NO, click here:  '],
#       dtype=object)

# %%
sentences = data['2_punctuation_removal'].unique()
words = dict()
for sent in sentences:
    sent = sent.lower().replace('\n', ' ').replace('\t', ' ')
    sent_tokens = sent_tokenize(sent)
    for s_token in sent_tokens:
        tokens = word_tokenize(s_token)
        for t in tokens:
            if t in words:
                words[t] += 1
            else:
                words[t] = 1

print(len(words))
_temp = [k for k,v in words.items() if v == 1]
print(len(_temp))
print(_temp)
# Out:
# 11888
# 3860
# ['joins', 'notifying', 'views', 'bearing', 'pfb', 'computed', 'acm', 'targetgr', 'pertains', 'commercial', 'infrastrucute', 'coupled', 'regroup', 'yourselves', 'sprint', 'heron', 'addrulestocache', 'releaseid', 'defaultruleenginebootstrap', 'disposing', 'jgroupsbroadcastmethod', 'jgroups', 'asis', 'netwoek', 'trips', 'cpualarmhigh', 'breaches', 'healthyhostcount', 'ave', 'zappos', 'deploys', 'pictures', 'ebsreadbyte', 'mainstream', 'movie', 'radhe', 'featuring', 'khan', 'entertainment', 'mega', 'viewership', 'glitches', 'social', 'merics', 'shceduled', 'bed', 'goog', 'amazonssmagentsetup', 'controll', 'shekar', 'kshekar', 't', 'libressl', 'restting', 'renitiating', 'ndf', 'installtion', 'retirment', 'walapkar', 'madam', 'ultization', 'everthing', 'vscan', 'infrequent', 'documentkey', 'prathmesh', 'gettign', 'vaild', 'formate', 'spinlock', 'karoo', 'sqlservr', 'getspinlock', 'spid', 'yields', 'xdesmgr', 'prebuild', 'achive', 'targetnotconnected', 'decoupling', 'imapired', 'tabs', 'prouction', 'croudtrail', 'reebo', 'setopt', 'sreehari', 'dindu', 'autoscaler', 'initaiting', 'sandwich', 'conlsole', 'validations', 'hipi', 'regulary', 'pipefail', 'critial', 'schenk', 'chief', 'officer', 'ingresses', 'grade', 'libatomic', 'achiving', 'devicenam', 'massaging', 'descriptive', 'reconencting', 'rajguru', 'infotext', 'timerfallback', 'han', 'hints', 'irregularities', 'insignificant', 'pathak', 'intiating', 'pawal', 'tusharbp', 'undergoes', 'doesnot', 'wrnng', 'initques', 'music', 'finekart', 'stephan', 'kenedy', 'teamlink', 'meetinglearn', 'rakesbir', 'immedidately', 'reinitaiting', 'shred', 'kandavelu', 'rep', 'chirs', 'thrugh', 'pacth', 'birvatkar', 'repostiroy', 'ubunut', 'enviornment', 'certifica', 'wonder', 'kadian', 'kanwar', 'abbrev', 'introspect', 'choosen', 'har', 'elifecycle', 'eshwaraiah', 'shekaraiah', 'volme', 'volumemodificationrateexceeded', 'ciming', 'premkumar', 'suuport', 'commadmin', 'bro', 'redhart', 'adpater', 'upgade', 'compromising', 'align', 'baseos', 'phased', 'delegated', 'nprc', 'diffrent', 'autometed', 'daredevil', 'rimal', 'symmantec', 'unusually', 'evry', 'deregiter', 'scal', 'termianted', 'unregistering', 'runaslocalsystem', 'powershellarguments', 'bugtraq', 'vuln', 'certified', 'unimpeded', 'asserting', 'cardholder', 'handsake', 'ovoid', 'exectuing', 'awsdatalifecyclemanagerdefaultroleforami', 'afer', 'eventviewer', 'lamba', 'qp', 'occuring', 'continuosuly', 'groupby', 'usagetype', 'observerd', 'authentiation', 'assitance', 'dansaha', 'teach', 'vcpulimitexceeded', 'colaboration', 'consumer', 'booking', 'hostanamed', 'evenafter', 'vnet', 'libaio', 'invalidparameter', 'unaspectedly', 'fauliure', 'minimise', 'softlink', 'inot', 'commnd', 'ipserviceprotocol', 'opscenter', 'issac', 'disproportionally', 'xing', 'gov', 'waiter', 'instancerunning', 'gaurd', 'elk', 'spoc', 'lunched', 'rayrao', 'eu', 'underperforming', 'prottection', 'ininstance', 'effecting', 'shepherd', 'diprotiv', 'finacle', 'weal', 'centralised', 'fluentd', 'receving', 'preetamv', 'loos', 'everyweek', 'insufficiency', 'unheathy', 'golang', 'hibernated', 'nandan', 'chechked', 'prospective', 'appache', 'wiki', 'intances', 'gifwrapper', 'cameras', 'webgui', 'getcalleridentity', 'secert', 'pings', 'inititaing', 'nilofer', 'amaazon', 'prabhakaran', 'isssue', 'ramagiri', 'airvtrawsdlpans', 'sachdeva', 'failining', 'instamce', 'resovle', 'helpo', 'initialising', 'hampers', 'insatances', 'kunjeti', 'phew', 'consents', 'reveals', 'criminal', 'officials', 'buff', 'lei', 'handlers', 'argspec', 'jayendra', 'bradly', 'forti', 'bastin', 'fund', 'grouo', 'startinginstances', 'responsemetadata', 'httpstatuscode', 'httpheaders', 'includesubdomains', 'retryattempts', 'describeservices', 'amazonecs', 'ffrom', 'zeroes', 'swaps', 'sadc', 'telinit', 'initctl', 'splash', 'tty', 'quarantined', 'updatessm', 'datae', 'thinks', 'amaozn', 'lit', 'commissioned', 'inbuilt', 'stash', 'addind', 'etl', 'onmachine', 'mahadiscom', 'spawns', 'multipe', 'changeset', 'microservicesp ...

# %% [markdown]
# ---
# lemmatization

# %%
lemmatizer = WordNetLemmatizer()
def lemmatization(x):
    x = x.lower().split()
    result = []
    for w in x:
        result.append(lemmatizer.lemmatize(w))
    return ' '.join(result)

data['3_post_lemmetization'] = data['2_punctuation_removal'].apply(lambda x: lemmatization(x))
data['3_post_lemmetization'].head(5).values
# Out:
# array(['dear team facing issue one the ec2 not coming kindly required your help please join meeting action taken launch ec2 take ami use this ami launch ec2 change eb km from aws eb cmk ec2 launched status check come trial time purpose want migrate into another aws account and this ec2 contain aws default km thanks nilay talati instance',
#        'hello have heard back from you regarding case for while for continued support regarding the same issue you can contact any time using the following url please note that action required your part you wish this case resolved however you want close this case yourself you could via the support center have heard back from you within the next hour will mark the case resolved although you can re open the case any time using the link above best regard amazon web service',
#        'while checking the instance the above instance status check would like know the cause that the instance wa status check that can take more preventive measure instance',
#        'hello have looked into the issue and are taking some action towards think action requires from your end you can surely close this case have now well known about the issue thank you',
#        'please let know helped resolve your issue yes click here click here'],
#       dtype=object)

# %%
sentences = data['3_post_lemmetization'].unique()
words = dict()
for sent in sentences:
    sent = sent.lower().replace('\n', ' ').replace('\t', ' ')
    sent_tokens = sent_tokenize(sent)
    for s_token in sent_tokens:
        tokens = word_tokenize(s_token)
        for t in tokens:
            if t in words:
                words[t] += 1
            else:
                words[t] = 1

print(len(words))
_temp = [k for k,v in words.items() if v == 1]
print(len(_temp))
print(_temp)
# Out:
# 11039
# 3638
# ['notifying', 'bearing', 'pfb', 'computed', 'acm', 'targetgr', 'pertains', 'commercial', 'infrastrucute', 'coupled', 'regroup', 'yourselves', 'sprint', 'heron', 'addrulestocache', 'releaseid', 'defaultruleenginebootstrap', 'disposing', 'jgroupsbroadcastmethod', 'jgroups', 'asis', 'netwoek', 'trip', 'cpualarmhigh', 'healthyhostcount', 'ave', 'zappos', 'deploys', 'ebsreadbyte', 'mainstream', 'radhe', 'featuring', 'khan', 'entertainment', 'mega', 'viewership', 'social', 'merics', 'shceduled', 'bed', 'goog', 'amazonssmagentsetup', 'controll', 'shekar', 'kshekar', 't', 'libressl', 'restting', 'renitiating', 'ndf', 'installtion', 'retirment', 'walapkar', 'madam', 'ultization', 'everthing', 'vscan', 'infrequent', 'documentkey', 'prathmesh', 'gettign', 'vaild', 'formate', 'spinlock', 'karoo', 'sqlservr', 'getspinlock', 'spid', 'xdesmgr', 'prebuild', 'achive', 'targetnotconnected', 'decoupling', 'imapired', 'prouction', 'croudtrail', 'reebo', 'setopt', 'sreehari', 'dindu', 'autoscaler', 'initaiting', 'sandwich', 'conlsole', 'hipi', 'regulary', 'pipefail', 'critial', 'schenk', 'chief', 'officer', 'ingress', 'grade', 'libatomic', 'achiving', 'devicenam', 'massaging', 'descriptive', 'reconencting', 'rajguru', 'infotext', 'timerfallback', 'han', 'irregularity', 'insignificant', 'pathak', 'intiating', 'pawal', 'tusharbp', 'undergoes', 'doesnot', 'wrnng', 'initques', 'music', 'finekart', 'stephan', 'kenedy', 'teamlink', 'meetinglearn', 'rakesbir', 'immedidately', 'reinitaiting', 'shred', 'kandavelu', 'rep', 'chirs', 'thrugh', 'pacth', 'birvatkar', 'repostiroy', 'ubunut', 'enviornment', 'certifica', 'wonder', 'kadian', 'kanwar', 'abbrev', 'introspect', 'choosen', 'har', 'elifecycle', 'eshwaraiah', 'shekaraiah', 'volme', 'volumemodificationrateexceeded', 'ciming', 'premkumar', 'suuport', 'commadmin', 'bro', 'redhart', 'adpater', 'upgade', 'compromising', 'align', 'baseos', 'phased', 'delegated', 'nprc', 'diffrent', 'autometed', 'daredevil', 'rimal', 'symmantec', 'unusually', 'evry', 'deregiter', 'scal', 'termianted', 'unregistering', 'runaslocalsystem', 'powershellarguments', 'bugtraq', 'vuln', 'certified', 'unimpeded', 'asserting', 'cardholder', 'handsake', 'ovoid', 'exectuing', 'awsdatalifecyclemanagerdefaultroleforami', 'afer', 'eventviewer', 'lamba', 'qp', 'occuring', 'continuosuly', 'groupby', 'usagetype', 'observerd', 'authentiation', 'assitance', 'dansaha', 'teach', 'vcpulimitexceeded', 'colaboration', 'booking', 'hostanamed', 'evenafter', 'vnet', 'libaio', 'invalidparameter', 'unaspectedly', 'fauliure', 'minimise', 'softlink', 'inot', 'commnd', 'ipserviceprotocol', 'opscenter', 'issac', 'disproportionally', 'xing', 'gov', 'waiter', 'instancerunning', 'gaurd', 'elk', 'spoc', 'lunched', 'rayrao', 'eu', 'underperforming', 'prottection', 'ininstance', 'effecting', 'shepherd', 'diprotiv', 'finacle', 'weal', 'centralised', 'fluentd', 'receving', 'preetamv', 'loo', 'everyweek', 'insufficiency', 'unheathy', 'golang', 'hibernated', 'nandan', 'chechked', 'prospective', 'appache', 'wiki', 'intances', 'gifwrapper', 'camera', 'webgui', 'getcalleridentity', 'secert', 'inititaing', 'nilofer', 'amaazon', 'prabhakaran', 'isssue', 'ramagiri', 'airvtrawsdlpans', 'sachdeva', 'failining', 'instamce', 'resovle', 'helpo', 'initialising', 'insatances', 'kunjeti', 'phew', 'reveals', 'criminal', 'buff', 'lei', 'argspec', 'jayendra', 'bradly', 'forti', 'bastin', 'fund', 'grouo', 'startinginstances', 'responsemetadata', 'httpstatuscode', 'httpheaders', 'includesubdomains', 'retryattempts', 'describeservices', 'amazonecs', 'ffrom', 'sadc', 'telinit', 'initctl', 'splash', 'tty', 'quarantined', 'updatessm', 'datae', 'amaozn', 'lit', 'commissioned', 'inbuilt', 'stash', 'addind', 'etl', 'onmachine', 'mahadiscom', 'multipe', 'changeset', 'microservicespubli', 'natgatewaylimitexceeded', 'customcdkbucke', 'mic', 'refining', 'malhotra', 'waste', 'awslogs', 'inwindow', 'solrcloud', 'age', 'withh', 'awscredentialsprovider', 'instanceprofilecredentialsprovider', 'worrying',  ...

# %% [markdown]
# ---
# stop word removal

# %%
stop_words = set(stopwords.words('english'))
data['4_stop_words_removed'] = data['3_post_lemmetization'].apply(lambda sent: ' '.join([w for w in sent.split() if not w.lower() in stop_words]))
data['4_stop_words_removed'].head(5).values
# Out:
# array(['dear team facing issue one ec2 coming kindly required help please join meeting action taken launch ec2 take ami use ami launch ec2 change eb km aws eb cmk ec2 launched status check come trial time purpose want migrate another aws account ec2 contain aws default km thanks nilay talati instance',
#        'hello heard back regarding case continued support regarding issue contact time using following url please note action required part wish case resolved however want close case could via support center heard back within next hour mark case resolved although open case time using link best regard amazon web service',
#        'checking instance instance status check would like know cause instance wa status check take preventive measure instance',
#        'hello looked issue taking action towards think action requires end surely close case well known issue thank',
#        'please let know helped resolve issue yes click click'],
#       dtype=object)

# %%
sentences = data['4_stop_words_removed'].unique()
words = dict()
for sent in sentences:
    sent = sent.lower().replace('\n', ' ').replace('\t', ' ')
    sent_tokens = sent_tokenize(sent)
    for s_token in sent_tokens:
        tokens = word_tokenize(s_token)
        for t in tokens:
            if t in words:
                words[t] += 1
            else:
                words[t] = 1

print(len(words))
_temp = [k for k,v in words.items() if v == 1]
print(len(_temp))
print(_temp)
# Out:
# 10911
# 3630
# ['notifying', 'bearing', 'pfb', 'computed', 'acm', 'targetgr', 'pertains', 'commercial', 'infrastrucute', 'coupled', 'regroup', 'sprint', 'heron', 'addrulestocache', 'releaseid', 'defaultruleenginebootstrap', 'disposing', 'jgroupsbroadcastmethod', 'jgroups', 'asis', 'netwoek', 'trip', 'cpualarmhigh', 'healthyhostcount', 'ave', 'zappos', 'deploys', 'ebsreadbyte', 'mainstream', 'radhe', 'featuring', 'khan', 'entertainment', 'mega', 'viewership', 'social', 'merics', 'shceduled', 'bed', 'goog', 'amazonssmagentsetup', 'controll', 'shekar', 'kshekar', 'libressl', 'restting', 'renitiating', 'ndf', 'installtion', 'retirment', 'walapkar', 'madam', 'ultization', 'everthing', 'vscan', 'infrequent', 'documentkey', 'prathmesh', 'gettign', 'vaild', 'formate', 'spinlock', 'karoo', 'sqlservr', 'getspinlock', 'spid', 'xdesmgr', 'prebuild', 'achive', 'targetnotconnected', 'decoupling', 'imapired', 'prouction', 'croudtrail', 'reebo', 'setopt', 'sreehari', 'dindu', 'autoscaler', 'initaiting', 'sandwich', 'conlsole', 'hipi', 'regulary', 'pipefail', 'critial', 'schenk', 'chief', 'officer', 'ingress', 'grade', 'libatomic', 'achiving', 'devicenam', 'massaging', 'descriptive', 'reconencting', 'rajguru', 'infotext', 'timerfallback', 'han', 'irregularity', 'insignificant', 'pathak', 'intiating', 'pawal', 'tusharbp', 'undergoes', 'doesnot', 'wrnng', 'initques', 'music', 'finekart', 'stephan', 'kenedy', 'teamlink', 'meetinglearn', 'rakesbir', 'immedidately', 'reinitaiting', 'shred', 'kandavelu', 'rep', 'chirs', 'thrugh', 'pacth', 'birvatkar', 'repostiroy', 'ubunut', 'enviornment', 'certifica', 'wonder', 'kadian', 'kanwar', 'abbrev', 'introspect', 'choosen', 'har', 'elifecycle', 'eshwaraiah', 'shekaraiah', 'volme', 'volumemodificationrateexceeded', 'ciming', 'premkumar', 'suuport', 'commadmin', 'bro', 'redhart', 'adpater', 'upgade', 'compromising', 'align', 'baseos', 'phased', 'delegated', 'nprc', 'diffrent', 'autometed', 'daredevil', 'rimal', 'symmantec', 'unusually', 'evry', 'deregiter', 'scal', 'termianted', 'unregistering', 'runaslocalsystem', 'powershellarguments', 'bugtraq', 'vuln', 'certified', 'unimpeded', 'asserting', 'cardholder', 'handsake', 'ovoid', 'exectuing', 'awsdatalifecyclemanagerdefaultroleforami', 'afer', 'eventviewer', 'lamba', 'qp', 'occuring', 'continuosuly', 'groupby', 'usagetype', 'observerd', 'authentiation', 'assitance', 'dansaha', 'teach', 'vcpulimitexceeded', 'colaboration', 'booking', 'hostanamed', 'evenafter', 'vnet', 'libaio', 'invalidparameter', 'unaspectedly', 'fauliure', 'minimise', 'softlink', 'inot', 'commnd', 'ipserviceprotocol', 'opscenter', 'issac', 'disproportionally', 'xing', 'gov', 'waiter', 'instancerunning', 'gaurd', 'elk', 'spoc', 'lunched', 'rayrao', 'eu', 'underperforming', 'prottection', 'ininstance', 'effecting', 'shepherd', 'diprotiv', 'finacle', 'weal', 'centralised', 'fluentd', 'receving', 'preetamv', 'loo', 'everyweek', 'insufficiency', 'unheathy', 'golang', 'hibernated', 'nandan', 'chechked', 'prospective', 'appache', 'wiki', 'intances', 'gifwrapper', 'camera', 'webgui', 'getcalleridentity', 'secert', 'inititaing', 'nilofer', 'amaazon', 'prabhakaran', 'isssue', 'ramagiri', 'airvtrawsdlpans', 'sachdeva', 'failining', 'instamce', 'resovle', 'helpo', 'initialising', 'insatances', 'kunjeti', 'phew', 'reveals', 'criminal', 'buff', 'lei', 'argspec', 'jayendra', 'bradly', 'forti', 'bastin', 'fund', 'grouo', 'startinginstances', 'responsemetadata', 'httpstatuscode', 'httpheaders', 'includesubdomains', 'retryattempts', 'describeservices', 'amazonecs', 'ffrom', 'sadc', 'telinit', 'initctl', 'splash', 'tty', 'quarantined', 'updatessm', 'datae', 'amaozn', 'lit', 'commissioned', 'inbuilt', 'stash', 'addind', 'etl', 'onmachine', 'mahadiscom', 'multipe', 'changeset', 'microservicespubli', 'natgatewaylimitexceeded', 'customcdkbucke', 'mic', 'refining', 'malhotra', 'waste', 'awslogs', 'inwindow', 'solrcloud', 'age', 'withh', 'awscredentialsprovider', 'instanceprofilecredentialsprovider', 'worrying', 'asynchronously', ' ...

# %%
data.head()
# Out:
#       case_id                    customer_name  \
# 0  8415574821                          Genpact
# 1  7938887601  Axiata Digital Services Sdn Bhd
# 2  7938887601  Axiata Digital Services Sdn Bhd
# 3  7938887601  Axiata Digital Services Sdn Bhd
# 4  7745171561         Tata Communications Ltd.
#
#                                service case_billing_region  \
# 0  Elastic Compute Cloud (EC2 - Linux)                APAC
# 1  Elastic Compute Cloud (EC2 - Linux)                APAC
# 2  Elastic Compute Cloud (EC2 - Linux)                APAC
# 3  Elastic Compute Cloud (EC2 - Linux)                APAC
# 4  Elastic Compute Cloud (EC2 - Linux)                APAC
#
#   customer_billing_country_name comm_owner_agent_login  \
# 0                         INDIA               gupmanav
# 1                         INDIA                arizona
# 2                         INDIA                 wadhwh
# 3                         INDIA                 wadhwh
# 4                         INDIA                arizona
#
#                                            comm_body case_creation_cal_date  \
# 0  Dear Team,  I am facing issue in one of the EC...          6/2/2021 0:00
# 1  Hello,  We haven't heard back from you regardi...          2/1/2021 0:00
# 2  while checking the instance the above instance...          2/1/2021 0:00
# 3  Hello,   We have looked into the issue and we ...          2/1/2021 0:00
# 4  Please let us know if we helped resolve your i...        12/16/2020 0:00
#
#      comm_date_utc      comm_subject  case_severity  \
# 0    6/2/2021 0:00    1/2 checks EC2              4
# 1    2/9/2021 0:00  1/2 status check              4
# 2    2/1/2021 0:00  1/2 status check              4
# 3    2/9/2021 0:00  1/2 status check              4
# 4  12/26/2020 0:00  2/2 check failed              3
#
#                                                 urls  \
# 0                  https://genpact.zoom.us/my/talati
# 1  https://console.aws.amazon.com/support/home?#/...
# 2                                               None
# 3                                               None
# 4  https://console.aws.amazon.com/support/feedbac...
#
#                              1_url_cleaned_comm_body  \
# 0  Dear Team,  I am facing issue in one of the EC...
# 1  Hello,  We haven't heard back from you regardi...
# 2  while checking the instance the above instance...
# 3  Hello,   We have looked into the issue and we ...
# 4  Please let us know if we helped resolve your i...
#
#                                2_punctuation_removal  \
# 0  dear team facing issue one the ec2 not coming ...
# 1  hello have heard back from you regarding case ...
# 2  while checking the instance the above instance...
# 3  hello have looked into the issue and are takin...
# 4  please let know helped resolve your issue yes ...
#
#                                 3_post_lemmetization  \
# 0  dear team facing issue one the ec2 not coming ...
# 1  hello have heard back from you regarding case ...
# 2  while checking the instance the above instance...
# 3  hello have looked into the issue and are takin...
# 4  please let know helped resolve your issue yes ...
#
#                                 4_stop_words_removed
# 0  dear team facing issue one ec2 coming kindly r...
# 1  hello heard back regarding case continued supp...
# 2  checking instance instance status check would ...
# 3  hello looked issue taking action towards think...
# 4  please let know helped resolve issue yes click...

# %%
data.columns
# Out:
# Index(['case_id', 'customer_name', 'service', 'case_billing_region',
#        'customer_billing_country_name', 'comm_owner_agent_login', 'comm_body',
#        'case_creation_cal_date', 'comm_date_utc', 'comm_subject',
#        'case_severity', 'urls', '1_url_cleaned_comm_body',
#        '2_punctuation_removal', '3_post_lemmetization',
#        '4_stop_words_removed'],
#       dtype='object')

# %%
data[
        [
            'case_id', 'customer_name', 'service', 'case_billing_region',
            'customer_billing_country_name', 'comm_owner_agent_login', 'comm_body',
            'case_creation_cal_date', 'comm_date_utc', 'comm_subject',
            'case_severity', 'urls', '4_stop_words_removed'
        ]
].to_pickle(f'{base_dir}/Data/topic_modeling_data.pkl')

# %%
# t = data['4_stop_words_removed'].unique()
# words = set()
# for v in t:
#     words.update(v.split())

# print(words)

# words = []
# for row in data.iterrows():
#     print(row['4_stop_words_removed'])

# %%
# language_dict = enchant.Dict("en_US")
# def is_not_blank(s):
#     return bool(s and not s.isspace())

# words_with_problem = []
# for k, v in words.items():
#     try:
# #             _word = contractions.fix(k.strip())
#         _word = k.strip()
#         if not language_dict.check(_word):
#             print(f"{k}: {v}")
#     except:
#         words_with_problem.append(k)

# words_with_problem

# contractions.fix(words_with_problem[0])

# %%
# sentence = """
# Hello We have n't heard back from you regarding case 7938887601 for a while For continued support regarding the same issue you can contact us any time using the following URL Please note that no action is required on your part if you wish this case to be resolved However if you want to close this case yourself you could do so via the Support Center If we have n't heard back from you within the next 72 hours we will mark the case as Resolved although you can re-open the case any time using the link above Best Regards Amazon Web Services
# """

# from pprint import pprint 

# nlp = spacy.load('en_core_web_sm')
# doc = nlp(sentence)
# pprint(" ".join([token.lemma_ for token in doc]))

# ps = PorterStemmer() 
# lemmatizer = WordNetLemmatizer() 
# for i in sentence.split():
#     print(f"{i}: Lemma={lemmatizer.lemmatize(i)}, Stem={ps.stem(i)}", )
